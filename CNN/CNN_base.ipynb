# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# %%
class ViolinViolaDataset(Dataset):
    def __init__(self, root_dir, label_map = None, transform=None):
        self.root_dir = root_dir
        self.files = [f for f in os.listdir(root_dir) if f.endswith('.npy')]
        self.label_map = label_map or {'violin': 0, 'viola': 1}
        self.transform = transform

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        filename = self.files[idx]
        filepath = os.path.join(self.root_dir, filename)
        mel = np.load(filepath)
        spec = torch.from_numpy(mel)
        spec = spec.unsqueeze(0)  # Add channel dimension
        label = self.label_map[filename.split('_')[1]] if self.label_map else None
        if self.transform:
            spec = self.transform(spec)
        return spec, label

# %%
transform = transforms.Compose([
    transforms.Resize((128, 517)),  # Resize to a fixed size
    transforms.Normalize([0.5], [0.5])  # Normalize the image
])

# %%
g_train = torch.Generator()
g_train.manual_seed(17)
train_dataset = ViolinViolaDataset('train/', transform=transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

g_testval = torch.Generator().manual_seed(17)
testval_dataset = ViolinViolaDataset('test/', transform=transform)
val_size = int(0.5 * len(testval_dataset))
test_size = len(testval_dataset) - val_size
val_subset, test_subset = random_split(testval_dataset, [val_size, test_size], generator=g_testval)
val_loader = DataLoader(val_subset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_subset, batch_size=32, shuffle=False)

# %%
class ViolinViolaCNN(nn.Module):
    def __init__(self):
        super(ViolinViolaCNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=1, out_channels=40, stride=(2, 1), kernel_size=(5, 1))   # output: (40, 62, 517)
        self.dropout1 = nn.Dropout2d(p=0.35)
        self.conv2 = nn.Conv2d(in_channels=40, out_channels=32, kernel_size=(3, 2))  # output: (32, 60, 516)
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=16, kernel_size=1)  # output: (16, 60, 516)

        self.pool = nn.AdaptiveAvgPool2d((16, 16))  # reduce to fixed-size for Dense

        self.fc1 = nn.Linear(16 * 16 * 16, 64)
        self.fc2 = nn.Linear(64, 16)
        self.fc3 = nn.Linear(16, 12)
        self.out = nn.Linear(12, 2)  # binary classification: violin vs viola

    def forward(self, x):
        x = F.relu(self.conv1(x))  # -> (40, 62, 517)
        x = self.dropout1(x)
        x = F.relu(self.conv2(x))  # -> (32, 60, 516)
        x = F.relu(self.conv3(x))  # -> (16, 60, 516)
        x = self.pool(x)           # -> (16, 16, 16)
        x = x.view(x.size(0), -1)  # flatten
        x = F.relu(self.fc1(x))    # -> (64)
        x = F.relu(self.fc2(x))    # -> (16)
        x = F.relu(self.fc3(x))    # -> (12)
        x = self.out(x)            # -> (2)
        return x

# %%
class ViolinViolaCrossEntropyLoss(nn.Module):
    def __init__(self):
        super(ViolinViolaCrossEntropyLoss, self).__init__()
        self.register_buffer("class_weights", torch.tensor([1.0, 1.2]))

    def forward(self, outputs, labels):
        if self.class_weights is not None:
            class_weights = self.class_weights.to(outputs.device)
            return F.cross_entropy(outputs, labels, weight=class_weights)
        return F.cross_entropy(outputs, labels)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
model = ViolinViolaCNN()
criterion = ViolinViolaCrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# Out:
# Using device: cuda

# %%
from collections import defaultdict

def train(model, train_loader, val_loader, criterion, optimizer, device, num_epochs=10):
    max_avg_acc = {}

    model.to(device)

    # Use DataParallel for multiple GPUs
    if torch.cuda.device_count() > 1:
        print(f"Using {torch.cuda.device_count()} GPUs with DataParallel")
        model.to(device)  # Move model to CUDA *before* DataParallel
        model = torch.nn.DataParallel(model)
    else:
        model.to(device)


    history = {
        "train_loss": [], "val_loss": [],
        "train_acc": [], "val_acc": [],
        "train_class_acc": [], "val_class_acc": [],
        "train_class_loss": [], "val_class_loss": [],
        "val_roc_y_true": [], "val_roc_y_score": [],
    }

    for epoch in range(num_epochs):
        model.train()
        total_loss, total_correct, total_samples = 0, 0, 0
        class_loss = defaultdict(float)
        class_correct = defaultdict(int)
        class_total = defaultdict(int)

        for X, y in train_loader:
            X, y = X.to(device), y.to(device)

            optimizer.zero_grad()
            logits = model(X)
            loss = criterion(logits, y)
            loss.backward()
            optimizer.step()

            preds = logits.argmax(dim=1)
            total_loss += loss.item() * y.size(0)
            total_correct += (preds == y).sum().item()
            total_samples += y.size(0)

            for cls in [0, 1]:  # violin, viola
                idx = (y == cls)
                if idx.sum().item() > 0:
                    cls_loss = criterion(logits[idx], y[idx])
                    class_loss[cls] += cls_loss.item() * idx.sum().item()
                    class_correct[cls] += (preds[idx] == y[idx]).sum().item()
                    class_total[cls] += idx.sum().item()

        train_loss = total_loss / total_samples
        train_acc = total_correct / total_samples
        train_class_acc = [class_correct[c] / class_total[c] for c in [0, 1]]
        train_class_loss = [class_loss[c] / class_total[c] for c in [0, 1]]

        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["train_class_acc"].append(train_class_acc)
        history["train_class_loss"].append(train_class_loss)

        # --- Validation ---
        model.eval()
        total_loss, total_correct, total_samples = 0, 0, 0
        class_loss = defaultdict(float)
        class_correct = defaultdict(int)
        class_total = defaultdict(int)
        val_y_true, val_y_score = [], []

        with torch.no_grad():
            for X, y in val_loader:
                X, y = X.to(device), y.to(device)
                logits = model(X)
                loss = criterion(logits, y)

                preds = logits.argmax(dim=1)
                probs = torch.softmax(logits, dim=1)[:, 1]

                total_loss += loss.item() * y.size(0)
                total_correct += (preds == y).sum().item()
                total_samples += y.size(0)

                val_y_true.extend(y.cpu().numpy())
                val_y_score.extend(probs.cpu().numpy())

                for cls in [0, 1]:
                    idx = (y == cls)
                    if idx.sum().item() > 0:
                        cls_loss = criterion(logits[idx], y[idx])
                        class_loss[cls] += cls_loss.item() * idx.sum().item()
                        class_correct[cls] += (preds[idx] == y[idx]).sum().item()
                        class_total[cls] += idx.sum().item()

        val_loss = total_loss / total_samples
        val_acc = total_correct / total_samples
        val_class_acc = [class_correct[c] / class_total[c] for c in [0, 1]]
        val_class_loss = [class_loss[c] / class_total[c] for c in [0, 1]]

        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)
        history["val_class_acc"].append(val_class_acc)
        history["val_class_loss"].append(val_class_loss)
        history["val_roc_y_true"] = val_y_true
        history["val_roc_y_score"] = val_y_score

        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"  Train Loss: {train_loss:.4f} | Acc: {train_acc:.4f} | Violin Acc: {train_class_acc[0]:.4f} | Viola Acc: {train_class_acc[1]:.4f}")
        print(f"  Val   Loss: {val_loss:.4f} | Acc: {val_acc:.4f} | Violin Acc: {val_class_acc[0]:.4f} | Viola Acc: {val_class_acc[1]:.4f}")

        # Save model every epoch
        torch.save(model.state_dict(), f"violin_viola_cnn_base_epoch_{epoch+1}.pth")
        print(f"Model saved as violin_viola_cnn_base_epoch_{epoch+1}.pth")
        # Save maximum average accuracy between violin and viola
        max_avg_acc[(epoch + 1)] = (train_acc + val_acc) / 2

    return history, max_avg_acc

def plot_history(history):
    epochs = range(1, len(history["train_loss"]) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, history["train_loss"], label="Train Loss")
    plt.plot(epochs, history["val_loss"], label="Val Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.title("Loss over Epochs")

    plt.subplot(1, 2, 2)
    plt.plot(epochs, history["train_acc"], label="Train Acc")
    plt.plot(epochs, history["val_acc"], label="Val Acc")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.title("Accuracy over Epochs")

    plt.tight_layout()
    plt.show()

def plot_roc(y_true, y_score):
    fpr, tpr, _ = roc_curve(y_true, y_score)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.2f})")
    plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve (Violin vs Viola)")
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()

# %%
history, max_avg_acc = train(model, train_loader, val_loader, criterion, optimizer, device='cuda', num_epochs=25)

plot_history(history)
plot_roc(history["val_roc_y_true"], history["val_roc_y_score"])

# Restore the best model based on maximum average accuracy
best_epoch = max(max_avg_acc, key=max_avg_acc.get)
state_dict = torch.load(f"violin_viola_cnn_base_epoch_{best_epoch}.pth")
# Remove 'module.' prefix from all keys
new_state_dict = {k.replace("module.", ""): v for k, v in state_dict.items()}
model.load_state_dict(new_state_dict)
print(f"Best model restored from epoch {best_epoch} with max average accuracy {max_avg_acc[best_epoch]:.4f}")
# Out:
# Using 2 GPUs with DataParallel
# Epoch 1/25
#   Train Loss: 0.5130 | Acc: 0.7507 | Violin Acc: 0.8305 | Viola Acc: 0.6268
#   Val   Loss: 0.4677 | Acc: 0.7852 | Violin Acc: 0.7632 | Viola Acc: 0.8320
# Model saved as violin_viola_cnn_base_epoch_1.pth
# Epoch 2/25
#   Train Loss: 0.3404 | Acc: 0.8540 | Violin Acc: 0.8662 | Viola Acc: 0.8351
#   Val   Loss: 0.5338 | Acc: 0.7455 | Violin Acc: 0.6324 | Viola Acc: 0.9860
# Model saved as violin_viola_cnn_base_epoch_2.pth
# Epoch 3/25
#   Train Loss: 0.2596 | Acc: 0.8913 | Violin Acc: 0.8921 | Viola Acc: 0.8901
#   Val   Loss: 0.2870 | Acc: 0.8675 | Violin Acc: 0.8524 | Viola Acc: 0.8997
# Model saved as violin_viola_cnn_base_epoch_3.pth
# Epoch 4/25
#   Train Loss: 0.2076 | Acc: 0.9171 | Violin Acc: 0.9166 | Viola Acc: 0.9180
#   Val   Loss: 0.2551 | Acc: 0.8832 | Violin Acc: 0.8849 | Viola Acc: 0.8795
# Model saved as violin_viola_cnn_base_epoch_4.pth
# Epoch 5/25
#   Train Loss: 0.1857 | Acc: 0.9274 | Violin Acc: 0.9288 | Viola Acc: 0.9252
#   Val   Loss: 0.2863 | Acc: 0.9093 | Violin Acc: 0.9744 | Viola Acc: 0.7706
# Model saved as violin_viola_cnn_base_epoch_5.pth
# Epoch 6/25
#   Train Loss: 0.1661 | Acc: 0.9356 | Violin Acc: 0.9369 | Viola Acc: 0.9336
#   Val   Loss: 0.2164 | Acc: 0.9175 | Violin Acc: 0.9353 | Viola Acc: 0.8795
# Model saved as violin_viola_cnn_base_epoch_6.pth
# Epoch 7/25
#   Train Loss: 0.1583 | Acc: 0.9399 | Violin Acc: 0.9443 | Viola Acc: 0.9330
#   Val   Loss: 0.2074 | Acc: 0.9200 | Violin Acc: 0.9182 | Viola Acc: 0.9238
# Model saved as violin_viola_cnn_base_epoch_7.pth
# Epoch 8/25
#   Train Loss: 0.1357 | Acc: 0.9495 | Violin Acc: 0.9530 | Viola Acc: 0.9439
#   Val   Loss: 0.3746 | Acc: 0.8867 | Violin Acc: 0.9876 | Viola Acc: 0.6719
# Model saved as violin_viola_cnn_base_epoch_8.pth
# Epoch 9/25
#   Train Loss: 0.1258 | Acc: 0.9528 | Violin Acc: 0.9560 | Viola Acc: 0.9479
#   Val   Loss: 0.1954 | Acc: 0.9314 | Violin Acc: 0.9415 | Viola Acc: 0.9098
# Model saved as violin_viola_cnn_base_epoch_9.pth
# Epoch 10/25
#   Train Loss: 0.1180 | Acc: 0.9566 | Violin Acc: 0.9583 | Viola Acc: 0.9539
#   Val   Loss: 0.2276 | Acc: 0.9175 | Violin Acc: 0.9598 | Viola Acc: 0.8274
# Model saved as violin_viola_cnn_base_epoch_10.pth
# Epoch 11/25
#   Train Loss: 0.1040 | Acc: 0.9620 | Violin Acc: 0.9646 | Viola Acc: 0.9579
#   Val   Loss: 0.2113 | Acc: 0.9311 | Violin Acc: 0.9675 | Viola Acc: 0.8538
# Model saved as violin_viola_cnn_base_epoch_11.pth
# Epoch 12/25
#   Train Loss: 0.0899 | Acc: 0.9654 | Violin Acc: 0.9674 | Viola Acc: 0.9625
#   Val   Loss: 0.3144 | Acc: 0.8958 | Violin Acc: 0.8670 | Viola Acc: 0.9572
# Model saved as violin_viola_cnn_base_epoch_12.pth
# Epoch 13/25
#   Train Loss: 0.0829 | Acc: 0.9691 | Violin Acc: 0.9707 | Viola Acc: 0.9666
#   Val   Loss: 0.2058 | Acc: 0.9304 | Violin Acc: 0.9583 | Viola Acc: 0.8709
# Model saved as violin_viola_cnn_base_epoch_13.pth
# Epoch 14/25
#   Train Loss: 0.0779 | Acc: 0.9709 | Violin Acc: 0.9722 | Viola Acc: 0.9689
#   Val   Loss: 0.2447 | Acc: 0.9257 | Violin Acc: 0.9773 | Viola Acc: 0.8157
# Model saved as violin_viola_cnn_base_epoch_14.pth
# Epoch 15/25
#   Train Loss: 0.0647 | Acc: 0.9758 | Violin Acc: 0.9784 | Viola Acc: 0.9718
#   Val   Loss: 0.2199 | Acc: 0.9299 | Violin Acc: 0.9558 | Viola Acc: 0.8748
# Model saved as violin_viola_cnn_base_epoch_15.pth
# Epoch 16/25
#   Train Loss: 0.0618 | Acc: 0.9768 | Violin Acc: 0.9774 | Viola Acc: 0.9759
#   Val   Loss: 0.2352 | Acc: 0.9274 | Violin Acc: 0.9346 | Viola Acc: 0.9121
# Model saved as violin_viola_cnn_base_epoch_16.pth
# Epoch 17/25
#   Train Loss: 0.0596 | Acc: 0.9775 | Violin Acc: 0.9788 | Viola Acc: 0.9753
#   Val   Loss: 0.2300 | Acc: 0.9279 | Violin Acc: 0.9437 | Viola Acc: 0.8942
# Model saved as violin_viola_cnn_base_epoch_17.pth
# Epoch 18/25
#   Train Loss: 0.0524 | Acc: 0.9813 | Violin Acc: 0.9827 | Viola Acc: 0.9792
#   Val   Loss: 0.3150 | Acc: 0.9036 | Violin Acc: 0.8992 | Viola Acc: 0.9129
# Model saved as violin_viola_cnn_base_epoch_18.pth
# Epoch 19/25
#   Train Loss: 0.0489 | Acc: 0.9826 | Violin Acc: 0.9843 | Viola Acc: 0.9799
#   Val   Loss: 0.2186 | Acc: 0.9284 | Violin Acc: 0.9306 | Viola Acc: 0.9238
# Model saved as violin_viola_cnn_base_epoch_19.pth
# Epoch 20/25
#   Train Loss: 0.0479 | Acc: 0.9812 | Violin Acc: 0.9824 | Viola Acc: 0.9795
#   Val   Loss: 0.2197 | Acc: 0.9316 | Violin Acc: 0.9529 | Viola Acc: 0.8865
# Model saved as violin_viola_cnn_base_epoch_20.pth
# Epoch 21/25
#   Train Loss: 0.0432 | Acc: 0.9840 | Violin Acc: 0.9852 | Viola Acc: 0.9821
#   Val   Loss: 0.2609 | Acc: 0.9272 | Violin Acc: 0.9240 | Viola Acc: 0.9339
# Model saved as violin_viola_cnn_base_epoch_21.pth
# Epoch 22/25
#   Train Loss: 0.0394 | Acc: 0.9852 | Violin Acc: 0.9869 | Viola Acc: 0.9827
#   Val   Loss: 0.2484 | Acc: 0.9192 | Violin Acc: 0.9225 | Viola Acc: 0.9121
# Model saved as violin_viola_cnn_base_epoch_22.pth
# Epoch 23/25
#   Train Loss: 0.0406 | Acc: 0.9844 | Violin Acc: 0.9847 | Viola Acc: 0.9839
#   Val   Loss: 0.2758 | Acc: 0.9324 | Violin Acc: 0.9496 | Viola Acc: 0.8958
# Model saved as violin_viola_cnn_base_epoch_23.pth
# Epoch 24/25
#   Train Loss: 0.0360 | Acc: 0.9862 | Violin Acc: 0.9868 | Viola Acc: 0.9854
#   Val   Loss: 0.2520 | Acc: 0.9279 | Violin Acc: 0.9291 | Viola Acc: 0.9253
# Model saved as violin_viola_cnn_base_epoch_24.pth
# Epoch 25/25
#   Train Loss: 0.0309 | Acc: 0.9894 | Violin Acc: 0.9888 | Viola Acc: 0.9902
#   Val   Loss: 0.5254 | Acc: 0.8750 | Violin Acc: 0.8392 | Viola Acc: 0.9510
# Model saved as violin_viola_cnn_base_epoch_25.pth
# Best model restored from epoch 23 with max average accuracy 0.9584

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

for epoch in range(1, 26):
    state_dict = torch.load(f"violin_viola_cnn_base_epoch_{epoch}.pth")
    new_state_dict = {k.replace("module.", ""): v for k, v in state_dict.items()}
    model.load_state_dict(new_state_dict)
    model.to('cpu')
    model.eval()
    total_correct, total_samples = 0, 0
    class_correct = defaultdict(int)
    class_total = defaultdict(int)

    all_preds = []
    all_labels = []

    with torch.no_grad():
        for X, y in test_loader:
            X, y = X.to('cpu'), y.to('cpu')
            logits = model(X)
            preds = logits.argmax(dim=1)
            total_correct += (preds == y).sum().item()
            total_samples += y.size(0)

            # For accuracy
            for i in range(y.size(0)):
                class_total[y[i].item()] += 1
                class_correct[y[i].item()] += (preds[i] == y[i]).item()

            # For F1/Precision/Recall
            all_preds.extend(preds.tolist())
            all_labels.extend(y.tolist())

    test_acc = total_correct / total_samples
    print(f"Epoch {epoch}: Test Accuracy: {test_acc:.4f}")

    for cls in [0, 1]:
        if class_total[cls] > 0:
            class_acc = class_correct[cls] / class_total[cls]
            print(f"  Class {cls} Accuracy: {class_acc:.4f}")

    avg_class_acc = sum(class_correct[c] / class_total[c] for c in [0, 1]) / 2
    print(f"Average Class Accuracy: {avg_class_acc:.4f}")

    # F1, Precision, Recall (macro = average across classes)
    f1 = f1_score(all_labels, all_preds, average='macro')
    precision = precision_score(all_labels, all_preds, average='macro')
    recall = recall_score(all_labels, all_preds, average='macro')
    print(f"F1 Score (macro): {f1:.4f}")
    print(f"Precision (macro): {precision:.4f}")
    print(f"Recall (macro): {recall:.4f}")
    print("-" * 40)
# Out:
# Epoch 1: Test Accuracy: 0.7589
#   Class 0 Accuracy: 0.7297
#   Class 1 Accuracy: 0.8178
# Average Class Accuracy: 0.7738
# F1 Score (macro): 0.7471
# Precision (macro): 0.7450
# Recall (macro): 0.7738
# ----------------------------------------
# Epoch 2: Test Accuracy: 0.7383
#   Class 0 Accuracy: 0.6171
#   Class 1 Accuracy: 0.9828
# Average Class Accuracy: 0.7999
# F1 Score (macro): 0.7363
# Precision (macro): 0.7732
# Recall (macro): 0.7999
# ----------------------------------------
# Epoch 3: Test Accuracy: 0.8586
#   Class 0 Accuracy: 0.8383
#   Class 1 Accuracy: 0.8996
# Average Class Accuracy: 0.8689
# F1 Score (macro): 0.8482
# Precision (macro): 0.8389
# Recall (macro): 0.8689
# ----------------------------------------
# Epoch 4: Test Accuracy: 0.8782
#   Class 0 Accuracy: 0.8732
#   Class 1 Accuracy: 0.8883
# Average Class Accuracy: 0.8808
# F1 Score (macro): 0.8671
# Precision (macro): 0.8584
# Recall (macro): 0.8808
# ----------------------------------------
# Epoch 5: Test Accuracy: 0.8959
#   Class 0 Accuracy: 0.9576
#   Class 1 Accuracy: 0.7714
# Average Class Accuracy: 0.8645
# F1 Score (macro): 0.8778
# Precision (macro): 0.8972
# Recall (macro): 0.8645
# ----------------------------------------
# Epoch 6: Test Accuracy: 0.9220
#   Class 0 Accuracy: 0.9401
#   Class 1 Accuracy: 0.8853
# Average Class Accuracy: 0.9127
# F1 Score (macro): 0.9121
# Precision (macro): 0.9115
# Recall (macro): 0.9127
# ----------------------------------------
# Epoch 7: Test Accuracy: 0.9158
#   Class 0 Accuracy: 0.9104
#   Class 1 Accuracy: 0.9265
# Average Class Accuracy: 0.9185
# F1 Score (macro): 0.9073
# Precision (macro): 0.8992
# Recall (macro): 0.9185
# ----------------------------------------
# Epoch 8: Test Accuracy: 0.8775
#   Class 0 Accuracy: 0.9855
#   Class 1 Accuracy: 0.6597
# Average Class Accuracy: 0.8226
# F1 Score (macro): 0.8481
# Precision (macro): 0.9057
# Recall (macro): 0.8226
# ----------------------------------------
# Epoch 9: Test Accuracy: 0.9212
#   Class 0 Accuracy: 0.9286
#   Class 1 Accuracy: 0.9063
# Average Class Accuracy: 0.9175
# F1 Score (macro): 0.9122
# Precision (macro): 0.9076
# Recall (macro): 0.9175
# ----------------------------------------
# Epoch 10: Test Accuracy: 0.9163
#   Class 0 Accuracy: 0.9591
#   Class 1 Accuracy: 0.8298
# Average Class Accuracy: 0.8945
# F1 Score (macro): 0.9033
# Precision (macro): 0.9144
# Recall (macro): 0.8945
# ----------------------------------------
# Epoch 11: Test Accuracy: 0.9282
#   Class 0 Accuracy: 0.9658
#   Class 1 Accuracy: 0.8523
# Average Class Accuracy: 0.9091
# F1 Score (macro): 0.9173
# Precision (macro): 0.9273
# Recall (macro): 0.9091
# ----------------------------------------
# Epoch 12: Test Accuracy: 0.8800
#   Class 0 Accuracy: 0.8461
#   Class 1 Accuracy: 0.9483
# Average Class Accuracy: 0.8972
# F1 Score (macro): 0.8719
# Precision (macro): 0.8620
# Recall (macro): 0.8972
# ----------------------------------------
# Epoch 13: Test Accuracy: 0.9277
#   Class 0 Accuracy: 0.9565
#   Class 1 Accuracy: 0.8696
# Average Class Accuracy: 0.9130
# F1 Score (macro): 0.9175
# Precision (macro): 0.9225
# Recall (macro): 0.9130
# ----------------------------------------
# Epoch 14: Test Accuracy: 0.9269
#   Class 0 Accuracy: 0.9766
#   Class 1 Accuracy: 0.8268
# Average Class Accuracy: 0.9017
# F1 Score (macro): 0.9147
# Precision (macro): 0.9326
# Recall (macro): 0.9017
# ----------------------------------------
# Epoch 15: Test Accuracy: 0.9294
#   Class 0 Accuracy: 0.9580
#   Class 1 Accuracy: 0.8718
# Average Class Accuracy: 0.9149
# F1 Score (macro): 0.9195
# Precision (macro): 0.9246
# Recall (macro): 0.9149
# ----------------------------------------
# Epoch 16: Test Accuracy: 0.9279
#   Class 0 Accuracy: 0.9375
#   Class 1 Accuracy: 0.9085
# Average Class Accuracy: 0.9230
# F1 Score (macro): 0.9194
# Precision (macro): 0.9161
# Recall (macro): 0.9230
# ----------------------------------------
# Epoch 17: Test Accuracy: 0.9314
#   Class 0 Accuracy: 0.9454
#   Class 1 Accuracy: 0.9033
# Average Class Accuracy: 0.9243
# F1 Score (macro): 0.9229
# Precision (macro): 0.9215
# Recall (macro): 0.9243
# ----------------------------------------
# Epoch 18: Test Accuracy: 0.8979
#   Class 0 Accuracy: 0.8840
#   Class 1 Accuracy: 0.9258
# Average Class Accuracy: 0.9049
# F1 Score (macro): 0.8889
# Precision (macro): 0.8792
# Recall (macro): 0.9049
# ----------------------------------------
# Epoch 19: Test Accuracy: 0.9302
#   Class 0 Accuracy: 0.9320
#   Class 1 Accuracy: 0.9265
# Average Class Accuracy: 0.9293
# F1 Score (macro): 0.9224
# Precision (macro): 0.9167
# Recall (macro): 0.9293
# ----------------------------------------
# Epoch 20: Test Accuracy: 0.9329
#   Class 0 Accuracy: 0.9524
#   Class 1 Accuracy: 0.8936
# Average Class Accuracy: 0.9230
# F1 Score (macro): 0.9241
# Precision (macro): 0.9253
# Recall (macro): 0.9230
# ----------------------------------------
# Epoch 21: Test Accuracy: 0.9220
#   Class 0 Accuracy: 0.9197
#   Class 1 Accuracy: 0.9265
# Average Class Accuracy: 0.9231
# F1 Score (macro): 0.9138
# Precision (macro): 0.9066
# Recall (macro): 0.9231
# ----------------------------------------
# Epoch 22: Test Accuracy: 0.9185
#   Class 0 Accuracy: 0.9190
#   Class 1 Accuracy: 0.9175
# Average Class Accuracy: 0.9183
# F1 Score (macro): 0.9098
# Precision (macro): 0.9031
# Recall (macro): 0.9183
# ----------------------------------------
# Epoch 23: Test Accuracy: 0.9299
#   Class 0 Accuracy: 0.9431
#   Class 1 Accuracy: 0.9033
# Average Class Accuracy: 0.9232
# F1 Score (macro): 0.9213
# Precision (macro): 0.9195
# Recall (macro): 0.9232
# ----------------------------------------
# Epoch 24: Test Accuracy: 0.9254
#   Class 0 Accuracy: 0.9234
#   Class 1 Accuracy: 0.9295
# Average Class Accuracy: 0.9265
# F1 Score (macro): 0.9176
# Precision (macro): 0.9105
# Recall (macro): 0.9265
# ----------------------------------------
# Epoch 25: Test Accuracy: 0.8618
#   Class 0 Accuracy: 0.8190
#   Class 1 Accuracy: 0.9483
# Average Class Accuracy: 0.8836
# F1 Score (macro): 0.8539
# Precision (macro): 0.8458
# Recall (macro): 0.8836
# ----------------------------------------

# %%
# Best choice: Epoch 19
