# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader, random_split, default_collate
from torchvision import transforms
from torchvision.transforms.v2 import MixUp
from snorkel.classification import cross_entropy_with_probs
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from MixtureMaskingProbs import MixtureMasking

# %%
class ViolinViolaDataset(Dataset):
    def __init__(self, root_dir, label_map = None, transform=None):
        self.root_dir = root_dir
        self.files = [f for f in os.listdir(root_dir) if f.endswith('.npy')]
        self.label_map = label_map or {'violin': 0, 'viola': 1}
        self.transform = transform

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        filename = self.files[idx]
        filepath = os.path.join(self.root_dir, filename)
        mel = np.load(filepath)
        spec = torch.from_numpy(mel)
        spec = spec.unsqueeze(0)  # Add channel dimension
        label = self.label_map[filename.split('_')[1]] if self.label_map else None
        if self.transform:
            spec = self.transform(spec)
        return spec, label

# %%
transform = transforms.Compose([
    transforms.Resize((128, 517)),  # Resize to a fixed size
    transforms.Normalize([0.5], [0.5])  # Normalize the image
])
mixup = MixUp(num_classes=2, alpha=0.2)
def mixup_fn(batch):
    return mixup(*default_collate(batch))
def one_hot_fn(batch, num_classes=2):
    images, labels = default_collate(batch)
    labels = F.one_hot(labels, num_classes=num_classes).float()
    return images, labels

# %%
g_train = torch.Generator()
g_train.manual_seed(17)
train_dataset = ViolinViolaDataset('train/', transform=transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, collate_fn=mixup_fn)

g_testval = torch.Generator().manual_seed(17)
testval_dataset = ViolinViolaDataset('test/', transform=transform)
val_size = int(0.5 * len(testval_dataset))
test_size = len(testval_dataset) - val_size
val_subset, test_subset = random_split(testval_dataset, [val_size, test_size], generator=g_testval)
val_loader = DataLoader(val_subset, batch_size=32, shuffle=False, collate_fn=mixup_fn)
test_loader = DataLoader(test_subset, batch_size=32, shuffle=False,collate_fn=mixup_fn)

# %%
for x, y in train_loader:
    print(x.shape)
    print(y.shape)
    break
# Out:
# torch.Size([32, 1, 128, 517])
# torch.Size([32, 2])

# %%
class ViolinViolaCNN(nn.Module):
    def __init__(self):
        super(ViolinViolaCNN, self).__init__()

        self.mixturemasking1 = MixtureMasking(freq_param=8, time_param=35, activate_prob=0.6)
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=40, stride=(2, 1), kernel_size=(5, 1))   # output: (40, 62, 517)
        self.mixturemasking2 = MixtureMasking(freq_param=4, time_param=35, activate_prob=0.6)
        self.conv2 = nn.Conv2d(in_channels=40, out_channels=32, kernel_size=(3, 2))  # output: (32, 60, 516)
        self.mixturemasking3 = MixtureMasking(freq_param=4, time_param=35, activate_prob=0.6)
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=16, kernel_size=1)  # output: (16, 60, 516)

        self.pool = nn.AdaptiveAvgPool2d((16, 16))  # reduce to fixed-size for Dense

        self.fc1 = nn.Linear(16 * 16 * 16, 64)
        self.fc2 = nn.Linear(64, 16)
        self.fc3 = nn.Linear(16, 12)
        self.out = nn.Linear(12, 2)  # binary classification: violin vs viola

    def forward(self, x, labels):
        x = self.mixturemasking1(x, labels)
        x = F.relu(self.conv1(x))  # -> (40, 62, 517)
        x = self.mixturemasking2(x, labels)
        x = F.relu(self.conv2(x))  # -> (32, 60, 516)
        x = self.mixturemasking3(x, labels)
        x = F.relu(self.conv3(x))  # -> (16, 60, 516)
        x = self.pool(x)           # -> (16, 16, 16)
        x = x.view(x.size(0), -1)  # flatten
        x = F.relu(self.fc1(x))    # -> (64)
        x = F.relu(self.fc2(x))    # -> (16)
        x = F.relu(self.fc3(x))    # -> (12)
        x = self.out(x)            # -> (2)
        return x

# %%
class ViolinViolaCrossEntropyLoss(nn.Module):
    def __init__(self):
        super(ViolinViolaCrossEntropyLoss, self).__init__()
        self.register_buffer("class_weights", torch.tensor([1.0, 1.2]))

    def forward(self, outputs, labels):
        if self.class_weights is not None:
            class_weights = self.class_weights.to(outputs.device)
            return cross_entropy_with_probs(outputs, labels, weight=class_weights)
        return cross_entropy_with_probs(outputs, labels)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
model = ViolinViolaCNN()
criterion = ViolinViolaCrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# Out:
# Using device: cuda

# %%
from collections import defaultdict

def train(model, train_loader, val_loader, criterion, optimizer, device, num_epochs=10):
    max_avg_acc = {}
    model.to(device)

    # Multi-GPU support
    if torch.cuda.device_count() > 1:
        print(f"Using {torch.cuda.device_count()} GPUs with DataParallel")
        model = torch.nn.DataParallel(model)
    else:
        model.to(device)

    history = {
        "train_loss": [], "val_loss": [],
        "train_acc": [], "val_acc": [],
        "train_class_acc": [], "val_class_acc": [],
        "train_class_loss": [], "val_class_loss": [],
        "val_roc_y_true": [], "val_roc_y_score": [],
    }

    for epoch in range(num_epochs):
        model.train()
        total_loss, total_correct, total_samples = 0, 0, 0
        class_loss = defaultdict(float)
        class_correct = defaultdict(int)
        class_total = defaultdict(int)

        for X, y in train_loader:
            X, y = X.to(device), y.to(device)
            y_cls = y.argmax(dim=1)  # [B, 2] → [B]

            optimizer.zero_grad()
            logits = model(X, y)
            loss = criterion(logits, y)
            loss.backward()
            optimizer.step()

            preds = logits.argmax(dim=1)
            total_loss += loss.item() * y.size(0)
            total_correct += (preds == y_cls).sum().item()
            total_samples += y.size(0)

            for cls in [0, 1]:
                idx = (y_cls == cls)
                if idx.sum().item() > 0:
                    cls_loss = criterion(logits[idx], y[idx])
                    class_loss[cls] += cls_loss.item() * idx.sum().item()
                    class_correct[cls] += (preds[idx] == y_cls[idx]).sum().item()
                    class_total[cls] += idx.sum().item()

        train_loss = total_loss / total_samples
        train_acc = total_correct / total_samples
        train_class_acc = [class_correct[c] / class_total[c] for c in [0, 1]]
        train_class_loss = [class_loss[c] / class_total[c] for c in [0, 1]]

        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["train_class_acc"].append(train_class_acc)
        history["train_class_loss"].append(train_class_loss)

        # --- Validation ---
        model.eval()
        total_loss, total_correct, total_samples = 0, 0, 0
        class_loss = defaultdict(float)
        class_correct = defaultdict(int)
        class_total = defaultdict(int)
        val_y_true, val_y_score = [], []

        with torch.no_grad():
            for X, y in val_loader:
                X, y = X.to(device), y.to(device)
                y_cls = y.argmax(dim=1)  # convert [B, 2] to [B]

                logits = model(X, None)
                loss = criterion(logits, y)
                preds = logits.argmax(dim=1)
                probs = torch.softmax(logits, dim=1)[:, 1]  # probability for class 1 (viola)

                total_loss += loss.item() * y.size(0)
                total_correct += (preds == y_cls).sum().item()
                total_samples += y.size(0)

                val_y_true.extend(y_cls.cpu().numpy())   # binary int labels for ROC
                val_y_score.extend(probs.cpu().numpy())  # continuous scores

                for cls in [0, 1]:
                    idx = (y_cls == cls)
                    if idx.sum().item() > 0:
                        cls_loss = criterion(logits[idx], y[idx])
                        class_loss[cls] += cls_loss.item() * idx.sum().item()
                        class_correct[cls] += (preds[idx] == y_cls[idx]).sum().item()
                        class_total[cls] += idx.sum().item()

        val_loss = total_loss / total_samples
        val_acc = total_correct / total_samples
        val_class_acc = [class_correct[c] / class_total[c] for c in [0, 1]]
        val_class_loss = [class_loss[c] / class_total[c] for c in [0, 1]]

        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)
        history["val_class_acc"].append(val_class_acc)
        history["val_class_loss"].append(val_class_loss)
        history["val_roc_y_true"] = val_y_true
        history["val_roc_y_score"] = val_y_score

        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"  Train Loss: {train_loss:.4f} | Acc: {train_acc:.4f} | Violin Acc: {train_class_acc[0]:.4f} | Viola Acc: {train_class_acc[1]:.4f}")
        print(f"  Val   Loss: {val_loss:.4f} | Acc: {val_acc:.4f} | Violin Acc: {val_class_acc[0]:.4f} | Viola Acc: {val_class_acc[1]:.4f}")

        # Save model every epoch
        torch.save(model.state_dict(), f"mmmu/violin_viola_cnn_mixturemasking_mixup_epoch_{epoch+1}.pth")
        print(f"Model saved as mmmu/violin_viola_cnn_mixturemasking_mixup_epoch_{epoch+1}.pth")
        max_avg_acc[(epoch + 1)] = (train_acc + val_acc) / 2

    return history, max_avg_acc

def plot_history(history):
    epochs = range(1, len(history["train_loss"]) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, history["train_loss"], label="Train Loss")
    plt.plot(epochs, history["val_loss"], label="Val Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.title("Loss over Epochs")

    plt.subplot(1, 2, 2)
    plt.plot(epochs, history["train_acc"], label="Train Acc")
    plt.plot(epochs, history["val_acc"], label="Val Acc")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.title("Accuracy over Epochs")

    plt.tight_layout()
    plt.show()

def plot_roc(y_true, y_score):
    fpr, tpr, _ = roc_curve(y_true, y_score)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.2f})")
    plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve (Violin vs Viola)")
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()

# %%
history, max_avg_acc = train(model, train_loader, val_loader, criterion, optimizer, device='cuda', num_epochs=60)

plot_history(history)
plot_roc(history["val_roc_y_true"], history["val_roc_y_score"])

# Restore the best model based on maximum average accuracy
best_epoch = max(max_avg_acc, key=max_avg_acc.get)
state_dict = torch.load(f"mmmu/violin_viola_cnn_mixturemasking_mixup_epoch_{best_epoch}.pth")
# Remove 'module.' prefix from all keys
new_state_dict = {k.replace("module.", ""): v for k, v in state_dict.items()}
model.load_state_dict(new_state_dict)
print(f"Best model restored from epoch {best_epoch} with max average accuracy {max_avg_acc[best_epoch]:.4f}")
# Out:
# Using 2 GPUs with DataParallel
# Epoch 1/60
#   Train Loss: 0.6580 | Acc: 0.6530 | Violin Acc: 0.7499 | Viola Acc: 0.5028
#   Val   Loss: 0.4961 | Acc: 0.8128 | Violin Acc: 0.8283 | Viola Acc: 0.7802
# Model saved as mmmu/violin_viola_cnn_mixturemasking_mixup_epoch_1.pth
# Epoch 2/60
#   Train Loss: 0.3493 | Acc: 0.8941 | Violin Acc: 0.9017 | Viola Acc: 0.8823
#   Val   Loss: 0.3560 | Acc: 0.8717 | Violin Acc: 0.8415 | Viola Acc: 0.9358
# Model saved as mmmu/violin_viola_cnn_mixturemasking_mixup_epoch_2.pth
# Epoch 3/60
#   Train Loss: 0.2832 | Acc: 0.9241 | Violin Acc: 0.9283 | Viola Acc: 0.9175
#   Val   Loss: 0.3475 | Acc: 0.8819 | Violin Acc: 0.8909 | Viola Acc: 0.8630
# Model saved as mmmu/violin_viola_cnn_mixturemasking_mixup_epoch_3.pth
# Epoch 4/60
#   Train Loss: 0.2721 | Acc: 0.9308 | Violin Acc: 0.9359 | Viola Acc: 0.9228
#   Val   Loss: 0.2954 | Acc: 0.9177 | Violin Acc: 0.9396 | Viola Acc: 0.8715
# Model saved as mmmu/violin_viola_cnn_mixturemasking_mixup_epoch_4.pth
# Epoch 5/60
#   Train Loss: 0.2339 | Acc: 0.9453 | Violin Acc: 0.9503 | Viola Acc: 0.9376
#   Val   Loss: 0.4614 | Acc: 0.8640 | Violin Acc: 0.9707 | Viola Acc: 0.6385
# Model saved as mmmu/violin_viola_cnn_mixturemasking_mixup_epoch_5.pth
# Epoch 6/60
#   Train Loss: 0.2294 | Acc: 0.9505 | Violin Acc: 0.9561 | Viola Acc: 0.9418
#   Val   Loss: 0.3075 | Acc: 0.9147 | Violin Acc: 0.9528 | Viola Acc: 0.8344
# Model saved as mmmu/violin_viola_cnn_mixturemasking_mixup_epoch
# Model saved as mmmu/violin_viola_cnn_mixturemasking_mixup_epoch_56.pth
# Epoch 57/60
#   Train Loss: 0.1776 | Acc: 0.9735 | Violin Acc: 0.9704 | Viola Acc: 0.9782
#   Val   Loss: 0.2997 | Acc: 0.9242 | Violin Acc: 0.9429 | Viola Acc: 0.8847
# Model saved as mmmu/violin_viola_cnn_mixturemasking_mixup_epoch_57.pth
# Epoch 58/60
#   Train Loss: 0.1769 | Acc: 0.9802 | Violin Acc: 0.9780 | Viola Acc: 0.9836
#   Val   Loss: 0.3775 | Acc: 0.9075 | Violin Acc: 0.9894 | Viola Acc: 0.7345
# Model saved as mmmu/violin_viola_cnn_mixturemasking_mixup_epoch_58.pth
# Epoch 59/60
#   Train Loss: 0.1842 | Acc: 0.9725 | Violin Acc: 0.9720 | Viola Acc: 0.9733
#   Val   Loss: 0.3136 | Acc: 0.9237 | Violin Acc: 0.9315 | Viola Acc: 0.9071
# Model saved as mmmu/violin_viola_cnn_mixturemasking_mixup_epoch_59.pth
# Epoch 60/60
#   Train Loss: 0.1778 | Acc: 0.9770 | Violin Acc: 0.9773 | Viola Acc: 0.9767
#   Val   Loss: 0.2681 | Acc: 0.9324 | Violin Acc: 0.9458 | Viola Acc: 0.9040
# Model saved as mmmu/violin_viola_cnn_mixturemasking_mixup_epoch_60.pth
# Best model restored from epoch 56 with max average accuracy 0.9556

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

for epoch in range(1, 61):
    state_dict = torch.load(f"mmmu/violin_viola_cnn_mixturemasking_mixup_epoch_{epoch}.pth")
    new_state_dict = {k.replace("module.", ""): v for k, v in state_dict.items()}
    model.load_state_dict(new_state_dict)
    model.to('cpu')
    model.eval()

    total_correct, total_samples = 0, 0
    class_correct = defaultdict(int)
    class_total = defaultdict(int)

    all_preds = []
    all_labels = []

    with torch.no_grad():
        for X, y in test_loader:
            X, y = X.to('cpu'), y.to('cpu')  # y is one-hot, shape [B, 2]
            y_cls = y.argmax(dim=1)         # convert to shape [B]

            logits = model(X, None)
            preds = logits.argmax(dim=1)

            total_correct += (preds == y_cls).sum().item()
            total_samples += y_cls.size(0)

            # For accuracy
            for i in range(y_cls.size(0)):
                label = y_cls[i].item()
                class_total[label] += 1
                class_correct[label] += (preds[i].item() == label)

            # For F1/Precision/Recall
            all_preds.extend(preds.tolist())
            all_labels.extend(y_cls.tolist())

    test_acc = total_correct / total_samples
    print(f"Epoch {epoch}: Test Accuracy: {test_acc:.4f}")

    for cls in [0, 1]:
        if class_total[cls] > 0:
            class_acc = class_correct[cls] / class_total[cls]
            print(f"  Class {cls} Accuracy: {class_acc:.4f}")

    avg_class_acc = sum(class_correct[c] / class_total[c] for c in [0, 1]) / 2
    print(f"Average Class Accuracy: {avg_class_acc:.4f}")

    # F1, Precision, Recall (macro = average across classes)
    f1 = f1_score(all_labels, all_preds, average='macro')
    precision = precision_score(all_labels, all_preds, average='macro')
    recall = recall_score(all_labels, all_preds, average='macro')
    print(f"F1 Score (macro): {f1:.4f}")
    print(f"Precision (macro): {precision:.4f}")
    print(f"Recall (macro): {recall:.4f}")
    print("-" * 40)
# Out:
# Epoch 1: Test Accuracy: 0.8029
#   Class 0 Accuracy: 0.8186
#   Class 1 Accuracy: 0.7711
# Average Class Accuracy: 0.7949
# F1 Score (macro): 0.7843
# Precision (macro): 0.7779
# Recall (macro): 0.7949
# ----------------------------------------
# Epoch 2: Test Accuracy: 0.8708
#   Class 0 Accuracy: 0.8335
#   Class 1 Accuracy: 0.9465
# Average Class Accuracy: 0.8900
# F1 Score (macro): 0.8624
# Precision (macro): 0.8531
# Recall (macro): 0.8900
# ----------------------------------------
# Epoch 3: Test Accuracy: 0.8864
#   Class 0 Accuracy: 0.8872
#   Class 1 Accuracy: 0.8848
# Average Class Accuracy: 0.8860
# F1 Score (macro): 0.8750
# Precision (macro): 0.8672
# Recall (macro): 0.8860
# ----------------------------------------
# Epoch 4: Test Accuracy: 0.9115
#   Class 0 Accuracy: 0.9262
#   Class 1 Accuracy: 0.8818
# Average Class Accuracy: 0.9040
# F1 Score (macro): 0.9008
# Precision (macro): 0.8978
# Recall (macro): 0.9040
# ----------------------------------------
# Epoch 5: Test Accuracy: 0.8718
#   Class 0 Accuracy: 0.9740
#   Class 1 Accuracy: 0.6642
# Average Class Accuracy: 0.8191
# F1 Score (macro): 0.8421
# Precision (macro): 0.8906
# Recall (macro): 0.8191
# ----------------------------------------
# Epoch 6: Test Accuracy: 0.9033
#   Class 0 Accuracy: 0.9347
#   Class 1 Accuracy: 0.8396
# Average Class Accuracy: 0.8872
# F1 Score (macro): 0.8899
# Precision (macro): 0.8929
# Recall (macro): 0.8872
# ----------------------------------------
# Epoch 7: Test Accuracy: 0.9100
#   Class 0 Accuracy: 0.9340
#   Class 1 Accuracy: 0.8614
# Average Class Accuracy: 0.8977
# F1 Score (macro): 0.8982
# Precision (macro): 0.8986
# Recall (macro): 0.8977
# ----------------------------------------
# Epoch 8: Test Accuracy: 0.9165
#   Class 0 Accuracy: 0.9073
#   Class 1 Accuracy: 0.9352
# Average Class Accuracy: 0.9213
# F1 Score (macro): 0.9083
# Precision (macro): 0.8992
# Recall (macro): 0.9213
# ----------------------------------------
# Epoch 9: Test Accuracy: 0.9123
#   Class 0 Accuracy: 0.9054
#   Class 1 Accuracy: 0.9262
# Average Class Accuracy: 0.9158
# F1 Score (macro): 0.9035
# Precision (macro): 0.8948
# Recall (macro): 0.9158
# ----------------------------------------
# Epoch 10: Test Accuracy: 0.9051
#   Class 0 Accuracy: 0.8999
#   Class 1 Accuracy: 0.9157
# Average Class Accuracy: 0.9078
# F1 Score (macro): 0.8956
# Precision (macro): 0.8871
# Recall (macro): 0.9078
# ----------------------------------------
# Epoch 11: Test Accuracy: 0.9023
#   Class 0 Accuracy: 0.9043
#   Class 1 Accuracy: 0.8983
# Average Class Accuracy: 0.9013
# F1 Score (macro): 0.8920
# Precision (macro): 0.8849
# Recall (macro): 0.9013
# ----------------------------------------
# Epoch 12: Test Accuracy: 0.9108
#   Class 0 Accuracy: 0.9373
#   Class 1 Accuracy: 0.8569
# Average Class Accuracy: 0.8971
# F1 Score (macro): 0.8987
# Precision (macro): 0.9004
# Recall (macro): 0.8971
# ----------------------------------------
# Epoch 13: Test Accuracy: 0.8956
#   Class 0 Accuracy: 0.9503
#   Class 1 Accuracy: 0.7846
# Average Class Accuracy: 0.8675
# F1 Score (macro): 0.8783
# Precision (macro): 0.8928
# Recall (macro): 0.8675
# ----------------------------------------
# Epoch 14: Test Accuracy: 0.9013
#   Class 0 Accuracy: 0.8846
#   Class 1 Accuracy: 0.9352
# Average Class Accuracy: 0.9099
# F1 Score (macro): 0.8927
# Precision (macro): 0.8825
# Recall (macro): 0.9099
# ----------------------------------------
# Epoch 15: Test Accuracy: 0.9013
#   Class 0 Accuracy: 0.9655
#   Class 1 Accuracy: 0.7711
# Average Class Accuracy: 0.8683
# F1 Score (macro): 0.8834
# Precision (macro): 0.9061
# Recall (macro): 0.8683
# ----------------------------------------
# Epoch 16: Test Accuracy: 0.9175
#   Class 0 Accuracy: 0.9232
#   Class 1 Accuracy: 0.9059
# Average Class Accuracy: 0.9145
# F1 Score (macro): 0.9081
# Precision (macro): 0.9027
# Recall (macro): 0.9145
# ----------------------------------------
# Epoch 17: Test Accuracy: 0.8929
#   Class 0 Accuracy: 0.8709
#   Class 1 Accuracy: 0.9375
# Average Class Accuracy: 0.9042
# F1 Score (macro): 0.8842
# Precision (macro): 0.8737
# Recall (macro): 0.9042
# ----------------------------------------
# Epoch 18: Test Accuracy: 0.9058
#   Class 0 Accuracy: 0.9128
#   Class 1 Accuracy: 0.8916
# Average Class Accuracy: 0.9022
# F1 Score (macro): 0.8953
# Precision (macro): 0.8896
# Recall (macro): 0.9022
# ----------------------------------------
# Epoch 19: Test Accuracy: 0.9108
#   Class 0 Accuracy: 0.9050
#   Class 1 Accuracy: 0.9224
# Average Class Accuracy: 0.9137
# F1 Score (macro): 0.9018
# Precision (macro): 0.8933
# Recall (macro): 0.9137
# ----------------------------------------
# Epoch 20: Test Accuracy: 0.9148
#   Class 0 Accuracy: 0.9347
#   Class 1 Accuracy: 0.8742
# Average Class Accuracy: 0.9045
# F1 Score (macro): 0.9038
# Precision (macro): 0.9031
# Recall (macro): 0.9045
# ----------------------------------------
# Epoch 21: Test Accuracy: 0.9130
#   Class 0 Accuracy: 0.9432
#   Class 1 Accuracy: 0.8517
# Average Class Accuracy: 0.8975
# F1 Score (macro): 0.9008
# Precision (macro): 0.9045
# Recall (macro): 0.8975
# ----------------------------------------
# Epoch 22: Test Accuracy: 0.9165
#   Class 0 Accuracy: 0.9214
#   Class 1 Accuracy: 0.9066
# Average Class Accuracy: 0.9140
# F1 Score (macro): 0.9071
# Precision (macro): 0.9014
# Recall (macro): 0.9140
# ----------------------------------------
# Epoch 23: Test Accuracy: 0.8941
#   Class 0 Accuracy: 0.9440
#   Class 1 Accuracy: 0.7929
# Average Class Accuracy: 0.8685
# F1 Score (macro): 0.8773
# Precision (macro): 0.8885
# Recall (macro): 0.8685
# ----------------------------------------
# Epoch 24: Test Accuracy: 0.9172
#   Class 0 Accuracy: 0.9395
#   Class 1 Accuracy: 0.8720
# Average Class Accuracy: 0.9058
# F1 Score (macro): 0.9063
# Precision (macro): 0.9069
# Recall (macro): 0.9058
# ----------------------------------------
# Epoch 25: Test Accuracy: 0.8944
#   Class 0 Accuracy: 0.9640
#   Class 1 Accuracy: 0.7530
# Average Class Accuracy: 0.8585
# F1 Score (macro): 0.8746
# Precision (macro): 0.8998
# Recall (macro): 0.8585
# ----------------------------------------
# Epoch 26: Test Accuracy: 0.9115
#   Class 0 Accuracy: 0.9377
#   Class 1 Accuracy: 0.8584
# Average Class Accuracy: 0.8981
# F1 Score (macro): 0.8996
# Precision (macro): 0.9012
# Recall (macro): 0.8981
# ----------------------------------------
# Epoch 27: Test Accuracy: 0.9016
#   Class 0 Accuracy: 0.9225
#   Class 1 Accuracy: 0.8592
# Average Class Accuracy: 0.8908
# F1 Score (macro): 0.8892
# Precision (macro): 0.8876
# Recall (macro): 0.8908
# ----------------------------------------
# Epoch 28: Test Accuracy: 0.9190
#   Class 0 Accuracy: 0.9507
#   Class 1 Accuracy: 0.8547
# Average Class Accuracy: 0.9027
# F1 Score (macro): 0.9073
# Precision (macro): 0.9125
# Recall (macro): 0.9027
# ----------------------------------------
# Epoch 29: Test Accuracy: 0.9061
#   Class 0 Accuracy: 0.9069
#   Class 1 Accuracy: 0.9044
# Average Class Accuracy: 0.9056
# F1 Score (macro): 0.8961
# Precision (macro): 0.8889
# Recall (macro): 0.9056
# ----------------------------------------
# Epoch 30: Test Accuracy: 0.9289
#   Class 0 Accuracy: 0.9355
#   Class 1 Accuracy: 0.9157
# Average Class Accuracy: 0.9256
# F1 Score (macro): 0.9206
# Precision (macro): 0.9161
# Recall (macro): 0.9256
# ----------------------------------------
# Epoch 31: Test Accuracy: 0.9190
#   Class 0 Accuracy: 0.9269
#   Class 1 Accuracy: 0.9029
# Average Class Accuracy: 0.9149
# F1 Score (macro): 0.9095
# Precision (macro): 0.9049
# Recall (macro): 0.9149
# ----------------------------------------
# Epoch 32: Test Accuracy: 0.9081
#   Class 0 Accuracy: 0.8965
#   Class 1 Accuracy: 0.9315
# Average Class Accuracy: 0.9140
# F1 Score (macro): 0.8994
# Precision (macro): 0.8898
# Recall (macro): 0.9140
# ----------------------------------------
# Epoch 33: Test Accuracy: 0.9138
#   Class 0 Accuracy: 0.9329
#   Class 1 Accuracy: 0.8750
# Average Class Accuracy: 0.9039
# F1 Score (macro): 0.9028
# Precision (macro): 0.9017
# Recall (macro): 0.9039
# ----------------------------------------
# Epoch 34: Test Accuracy: 0.9170
#   Class 0 Accuracy: 0.9169
#   Class 1 Accuracy: 0.9172
# Average Class Accuracy: 0.9170
# F1 Score (macro): 0.9081
# Precision (macro): 0.9010
# Recall (macro): 0.9170
# ----------------------------------------
# Epoch 35: Test Accuracy: 0.9138
#   Class 0 Accuracy: 0.9236
#   Class 1 Accuracy: 0.8938
# Average Class Accuracy: 0.9087
# F1 Score (macro): 0.9037
# Precision (macro): 0.8993
# Recall (macro): 0.9087
# ----------------------------------------
# Epoch 36: Test Accuracy: 0.9175
#   Class 0 Accuracy: 0.9128
#   Class 1 Accuracy: 0.9270
# Average Class Accuracy: 0.9199
# F1 Score (macro): 0.9090
# Precision (macro): 0.9009
# Recall (macro): 0.9199
# ----------------------------------------
# Epoch 37: Test Accuracy: 0.9167
#   Class 0 Accuracy: 0.9165
#   Class 1 Accuracy: 0.9172
# Average Class Accuracy: 0.9169
# F1 Score (macro): 0.9078
# Precision (macro): 0.9007
# Recall (macro): 0.9169
# ----------------------------------------
# Epoch 38: Test Accuracy: 0.9041
#   Class 0 Accuracy: 0.9540
#   Class 1 Accuracy: 0.8027
# Average Class Accuracy: 0.8784
# F1 Score (macro): 0.8885
# Precision (macro): 0.9017
# Recall (macro): 0.8784
# ----------------------------------------
# Epoch 39: Test Accuracy: 0.9220
#   Class 0 Accuracy: 0.9759
#   Class 1 Accuracy: 0.8125
# Average Class Accuracy: 0.8942
# F1 Score (macro): 0.9083
# Precision (macro): 0.9284
# Recall (macro): 0.8942
# ----------------------------------------
# Epoch 40: Test Accuracy: 0.9257
#   Class 0 Accuracy: 0.9503
#   Class 1 Accuracy: 0.8758
# Average Class Accuracy: 0.9130
# F1 Score (macro): 0.9155
# Precision (macro): 0.9181
# Recall (macro): 0.9130
# ----------------------------------------
# Epoch 41: Test Accuracy: 0.9160
#   Class 0 Accuracy: 0.9462
#   Class 1 Accuracy: 0.8547
# Average Class Accuracy: 0.9004
# F1 Score (macro): 0.9041
# Precision (macro): 0.9082
# Recall (macro): 0.9004
# ----------------------------------------
# Epoch 42: Test Accuracy: 0.9185
#   Class 0 Accuracy: 0.9221
#   Class 1 Accuracy: 0.9111
# Average Class Accuracy: 0.9166
# F1 Score (macro): 0.9094
# Precision (macro): 0.9034
# Recall (macro): 0.9166
# ----------------------------------------
# Epoch 43: Test Accuracy: 0.9207
#   Class 0 Accuracy: 0.9618
#   Class 1 Accuracy: 0.8373
# Average Class Accuracy: 0.8996
# F1 Score (macro): 0.9083
# Precision (macro): 0.9192
# Recall (macro): 0.8996
# ----------------------------------------
# Epoch 44: Test Accuracy: 0.9090
#   Class 0 Accuracy: 0.9685
#   Class 1 Accuracy: 0.7884
# Average Class Accuracy: 0.8784
# F1 Score (macro): 0.8929
# Precision (macro): 0.9139
# Recall (macro): 0.8784
# ----------------------------------------
# Epoch 45: Test Accuracy: 0.9279
#   Class 0 Accuracy: 0.9588
#   Class 1 Accuracy: 0.8652
# Average Class Accuracy: 0.9120
# F1 Score (macro): 0.9174
# Precision (macro): 0.9236
# Recall (macro): 0.9120
# ----------------------------------------
# Epoch 46: Test Accuracy: 0.9222
#   Class 0 Accuracy: 0.9266
#   Class 1 Accuracy: 0.9134
# Average Class Accuracy: 0.9200
# F1 Score (macro): 0.9134
# Precision (macro): 0.9078
# Recall (macro): 0.9200
# ----------------------------------------
# Epoch 47: Test Accuracy: 0.9254
#   Class 0 Accuracy: 0.9514
#   Class 1 Accuracy: 0.8727
# Average Class Accuracy: 0.9121
# F1 Score (macro): 0.9151
# Precision (macro): 0.9183
# Recall (macro): 0.9121
# ----------------------------------------
# Epoch 48: Test Accuracy: 0.9302
#   Class 0 Accuracy: 0.9507
#   Class 1 Accuracy: 0.8886
# Average Class Accuracy: 0.9196
# F1 Score (macro): 0.9208
# Precision (macro): 0.9221
# Recall (macro): 0.9196
# ----------------------------------------
# Epoch 49: Test Accuracy: 0.9123
#   Class 0 Accuracy: 0.9091
#   Class 1 Accuracy: 0.9187
# Average Class Accuracy: 0.9139
# F1 Score (macro): 0.9032
# Precision (macro): 0.8953
# Recall (macro): 0.9139
# ----------------------------------------
# Epoch 50: Test Accuracy: 0.9217
#   Class 0 Accuracy: 0.9292
#   Class 1 Accuracy: 0.9066
# Average Class Accuracy: 0.9179
# F1 Score (macro): 0.9126
# Precision (macro): 0.9080
# Recall (macro): 0.9179
# ----------------------------------------
# Epoch 51: Test Accuracy: 0.9088
#   Class 0 Accuracy: 0.9125
#   Class 1 Accuracy: 0.9014
# Average Class Accuracy: 0.9069
# F1 Score (macro): 0.8988
# Precision (macro): 0.8924
# Recall (macro): 0.9069
# ----------------------------------------
# Epoch 52: Test Accuracy: 0.9153
#   Class 0 Accuracy: 0.9254
#   Class 1 Accuracy: 0.8946
# Average Class Accuracy: 0.9100
# F1 Score (macro): 0.9053
# Precision (macro): 0.9011
# Recall (macro): 0.9100
# ----------------------------------------
# Epoch 53: Test Accuracy: 0.9341
#   Class 0 Accuracy: 0.9551
#   Class 1 Accuracy: 0.8916
# Average Class Accuracy: 0.9233
# F1 Score (macro): 0.9252
# Precision (macro): 0.9272
# Recall (macro): 0.9233
# ----------------------------------------
# Epoch 54: Test Accuracy: 0.9252
#   Class 0 Accuracy: 0.9414
#   Class 1 Accuracy: 0.8923
# Average Class Accuracy: 0.9169
# F1 Score (macro): 0.9157
# Precision (macro): 0.9145
# Recall (macro): 0.9169
# ----------------------------------------
# Epoch 55: Test Accuracy: 0.9252
#   Class 0 Accuracy: 0.9677
#   Class 1 Accuracy: 0.8389
# Average Class Accuracy: 0.9033
# F1 Score (macro): 0.9132
# Precision (macro): 0.9259
# Recall (macro): 0.9033
# ----------------------------------------
# Epoch 56: Test Accuracy: 0.9240
#   Class 0 Accuracy: 0.9395
#   Class 1 Accuracy: 0.8923
# Average Class Accuracy: 0.9159
# F1 Score (macro): 0.9143
# Precision (macro): 0.9128
# Recall (macro): 0.9159
# ----------------------------------------
# Epoch 57: Test Accuracy: 0.9167
#   Class 0 Accuracy: 0.9251
#   Class 1 Accuracy: 0.8998
# Average Class Accuracy: 0.9125
# F1 Score (macro): 0.9071
# Precision (macro): 0.9024
# Recall (macro): 0.9125
# ----------------------------------------
# Epoch 58: Test Accuracy: 0.9095
#   Class 0 Accuracy: 0.9881
#   Class 1 Accuracy: 0.7500
# Average Class Accuracy: 0.8691
# F1 Score (macro): 0.8908
# Precision (macro): 0.9290
# Recall (macro): 0.8691
# ----------------------------------------
# Epoch 59: Test Accuracy: 0.9105
#   Class 0 Accuracy: 0.9088
#   Class 1 Accuracy: 0.9142
# Average Class Accuracy: 0.9115
# F1 Score (macro): 0.9012
# Precision (macro): 0.8935
# Recall (macro): 0.9115
# ----------------------------------------
# Epoch 60: Test Accuracy: 0.9334
#   Class 0 Accuracy: 0.9403
#   Class 1 Accuracy: 0.9194
# Average Class Accuracy: 0.9299
# F1 Score (macro): 0.9255
# Precision (macro): 0.9215
# Recall (macro): 0.9299
# ----------------------------------------

# %%
# Best choice: Epoch 47
