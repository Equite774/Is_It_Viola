# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from MixtureMasking import MixtureMasking

# %%
class ViolinViolaDataset(Dataset):
    def __init__(self, root_dir, label_map = None, transform=None):
        self.root_dir = root_dir
        self.files = [f for f in os.listdir(root_dir) if f.endswith('.npy')]
        self.label_map = label_map or {'violin': 0, 'viola': 1}
        self.transform = transform

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        filename = self.files[idx]
        filepath = os.path.join(self.root_dir, filename)
        mel = np.load(filepath)
        spec = torch.from_numpy(mel)
        spec = spec.unsqueeze(0)  # Add channel dimension
        label = self.label_map[filename.split('_')[1]] if self.label_map else None
        if self.transform:
            spec = self.transform(spec)
        return spec, label

# %%
transform = transforms.Compose([
    transforms.Resize((128, 517)),  # Resize to a fixed size
    transforms.Normalize([0.5], [0.5])  # Normalize the image
])

# %%
g_train = torch.Generator()
g_train.manual_seed(17)
train_dataset = ViolinViolaDataset('train/', transform=transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

g_testval = torch.Generator().manual_seed(17)
testval_dataset = ViolinViolaDataset('test/', transform=transform)
val_size = int(0.5 * len(testval_dataset))
test_size = len(testval_dataset) - val_size
val_subset, test_subset = random_split(testval_dataset, [val_size, test_size], generator=g_testval)
val_loader = DataLoader(val_subset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_subset, batch_size=32, shuffle=False)

# %%
for x, y in train_loader:
    print(x.shape)
    print(y.shape)
    break
# Out:
# torch.Size([32, 1, 128, 517])
# torch.Size([32])

# %%
class ViolinViolaCNN(nn.Module):
    def __init__(self):
        super(ViolinViolaCNN, self).__init__()

        self.mixturemasking1 = MixtureMasking(freq_param=8, time_param=35, activate_prob=0.6)
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=40, stride=(2, 1), kernel_size=(5, 1))   # output: (40, 62, 517)
        self.mixturemasking2 = MixtureMasking(freq_param=4, time_param=35, activate_prob=0.6)
        self.conv2 = nn.Conv2d(in_channels=40, out_channels=32, kernel_size=(3, 2))  # output: (32, 60, 516)
        self.mixturemasking3 = MixtureMasking(freq_param=4, time_param=35, activate_prob=0.6)
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=16, kernel_size=1)  # output: (16, 60, 516)

        self.pool = nn.AdaptiveAvgPool2d((16, 16))  # reduce to fixed-size for Dense

        self.fc1 = nn.Linear(16 * 16 * 16, 64)
        self.fc2 = nn.Linear(64, 16)
        self.fc3 = nn.Linear(16, 12)
        self.out = nn.Linear(12, 2)  # binary classification: violin vs viola

    def forward(self, x, labels):
        x = self.mixturemasking1(x, labels)
        x = F.relu(self.conv1(x))  # -> (40, 62, 517)
        x = self.mixturemasking2(x, labels)
        x = F.relu(self.conv2(x))  # -> (32, 60, 516)
        x = self.mixturemasking3(x, labels)
        x = F.relu(self.conv3(x))  # -> (16, 60, 516)
        x = self.pool(x)           # -> (16, 16, 16)
        x = x.view(x.size(0), -1)  # flatten
        x = F.relu(self.fc1(x))    # -> (64)
        x = F.relu(self.fc2(x))    # -> (16)
        x = F.relu(self.fc3(x))    # -> (12)
        x = self.out(x)            # -> (2)
        return x

# %%
class ViolinViolaCrossEntropyLoss(nn.Module):
    def __init__(self):
        super(ViolinViolaCrossEntropyLoss, self).__init__()
        self.register_buffer("class_weights", torch.tensor([1.0, 1.2]))

    def forward(self, outputs, labels):
        if self.class_weights is not None:
            class_weights = self.class_weights.to(outputs.device)
            return F.cross_entropy(outputs, labels, weight=class_weights)
        return F.cross_entropy(outputs, labels)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
model = ViolinViolaCNN()
criterion = ViolinViolaCrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# Out:
# Using device: cuda

# %%
from collections import defaultdict

def train(model, train_loader, val_loader, criterion, optimizer, device, num_epochs=10):
    max_avg_acc = {}

    model.to(device)

    # Use DataParallel for multiple GPUs
    if torch.cuda.device_count() > 1:
        print(f"Using {torch.cuda.device_count()} GPUs with DataParallel")
        model.to(device)  # Move model to CUDA *before* DataParallel
        model = torch.nn.DataParallel(model)
    else:
        model.to(device)


    history = {
        "train_loss": [], "val_loss": [],
        "train_acc": [], "val_acc": [],
        "train_class_acc": [], "val_class_acc": [],
        "train_class_loss": [], "val_class_loss": [],
        "val_roc_y_true": [], "val_roc_y_score": [],
    }

    for epoch in range(num_epochs):
        model.train()
        total_loss, total_correct, total_samples = 0, 0, 0
        class_loss = defaultdict(float)
        class_correct = defaultdict(int)
        class_total = defaultdict(int)

        for X, y in train_loader:
            X, y = X.to(device), y.to(device)

            optimizer.zero_grad()
            logits = model(X, y)
            loss = criterion(logits, y)
            loss.backward()
            optimizer.step()

            preds = logits.argmax(dim=1)
            total_loss += loss.item() * y.size(0)
            total_correct += (preds == y).sum().item()
            total_samples += y.size(0)

            for cls in [0, 1]:  # violin, viola
                idx = (y == cls)
                if idx.sum().item() > 0:
                    cls_loss = criterion(logits[idx], y[idx])
                    class_loss[cls] += cls_loss.item() * idx.sum().item()
                    class_correct[cls] += (preds[idx] == y[idx]).sum().item()
                    class_total[cls] += idx.sum().item()

        train_loss = total_loss / total_samples
        train_acc = total_correct / total_samples
        train_class_acc = [class_correct[c] / class_total[c] for c in [0, 1]]
        train_class_loss = [class_loss[c] / class_total[c] for c in [0, 1]]

        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["train_class_acc"].append(train_class_acc)
        history["train_class_loss"].append(train_class_loss)

        # --- Validation ---
        model.eval()
        total_loss, total_correct, total_samples = 0, 0, 0
        class_loss = defaultdict(float)
        class_correct = defaultdict(int)
        class_total = defaultdict(int)
        val_y_true, val_y_score = [], []

        with torch.no_grad():
            for X, y in val_loader:
                X, y = X.to(device), y.to(device)
                logits = model(X, None)
                loss = criterion(logits, y)

                preds = logits.argmax(dim=1)
                probs = torch.softmax(logits, dim=1)[:, 1]

                total_loss += loss.item() * y.size(0)
                total_correct += (preds == y).sum().item()
                total_samples += y.size(0)

                val_y_true.extend(y.cpu().numpy())
                val_y_score.extend(probs.cpu().numpy())

                for cls in [0, 1]:
                    idx = (y == cls)
                    if idx.sum().item() > 0:
                        cls_loss = criterion(logits[idx], y[idx])
                        class_loss[cls] += cls_loss.item() * idx.sum().item()
                        class_correct[cls] += (preds[idx] == y[idx]).sum().item()
                        class_total[cls] += idx.sum().item()

        val_loss = total_loss / total_samples
        val_acc = total_correct / total_samples
        val_class_acc = [class_correct[c] / class_total[c] for c in [0, 1]]
        val_class_loss = [class_loss[c] / class_total[c] for c in [0, 1]]

        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)
        history["val_class_acc"].append(val_class_acc)
        history["val_class_loss"].append(val_class_loss)
        history["val_roc_y_true"] = val_y_true
        history["val_roc_y_score"] = val_y_score

        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"  Train Loss: {train_loss:.4f} | Acc: {train_acc:.4f} | Violin Acc: {train_class_acc[0]:.4f} | Viola Acc: {train_class_acc[1]:.4f}")
        print(f"  Val   Loss: {val_loss:.4f} | Acc: {val_acc:.4f} | Violin Acc: {val_class_acc[0]:.4f} | Viola Acc: {val_class_acc[1]:.4f}")

        # Save model every epoch
        torch.save(model.state_dict(), f"violin_viola_cnn_mixturemasking_epoch_{epoch+1}.pth")
        print(f"Model saved as violin_viola_cnn_mixturemasking_epoch_{epoch+1}.pth")
        # Save maximum average accuracy between violin and viola
        max_avg_acc[(epoch + 1)] = (train_acc + val_acc) / 2

    return history, max_avg_acc

def plot_history(history):
    epochs = range(1, len(history["train_loss"]) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, history["train_loss"], label="Train Loss")
    plt.plot(epochs, history["val_loss"], label="Val Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.title("Loss over Epochs")

    plt.subplot(1, 2, 2)
    plt.plot(epochs, history["train_acc"], label="Train Acc")
    plt.plot(epochs, history["val_acc"], label="Val Acc")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.title("Accuracy over Epochs")

    plt.tight_layout()
    plt.show()

def plot_roc(y_true, y_score):
    fpr, tpr, _ = roc_curve(y_true, y_score)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.2f})")
    plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve (Violin vs Viola)")
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()

# %%
history, max_avg_acc = train(model, train_loader, val_loader, criterion, optimizer, device='cuda', num_epochs=50)

plot_history(history)
plot_roc(history["val_roc_y_true"], history["val_roc_y_score"])

# Restore the best model based on maximum average accuracy
best_epoch = max(max_avg_acc, key=max_avg_acc.get)
state_dict = torch.load(f"violin_viola_cnn_mixturemasking_epoch_{best_epoch}.pth")
# Remove 'module.' prefix from all keys
new_state_dict = {k.replace("module.", ""): v for k, v in state_dict.items()}
model.load_state_dict(new_state_dict)
print(f"Best model restored from epoch {best_epoch} with max average accuracy {max_avg_acc[best_epoch]:.4f}")
# Out:
# Using 2 GPUs with DataParallel
# Epoch 1/50
#   Train Loss: 0.3744 | Acc: 0.8157 | Violin Acc: 0.8555 | Viola Acc: 0.7540
#   Val   Loss: 0.2554 | Acc: 0.8867 | Violin Acc: 0.8872 | Viola Acc: 0.8854
# Model saved as violin_viola_cnn_mixturemasking_epoch_1.pth
# Epoch 2/50
#   Train Loss: 0.1530 | Acc: 0.9387 | Violin Acc: 0.9413 | Viola Acc: 0.9347
#   Val   Loss: 0.1990 | Acc: 0.9120 | Violin Acc: 0.9022 | Viola Acc: 0.9327
# Model saved as violin_viola_cnn_mixturemasking_epoch_2.pth
# Epoch 3/50
#   Train Loss: 0.1209 | Acc: 0.9540 | Violin Acc: 0.9588 | Viola Acc: 0.9467
#   Val   Loss: 0.2521 | Acc: 0.9140 | Violin Acc: 0.9780 | Viola Acc: 0.7786
# Model saved as violin_viola_cnn_mixturemasking_epoch_3.pth
# Epoch 4/50
#   Train Loss: 0.1023 | Acc: 0.9600 | Violin Acc: 0.9650 | Viola Acc: 0.9523
#   Val   Loss: 0.2866 | Acc: 0.9008 | Violin Acc: 0.9799 | Viola Acc: 0.7337
# Model saved as violin_viola_cnn_mixturemasking_epoch_4.pth
# Epoch 5/50
#   Train Loss: 0.0874 | Acc: 0.9658 | Violin Acc: 0.9707 | Viola Acc: 0.9582
#   Val   Loss: 0.2000 | Acc: 0.9239 | Violin Acc: 0.9260 | Viola Acc: 0.9195
# Model saved as violin_viola_cnn_mixturemasking_epoch_5.pth
# Epoch 6/50
#   Train Loss: 0.0833 | Acc: 0.9663 | Violin Acc: 0.9696 | Viola Acc: 0.9612
#   Val   Loss: 0.1979 | Acc: 0.9242 | Violin Acc: 0.9432 | Viola Acc: 0.8839
# Model saved as violin_viola_cnn_mixturemasking_epoch_6.pth
# Epoch 7/50
#   Train Loss: 0.0698 | Acc: 0.9745 | Violin Acc: 0.9770 | Viola Acc: 0.9707
#   Val   Loss: 0.2227 | Acc: 0.9180 | Violin Acc: 0.9143 | Viola Acc: 0.9257
# Model saved as violin_viola_cnn_mixturemasking_epoch_48.pth
# Epoch 49/50
#   Train Loss: 0.0123 | Acc: 0.9962 | Violin Acc: 0.9963 | Viola Acc: 0.9960
#   Val   Loss: 0.2487 | Acc: 0.9525 | Violin Acc: 0.9788 | Viola Acc: 0.8971
# Model saved as violin_viola_cnn_mixturemasking_epoch_49.pth
# Epoch 50/50
#   Train Loss: 0.0124 | Acc: 0.9959 | Violin Acc: 0.9960 | Viola Acc: 0.9956
#   Val   Loss: 0.4429 | Acc: 0.9316 | Violin Acc: 0.9927 | Viola Acc: 0.8026
# Model saved as violin_viola_cnn_mixturemasking_epoch_50.pth
# Best model restored from epoch 47 with max average accuracy 0.9761

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

for epoch in range(1, 51):
    state_dict = torch.load(f"violin_viola_cnn_mixturemasking_epoch_{epoch}.pth")
    new_state_dict = {k.replace("module.", ""): v for k, v in state_dict.items()}
    model.load_state_dict(new_state_dict)
    model.to('cpu')
    model.eval()
    total_correct, total_samples = 0, 0
    class_correct = defaultdict(int)
    class_total = defaultdict(int)

    all_preds = []
    all_labels = []

    with torch.no_grad():
        for X, y in test_loader:
            X, y = X.to('cpu'), y.to('cpu')
            logits = model(X, None)
            preds = logits.argmax(dim=1)
            total_correct += (preds == y).sum().item()
            total_samples += y.size(0)

            # For accuracy
            for i in range(y.size(0)):
                class_total[y[i].item()] += 1
                class_correct[y[i].item()] += (preds[i] == y[i]).item()

            # For F1/Precision/Recall
            all_preds.extend(preds.tolist())
            all_labels.extend(y.tolist())

    test_acc = total_correct / total_samples
    print(f"Epoch {epoch}: Test Accuracy: {test_acc:.4f}")

    for cls in [0, 1]:
        if class_total[cls] > 0:
            class_acc = class_correct[cls] / class_total[cls]
            print(f"  Class {cls} Accuracy: {class_acc:.4f}")

    avg_class_acc = sum(class_correct[c] / class_total[c] for c in [0, 1]) / 2
    print(f"Average Class Accuracy: {avg_class_acc:.4f}")

    # F1, Precision, Recall (macro = average across classes)
    f1 = f1_score(all_labels, all_preds, average='macro')
    precision = precision_score(all_labels, all_preds, average='macro')
    recall = recall_score(all_labels, all_preds, average='macro')
    print(f"F1 Score (macro): {f1:.4f}")
    print(f"Precision (macro): {precision:.4f}")
    print(f"Recall (macro): {recall:.4f}")
    print("-" * 40)
# Out:
# Epoch 1: Test Accuracy: 0.8775
#   Class 0 Accuracy: 0.8717
#   Class 1 Accuracy: 0.8893
# Average Class Accuracy: 0.8805
# F1 Score (macro): 0.8662
# Precision (macro): 0.8573
# Recall (macro): 0.8805
# ----------------------------------------
# Epoch 2: Test Accuracy: 0.9108
#   Class 0 Accuracy: 0.8924
#   Class 1 Accuracy: 0.9480
# Average Class Accuracy: 0.9202
# F1 Score (macro): 0.9029
# Precision (macro): 0.8925
# Recall (macro): 0.9202
# ----------------------------------------
# Epoch 3: Test Accuracy: 0.9113
#   Class 0 Accuracy: 0.9714
#   Class 1 Accuracy: 0.7892
# Average Class Accuracy: 0.8803
# F1 Score (macro): 0.8953
# Precision (macro): 0.9175
# Recall (macro): 0.8803
# ----------------------------------------
# Epoch 4: Test Accuracy: 0.8976
#   Class 0 Accuracy: 0.9729
#   Class 1 Accuracy: 0.7447
# Average Class Accuracy: 0.8588
# F1 Score (macro): 0.8774
# Precision (macro): 0.9084
# Recall (macro): 0.8588
# ----------------------------------------
# Epoch 5: Test Accuracy: 0.9257
#   Class 0 Accuracy: 0.9206
#   Class 1 Accuracy: 0.9360
# Average Class Accuracy: 0.9283
# F1 Score (macro): 0.9179
# Precision (macro): 0.9100
# Recall (macro): 0.9283
# ----------------------------------------
# Epoch 6: Test Accuracy: 0.9190
#   Class 0 Accuracy: 0.9336
#   Class 1 Accuracy: 0.8893
# Average Class Accuracy: 0.9115
# F1 Score (macro): 0.9089
# Precision (macro): 0.9066
# Recall (macro): 0.9115
# ----------------------------------------
# Epoch 7: Test Accuracy: 0.9202
#   Class 0 Accuracy: 0.9147
#   Class 1 Accuracy: 0.9315
# Average Class Accuracy: 0.9231
# F1 Score (macro): 0.9120
# Precision (macro): 0.9038
# Recall (macro): 0.9231
# ----------------------------------------
# Epoch 8: Test Accuracy: 0.9327
#   Class 0 Accuracy: 0.9410
#   Class 1 Accuracy: 0.9157
# Average Class Accuracy: 0.9283
# F1 Score (macro): 0.9245
# Precision (macro): 0.9210
# Recall (macro): 0.9283
# ----------------------------------------
# Epoch 9: Test Accuracy: 0.9083
#   Class 0 Accuracy: 0.9203
#   Class 1 Accuracy: 0.8840
# Average Class Accuracy: 0.9021
# F1 Score (macro): 0.8975
# Precision (macro): 0.8934
# Recall (macro): 0.9021
# ----------------------------------------
# Epoch 10: Test Accuracy: 0.9252
#   Class 0 Accuracy: 0.9136
#   Class 1 Accuracy: 0.9488
# Average Class Accuracy: 0.9312
# F1 Score (macro): 0.9179
# Precision (macro): 0.9085
# Recall (macro): 0.9312
# ----------------------------------------
# Epoch 11: Test Accuracy: 0.9292
#   Class 0 Accuracy: 0.9607
#   Class 1 Accuracy: 0.8652
# Average Class Accuracy: 0.9129
# F1 Score (macro): 0.9188
# Precision (macro): 0.9254
# Recall (macro): 0.9129
# ----------------------------------------
# Epoch 12: Test Accuracy: 0.9225
#   Class 0 Accuracy: 0.9547
#   Class 1 Accuracy: 0.8569
# Average Class Accuracy: 0.9058
# F1 Score (macro): 0.9112
# Precision (macro): 0.9172
# Recall (macro): 0.9058
# ----------------------------------------
# Epoch 13: Test Accuracy: 0.9366
#   Class 0 Accuracy: 0.9785
#   Class 1 Accuracy: 0.8517
# Average Class Accuracy: 0.9151
# F1 Score (macro): 0.9263
# Precision (macro): 0.9409
# Recall (macro): 0.9151
# ----------------------------------------
# Epoch 14: Test Accuracy: 0.9351
#   Class 0 Accuracy: 0.9566
#   Class 1 Accuracy: 0.8916
# Average Class Accuracy: 0.9241
# F1 Score (macro): 0.9263
# Precision (macro): 0.9286
# Recall (macro): 0.9241
# ----------------------------------------
# Epoch 15: Test Accuracy: 0.9339
#   Class 0 Accuracy: 0.9377
#   Class 1 Accuracy: 0.9262
# Average Class Accuracy: 0.9319
# F1 Score (macro): 0.9262
# Precision (macro): 0.9213
# Recall (macro): 0.9319
# ----------------------------------------
# Epoch 16: Test Accuracy: 0.9381
#   Class 0 Accuracy: 0.9525
#   Class 1 Accuracy: 0.9089
# Average Class Accuracy: 0.9307
# F1 Score (macro): 0.9301
# Precision (macro): 0.9296
# Recall (macro): 0.9307
# ----------------------------------------
# Epoch 17: Test Accuracy: 0.9354
#   Class 0 Accuracy: 0.9781
#   Class 1 Accuracy: 0.8486
# Average Class Accuracy: 0.9134
# F1 Score (macro): 0.9248
# Precision (macro): 0.9397
# Recall (macro): 0.9134
# ----------------------------------------
# Epoch 18: Test Accuracy: 0.9349
#   Class 0 Accuracy: 0.9228
#   Class 1 Accuracy: 0.9593
# Average Class Accuracy: 0.9411
# F1 Score (macro): 0.9284
# Precision (macro): 0.9192
# Recall (macro): 0.9411
# ----------------------------------------
# Epoch 19: Test Accuracy: 0.9349
#   Class 0 Accuracy: 0.9180
#   Class 1 Accuracy: 0.9691
# Average Class Accuracy: 0.9436
# F1 Score (macro): 0.9287
# Precision (macro): 0.9186
# Recall (macro): 0.9436
# ----------------------------------------
# Epoch 20: Test Accuracy: 0.9428
#   Class 0 Accuracy: 0.9496
#   Class 1 Accuracy: 0.9292
# Average Class Accuracy: 0.9394
# F1 Score (macro): 0.9359
# Precision (macro): 0.9327
# Recall (macro): 0.9394
# ----------------------------------------
# Epoch 21: Test Accuracy: 0.8981
#   Class 0 Accuracy: 0.8587
#   Class 1 Accuracy: 0.9782
# Average Class Accuracy: 0.9184
# F1 Score (macro): 0.8912
# Precision (macro): 0.8804
# Recall (macro): 0.9184
# ----------------------------------------
# Epoch 22: Test Accuracy: 0.9426
#   Class 0 Accuracy: 0.9618
#   Class 1 Accuracy: 0.9036
# Average Class Accuracy: 0.9327
# F1 Score (macro): 0.9348
# Precision (macro): 0.9370
# Recall (macro): 0.9327
# ----------------------------------------
# Epoch 23: Test Accuracy: 0.9384
#   Class 0 Accuracy: 0.9640
#   Class 1 Accuracy: 0.8863
# Average Class Accuracy: 0.9252
# F1 Score (macro): 0.9296
# Precision (macro): 0.9345
# Recall (macro): 0.9252
# ----------------------------------------
# Epoch 24: Test Accuracy: 0.9344
#   Class 0 Accuracy: 0.9414
#   Class 1 Accuracy: 0.9202
# Average Class Accuracy: 0.9308
# F1 Score (macro): 0.9265
# Precision (macro): 0.9227
# Recall (macro): 0.9308
# ----------------------------------------
# Epoch 25: Test Accuracy: 0.9468
#   Class 0 Accuracy: 0.9510
#   Class 1 Accuracy: 0.9383
# Average Class Accuracy: 0.9446
# F1 Score (macro): 0.9404
# Precision (macro): 0.9366
# Recall (macro): 0.9446
# ----------------------------------------
# Epoch 26: Test Accuracy: 0.9076
#   Class 0 Accuracy: 0.9915
#   Class 1 Accuracy: 0.7372
# Average Class Accuracy: 0.8643
# F1 Score (macro): 0.8876
# Precision (macro): 0.9308
# Recall (macro): 0.8643
# ----------------------------------------
# Epoch 27: Test Accuracy: 0.9376
#   Class 0 Accuracy: 0.9670
#   Class 1 Accuracy: 0.8780
# Average Class Accuracy: 0.9225
# F1 Score (macro): 0.9284
# Precision (macro): 0.9353
# Recall (macro): 0.9225
# ----------------------------------------
# Epoch 28: Test Accuracy: 0.9095
#   Class 0 Accuracy: 0.9707
#   Class 1 Accuracy: 0.7854
# Average Class Accuracy: 0.8780
# F1 Score (macro): 0.8932
# Precision (macro): 0.9157
# Recall (macro): 0.8780
# ----------------------------------------
# Epoch 29: Test Accuracy: 0.9399
#   Class 0 Accuracy: 0.9381
#   Class 1 Accuracy: 0.9435
# Average Class Accuracy: 0.9408
# F1 Score (macro): 0.9331
# Precision (macro): 0.9268
# Recall (macro): 0.9408
# ----------------------------------------
# Epoch 30: Test Accuracy: 0.9349
#   Class 0 Accuracy: 0.9503
#   Class 1 Accuracy: 0.9036
# Average Class Accuracy: 0.9270
# F1 Score (macro): 0.9265
# Precision (macro): 0.9260
# Recall (macro): 0.9270
# ----------------------------------------
# Epoch 31: Test Accuracy: 0.9423
#   Class 0 Accuracy: 0.9596
#   Class 1 Accuracy: 0.9074
# Average Class Accuracy: 0.9335
# F1 Score (macro): 0.9346
# Precision (macro): 0.9358
# Recall (macro): 0.9335
# ----------------------------------------
# Epoch 32: Test Accuracy: 0.9431
#   Class 0 Accuracy: 0.9536
#   Class 1 Accuracy: 0.9217
# Average Class Accuracy: 0.9377
# F1 Score (macro): 0.9359
# Precision (macro): 0.9342
# Recall (macro): 0.9377
# ----------------------------------------
# Epoch 33: Test Accuracy: 0.9441
#   Class 0 Accuracy: 0.9711
#   Class 1 Accuracy: 0.8893
# Average Class Accuracy: 0.9302
# F1 Score (macro): 0.9359
# Precision (macro): 0.9424
# Recall (macro): 0.9302
# ----------------------------------------
# Epoch 34: Test Accuracy: 0.9436
#   Class 0 Accuracy: 0.9392
#   Class 1 Accuracy: 0.9526
# Average Class Accuracy: 0.9459
# F1 Score (macro): 0.9374
# Precision (macro): 0.9305
# Recall (macro): 0.9459
# ----------------------------------------
# Epoch 35: Test Accuracy: 0.9414
#   Class 0 Accuracy: 0.9369
#   Class 1 Accuracy: 0.9503
# Average Class Accuracy: 0.9436
# F1 Score (macro): 0.9349
# Precision (macro): 0.9279
# Recall (macro): 0.9436
# ----------------------------------------
# Epoch 36: Test Accuracy: 0.9411
#   Class 0 Accuracy: 0.9366
#   Class 1 Accuracy: 0.9503
# Average Class Accuracy: 0.9434
# F1 Score (macro): 0.9347
# Precision (macro): 0.9276
# Recall (macro): 0.9434
# ----------------------------------------
# Epoch 37: Test Accuracy: 0.9379
#   Class 0 Accuracy: 0.9677
#   Class 1 Accuracy: 0.8773
# Average Class Accuracy: 0.9225
# F1 Score (macro): 0.9287
# Precision (macro): 0.9359
# Recall (macro): 0.9225
# ----------------------------------------
# Epoch 38: Test Accuracy: 0.9451
#   Class 0 Accuracy: 0.9611
#   Class 1 Accuracy: 0.9127
# Average Class Accuracy: 0.9369
# F1 Score (macro): 0.9378
# Precision (macro): 0.9387
# Recall (macro): 0.9369
# ----------------------------------------
# Epoch 39: Test Accuracy: 0.9369
#   Class 0 Accuracy: 0.9403
#   Class 1 Accuracy: 0.9300
# Average Class Accuracy: 0.9351
# F1 Score (macro): 0.9295
# Precision (macro): 0.9246
# Recall (macro): 0.9351
# ----------------------------------------
# Epoch 40: Test Accuracy: 0.9322
#   Class 0 Accuracy: 0.9822
#   Class 1 Accuracy: 0.8306
# Average Class Accuracy: 0.9064
# F1 Score (macro): 0.9204
# Precision (macro): 0.9400
# Recall (macro): 0.9064
# ----------------------------------------
# Epoch 41: Test Accuracy: 0.9384
#   Class 0 Accuracy: 0.9381
#   Class 1 Accuracy: 0.9390
# Average Class Accuracy: 0.9385
# F1 Score (macro): 0.9314
# Precision (macro): 0.9254
# Recall (macro): 0.9385
# ----------------------------------------
# Epoch 42: Test Accuracy: 0.9284
#   Class 0 Accuracy: 0.9203
#   Class 1 Accuracy: 0.9450
# Average Class Accuracy: 0.9326
# F1 Score (macro): 0.9211
# Precision (macro): 0.9126
# Recall (macro): 0.9326
# ----------------------------------------
# Epoch 43: Test Accuracy: 0.9205
#   Class 0 Accuracy: 0.9028
#   Class 1 Accuracy: 0.9563
# Average Class Accuracy: 0.9296
# F1 Score (macro): 0.9132
# Precision (macro): 0.9029
# Recall (macro): 0.9296
# ----------------------------------------
# Epoch 44: Test Accuracy: 0.9441
#   Class 0 Accuracy: 0.9514
#   Class 1 Accuracy: 0.9292
# Average Class Accuracy: 0.9403
# F1 Score (macro): 0.9372
# Precision (macro): 0.9343
# Recall (macro): 0.9403
# ----------------------------------------
# Epoch 45: Test Accuracy: 0.9329
#   Class 0 Accuracy: 0.9781
#   Class 1 Accuracy: 0.8411
# Average Class Accuracy: 0.9096
# F1 Score (macro): 0.9217
# Precision (macro): 0.9379
# Recall (macro): 0.9096
# ----------------------------------------
# Epoch 46: Test Accuracy: 0.9411
#   Class 0 Accuracy: 0.9666
#   Class 1 Accuracy: 0.8893
# Average Class Accuracy: 0.9280
# F1 Score (macro): 0.9327
# Precision (macro): 0.9379
# Recall (macro): 0.9280
# ----------------------------------------
# Epoch 47: Test Accuracy: 0.9483
#   Class 0 Accuracy: 0.9492
#   Class 1 Accuracy: 0.9465
# Average Class Accuracy: 0.9479
# F1 Score (macro): 0.9423
# Precision (macro): 0.9374
# Recall (macro): 0.9479
# ----------------------------------------
# Epoch 48: Test Accuracy: 0.9438
#   Class 0 Accuracy: 0.9677
#   Class 1 Accuracy: 0.8953
# Average Class Accuracy: 0.9315
# F1 Score (macro): 0.9358
# Precision (macro): 0.9406
# Recall (macro): 0.9315
# ----------------------------------------
# Epoch 49: Test Accuracy: 0.9508
#   Class 0 Accuracy: 0.9785
#   Class 1 Accuracy: 0.8946
# Average Class Accuracy: 0.9365
# F1 Score (macro): 0.9435
# Precision (macro): 0.9515
# Recall (macro): 0.9365
# ----------------------------------------
# Epoch 50: Test Accuracy: 0.9185
#   Class 0 Accuracy: 0.9855
#   Class 1 Accuracy: 0.7824
# Average Class Accuracy: 0.8840
# F1 Score (macro): 0.9028
# Precision (macro): 0.9329
# Recall (macro): 0.8840
# ----------------------------------------

# %%
# Best choice: Epoch 47
