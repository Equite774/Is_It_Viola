# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader, random_split, default_collate
from torchvision import transforms
from torchvision.transforms.v2 import CutMix
from snorkel.classification import cross_entropy_with_probs
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# %%
class ViolinViolaDataset(Dataset):
    def __init__(self, root_dir, label_map = None, transform=None, ):
        self.root_dir = root_dir
        self.files = [f for f in os.listdir(root_dir) if f.endswith('.npy')]
        self.label_map = label_map or {'violin': 0, 'viola': 1}
        self.transform = transform

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        filename = self.files[idx]
        filepath = os.path.join(self.root_dir, filename)
        mel = np.load(filepath)
        spec = torch.from_numpy(mel)
        spec = spec.unsqueeze(0)  # Add channel dimension
        label = self.label_map[filename.split('_')[1]] if self.label_map else None
        if self.transform:
            spec = self.transform(spec)
        return spec, label

# %%
transform = transforms.Compose([
    transforms.Resize((128, 517)),  # Resize to a fixed size
    transforms.Normalize([0.5], [0.5])  # Normalize the image
])
cutmix = CutMix(num_classes=2, alpha=0.2)
def cutmix_fn(batch):
    return cutmix(*default_collate(batch))
def one_hot_fn(batch, num_classes=2):
    images, labels = default_collate(batch)
    labels = F.one_hot(labels, num_classes=num_classes).float()
    return images, labels

# %%
g_train = torch.Generator()
g_train.manual_seed(17)
train_dataset = ViolinViolaDataset('train/', transform=transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, collate_fn=cutmix_fn)

g_testval = torch.Generator().manual_seed(17)
testval_dataset = ViolinViolaDataset('test/', transform=transform)
val_size = int(0.5 * len(testval_dataset))
test_size = len(testval_dataset) - val_size
val_subset, test_subset = random_split(testval_dataset, [val_size, test_size], generator=g_testval)
val_loader = DataLoader(val_subset, batch_size=32, shuffle=False, collate_fn=one_hot_fn)
test_loader = DataLoader(test_subset, batch_size=32, shuffle=False, collate_fn=one_hot_fn)

# %%
for images, labels in train_loader:
    print(f"After CutMix: {images.shape = }, {labels.shape = }")
    print(labels[31])
    break
for images, labels in val_loader:
    print(f"No CutMix: {images.shape = }, {labels.shape = }")
    print(labels[31])
    break
for images, labels in test_loader:
    print(f"No CutMix: {images.shape = }, {labels.shape = }")
    print(labels[31])
    break
# Out:
# After CutMix: images.shape = torch.Size([32, 1, 128, 517]), labels.shape = torch.Size([32, 2])
# tensor([0.8164, 0.1836])
# No CutMix: images.shape = torch.Size([32, 1, 128, 517]), labels.shape = torch.Size([32, 2])
# tensor([1., 0.])
# No CutMix: images.shape = torch.Size([32, 1, 128, 517]), labels.shape = torch.Size([32, 2])
# tensor([1., 0.])

# %%
class ViolinViolaCNN(nn.Module):
    def __init__(self):
        super(ViolinViolaCNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=1, out_channels=40, stride=(2, 1), kernel_size=(5, 1))   # output: (40, 62, 517)
        self.dropout1 = nn.Dropout2d(p=0.35)
        self.conv2 = nn.Conv2d(in_channels=40, out_channels=32, kernel_size=(3, 2))  # output: (32, 60, 516)
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=16, kernel_size=1)  # output: (16, 60, 516)

        self.pool = nn.AdaptiveAvgPool2d((16, 16))  # reduce to fixed-size for Dense

        self.fc1 = nn.Linear(16 * 16 * 16, 64)
        self.fc2 = nn.Linear(64, 16)
        self.fc3 = nn.Linear(16, 12)
        self.out = nn.Linear(12, 2)  # binary classification: violin vs viola

    def forward(self, x):
        x = F.relu(self.conv1(x))  # -> (40, 62, 517)
        x = self.dropout1(x)
        x = F.relu(self.conv2(x))  # -> (32, 60, 516)
        x = F.relu(self.conv3(x))  # -> (16, 60, 516)
        x = self.pool(x)           # -> (16, 16, 16)
        x = x.view(x.size(0), -1)  # flatten
        x = F.relu(self.fc1(x))    # -> (64)
        x = F.relu(self.fc2(x))    # -> (16)
        x = F.relu(self.fc3(x))    # -> (12)
        x = self.out(x)            # -> (2)
        return x

# %%
class ViolinViolaCrossEntropyLoss(nn.Module):
    def __init__(self):
        super(ViolinViolaCrossEntropyLoss, self).__init__()
        self.register_buffer("class_weights", torch.tensor([1.0, 1.2]))

    def forward(self, outputs, labels):
        if self.class_weights is not None:
            class_weights = self.class_weights.to(outputs.device)
            return cross_entropy_with_probs(outputs, labels, weight=class_weights)
        return cross_entropy_with_probs(outputs, labels)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
model = ViolinViolaCNN()
criterion = ViolinViolaCrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# Out:
# Using device: cuda

# %%
from collections import defaultdict

def train(model, train_loader, val_loader, criterion, optimizer, device, num_epochs=10):
    max_avg_acc = {}
    model.to(device)

    # Multi-GPU support
    if torch.cuda.device_count() > 1:
        print(f"Using {torch.cuda.device_count()} GPUs with DataParallel")
        model = torch.nn.DataParallel(model)
    else:
        model.to(device)

    history = {
        "train_loss": [], "val_loss": [],
        "train_acc": [], "val_acc": [],
        "train_class_acc": [], "val_class_acc": [],
        "train_class_loss": [], "val_class_loss": [],
        "val_roc_y_true": [], "val_roc_y_score": [],
    }

    for epoch in range(num_epochs):
        model.train()
        total_loss, total_correct, total_samples = 0, 0, 0
        class_loss = defaultdict(float)
        class_correct = defaultdict(int)
        class_total = defaultdict(int)

        for X, y in train_loader:
            X, y = X.to(device), y.to(device)
            y_cls = y.argmax(dim=1)  # [B, 2] → [B]

            optimizer.zero_grad()
            logits = model(X)
            loss = criterion(logits, y)
            loss.backward()
            optimizer.step()

            preds = logits.argmax(dim=1)
            total_loss += loss.item() * y.size(0)
            total_correct += (preds == y_cls).sum().item()
            total_samples += y.size(0)

            for cls in [0, 1]:
                idx = (y_cls == cls)
                if idx.sum().item() > 0:
                    cls_loss = criterion(logits[idx], y[idx])
                    class_loss[cls] += cls_loss.item() * idx.sum().item()
                    class_correct[cls] += (preds[idx] == y_cls[idx]).sum().item()
                    class_total[cls] += idx.sum().item()

        train_loss = total_loss / total_samples
        train_acc = total_correct / total_samples
        train_class_acc = [class_correct[c] / class_total[c] for c in [0, 1]]
        train_class_loss = [class_loss[c] / class_total[c] for c in [0, 1]]

        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["train_class_acc"].append(train_class_acc)
        history["train_class_loss"].append(train_class_loss)

        # --- Validation ---
        model.eval()
        total_loss, total_correct, total_samples = 0, 0, 0
        class_loss = defaultdict(float)
        class_correct = defaultdict(int)
        class_total = defaultdict(int)
        val_y_true, val_y_score = [], []

        with torch.no_grad():
            for X, y in val_loader:
                X, y = X.to(device), y.to(device)
                y_cls = y.argmax(dim=1)  # convert [B, 2] to [B]

                logits = model(X)
                loss = criterion(logits, y)
                preds = logits.argmax(dim=1)
                probs = torch.softmax(logits, dim=1)[:, 1]  # probability for class 1 (viola)

                total_loss += loss.item() * y.size(0)
                total_correct += (preds == y_cls).sum().item()
                total_samples += y.size(0)

                val_y_true.extend(y_cls.cpu().numpy())   # binary int labels for ROC
                val_y_score.extend(probs.cpu().numpy())  # continuous scores

                for cls in [0, 1]:
                    idx = (y_cls == cls)
                    if idx.sum().item() > 0:
                        cls_loss = criterion(logits[idx], y[idx])
                        class_loss[cls] += cls_loss.item() * idx.sum().item()
                        class_correct[cls] += (preds[idx] == y_cls[idx]).sum().item()
                        class_total[cls] += idx.sum().item()

        val_loss = total_loss / total_samples
        val_acc = total_correct / total_samples
        val_class_acc = [class_correct[c] / class_total[c] for c in [0, 1]]
        val_class_loss = [class_loss[c] / class_total[c] for c in [0, 1]]

        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)
        history["val_class_acc"].append(val_class_acc)
        history["val_class_loss"].append(val_class_loss)
        history["val_roc_y_true"] = val_y_true
        history["val_roc_y_score"] = val_y_score

        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"  Train Loss: {train_loss:.4f} | Acc: {train_acc:.4f} | Violin Acc: {train_class_acc[0]:.4f} | Viola Acc: {train_class_acc[1]:.4f}")
        print(f"  Val   Loss: {val_loss:.4f} | Acc: {val_acc:.4f} | Violin Acc: {val_class_acc[0]:.4f} | Viola Acc: {val_class_acc[1]:.4f}")

        # Save model every epoch
        torch.save(model.state_dict(), f"violin_viola_cnn_cutmix_epoch_{epoch+1}.pth")
        print(f"Model saved as violin_viola_cnn_cutmix_epoch_{epoch+1}.pth")
        max_avg_acc[(epoch + 1)] = (train_acc + val_acc) / 2

    return history, max_avg_acc

def plot_history(history):
    epochs = range(1, len(history["train_loss"]) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, history["train_loss"], label="Train Loss")
    plt.plot(epochs, history["val_loss"], label="Val Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.title("Loss over Epochs")

    plt.subplot(1, 2, 2)
    plt.plot(epochs, history["train_acc"], label="Train Acc")
    plt.plot(epochs, history["val_acc"], label="Val Acc")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.title("Accuracy over Epochs")

    plt.tight_layout()
    plt.show()

def plot_roc(y_true, y_score):
    fpr, tpr, _ = roc_curve(y_true, y_score)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.2f})")
    plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve (Violin vs Viola)")
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()

# %%
history, max_avg_acc = train(model, train_loader, val_loader, criterion, optimizer, device='cuda', num_epochs=35)

plot_history(history)
plot_roc(history["val_roc_y_true"], history["val_roc_y_score"])

# Restore the best model based on maximum average accuracy
best_epoch = max(max_avg_acc, key=max_avg_acc.get)
state_dict = torch.load(f"violin_viola_cnn_cutmix_epoch_{best_epoch}.pth")
# Remove 'module.' prefix from all keys
new_state_dict = {k.replace("module.", ""): v for k, v in state_dict.items()}
model.load_state_dict(new_state_dict)
print(f"Best model restored from epoch {best_epoch} with max average accuracy {max_avg_acc[best_epoch]:.4f}")
# Out:
# Using 2 GPUs with DataParallel
# Epoch 1/35
#   Train Loss: 0.7033 | Acc: 0.6309 | Violin Acc: 0.7895 | Viola Acc: 0.3850
#   Val   Loss: 0.6000 | Acc: 0.6950 | Violin Acc: 0.6174 | Viola Acc: 0.8591
# Model saved as violin_viola_cnn_cutmix_epoch_1.pth
# Epoch 2/35
#   Train Loss: 0.5710 | Acc: 0.7678 | Violin Acc: 0.8063 | Viola Acc: 0.7082
#   Val   Loss: 0.5344 | Acc: 0.7415 | Violin Acc: 0.6492 | Viola Acc: 0.9365
# Model saved as violin_viola_cnn_cutmix_epoch_2.pth
# Epoch 3/35
#   Train Loss: 0.4960 | Acc: 0.8172 | Violin Acc: 0.8458 | Viola Acc: 0.7729
#   Val   Loss: 0.3448 | Acc: 0.8606 | Violin Acc: 0.8425 | Viola Acc: 0.8986
# Model saved as violin_viola_cnn_cutmix_epoch_3.pth
# Epoch 4/35
#   Train Loss: 0.4577 | Acc: 0.8451 | Violin Acc: 0.8683 | Viola Acc: 0.8090
#   Val   Loss: 0.3437 | Acc: 0.8556 | Violin Acc: 0.8352 | Viola Acc: 0.8986
# Model saved as violin_viola_cnn_cutmix_epoch_4.pth
# Epoch 5/35
#   Train Loss: 0.4447 | Acc: 0.8531 | Violin Acc: 0.8767 | Viola Acc: 0.8166
#   Val   Loss: 0.3060 | Acc: 0.8936 | Violin Acc: 0.9509 | Viola Acc: 0.7724
# Model saved as violin_viola_cnn_cutmix_epoch_5.pth
# Epoch 6/35
#   Train Loss: 0.4335 | Acc: 0.8596 | Violin Acc: 0.8813 | Viola Acc: 0.8261
#   Val   Loss: 0.2745 | Acc: 0.9068 | Violin Acc: 0.9238 | Viola Acc: 0.8707
# Model saved as violin_viola_cnn_cutmix_epoch_28.pth
# Epoch 29/35
#   Train Loss: 0.3580 | Acc: 0.9025 | Violin Acc: 0.9129 | Viola Acc: 0.8864
#   Val   Loss: 0.2792 | Acc: 0.9197 | Violin Acc: 0.9341 | Viola Acc: 0.8893
# Model saved as violin_viola_cnn_cutmix_epoch_29.pth
# Epoch 30/35
#   Train Loss: 0.3557 | Acc: 0.8986 | Violin Acc: 0.9106 | Viola Acc: 0.8798
#   Val   Loss: 0.2690 | Acc: 0.9195 | Violin Acc: 0.9612 | Viola Acc: 0.8313
# Model saved as violin_viola_cnn_cutmix_epoch_30.pth
# Epoch 31/35
#   Train Loss: 0.3579 | Acc: 0.8999 | Violin Acc: 0.9125 | Viola Acc: 0.8805
#   Val   Loss: 0.2502 | Acc: 0.9239 | Violin Acc: 0.9623 | Viola Acc: 0.8429
# Model saved as violin_viola_cnn_cutmix_epoch_31.pth
# Epoch 32/35
#   Train Loss: 0.3523 | Acc: 0.8996 | Violin Acc: 0.9128 | Viola Acc: 0.8791
#   Val   Loss: 0.2267 | Acc: 0.9269 | Violin Acc: 0.9440 | Viola Acc: 0.8909
# Model saved as violin_viola_cnn_cutmix_epoch_32.pth
# Epoch 33/35
#   Train Loss: 0.3557 | Acc: 0.9018 | Violin Acc: 0.9147 | Viola Acc: 0.8818
#   Val   Loss: 0.2793 | Acc: 0.9222 | Violin Acc: 0.9579 | Viola Acc: 0.8467
# Model saved as violin_viola_cnn_cutmix_epoch_33.pth
# Epoch 34/35
#   Train Loss: 0.3554 | Acc: 0.9041 | Violin Acc: 0.9132 | Viola Acc: 0.8900
#   Val   Loss: 0.2664 | Acc: 0.9212 | Violin Acc: 0.9268 | Viola Acc: 0.9094
# Model saved as violin_viola_cnn_cutmix_epoch_34.pth
# Epoch 35/35
#   Train Loss: 0.3604 | Acc: 0.9039 | Violin Acc: 0.9160 | Viola Acc: 0.8852
#   Val   Loss: 0.2676 | Acc: 0.9088 | Violin Acc: 0.9015 | Viola Acc: 0.9241
# Model saved as violin_viola_cnn_cutmix_epoch_35.pth
# Best model restored from epoch 27 with max average accuracy 0.9185

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

for epoch in range(1, 36):
    state_dict = torch.load(f"violin_viola_cnn_cutmix_epoch_{epoch}.pth")
    new_state_dict = {k.replace("module.", ""): v for k, v in state_dict.items()}
    model.load_state_dict(new_state_dict)
    model.to('cpu')
    model.eval()

    total_correct, total_samples = 0, 0
    class_correct = defaultdict(int)
    class_total = defaultdict(int)

    all_preds = []
    all_labels = []

    with torch.no_grad():
        for X, y in test_loader:
            X, y = X.to('cpu'), y.to('cpu')  # y is one-hot, shape [B, 2]
            y_cls = y.argmax(dim=1)         # convert to shape [B]

            logits = model(X)
            preds = logits.argmax(dim=1)

            total_correct += (preds == y_cls).sum().item()
            total_samples += y_cls.size(0)

            # For accuracy
            for i in range(y_cls.size(0)):
                label = y_cls[i].item()
                class_total[label] += 1
                class_correct[label] += (preds[i].item() == label)

            # For F1/Precision/Recall
            all_preds.extend(preds.tolist())
            all_labels.extend(y_cls.tolist())

    test_acc = total_correct / total_samples
    print(f"Epoch {epoch}: Test Accuracy: {test_acc:.4f}")

    for cls in [0, 1]:
        if class_total[cls] > 0:
            class_acc = class_correct[cls] / class_total[cls]
            print(f"  Class {cls} Accuracy: {class_acc:.4f}")

    avg_class_acc = sum(class_correct[c] / class_total[c] for c in [0, 1]) / 2
    print(f"Average Class Accuracy: {avg_class_acc:.4f}")

    # F1, Precision, Recall (macro = average across classes)
    f1 = f1_score(all_labels, all_preds, average='macro')
    precision = precision_score(all_labels, all_preds, average='macro')
    recall = recall_score(all_labels, all_preds, average='macro')
    print(f"F1 Score (macro): {f1:.4f}")
    print(f"Precision (macro): {precision:.4f}")
    print(f"Recall (macro): {recall:.4f}")
    print("-" * 40)
# Out:
# Epoch 1: Test Accuracy: 0.7010
#   Class 0 Accuracy: 0.6246
#   Class 1 Accuracy: 0.8562
# Average Class Accuracy: 0.7404
# F1 Score (macro): 0.6954
# Precision (macro): 0.7136
# Recall (macro): 0.7404
# ----------------------------------------
# Epoch 2: Test Accuracy: 0.7398
#   Class 0 Accuracy: 0.6432
#   Class 1 Accuracy: 0.9360
# Average Class Accuracy: 0.7896
# F1 Score (macro): 0.7359
# Precision (macro): 0.7585
# Recall (macro): 0.7896
# ----------------------------------------
# Epoch 3: Test Accuracy: 0.8663
#   Class 0 Accuracy: 0.8431
#   Class 1 Accuracy: 0.9134
# Average Class Accuracy: 0.8783
# F1 Score (macro): 0.8563
# Precision (macro): 0.8466
# Recall (macro): 0.8783
# ----------------------------------------
# Epoch 4: Test Accuracy: 0.8539
#   Class 0 Accuracy: 0.8242
#   Class 1 Accuracy: 0.9142
# Average Class Accuracy: 0.8692
# F1 Score (macro): 0.8441
# Precision (macro): 0.8352
# Recall (macro): 0.8692
# ----------------------------------------
# Epoch 5: Test Accuracy: 0.8854
#   Class 0 Accuracy: 0.9373
#   Class 1 Accuracy: 0.7801
# Average Class Accuracy: 0.8587
# F1 Score (macro): 0.8672
# Precision (macro): 0.8781
# Recall (macro): 0.8587
# ----------------------------------------
# Epoch 6: Test Accuracy: 0.9051
#   Class 0 Accuracy: 0.9139
#   Class 1 Accuracy: 0.8870
# Average Class Accuracy: 0.9005
# F1 Score (macro): 0.8943
# Precision (macro): 0.8890
# Recall (macro): 0.9005
# ----------------------------------------
# Epoch 7: Test Accuracy: 0.8839
#   Class 0 Accuracy: 0.8583
#   Class 1 Accuracy: 0.9360
# Average Class Accuracy: 0.8972
# F1 Score (macro): 0.8751
# Precision (macro): 0.8647
# Recall (macro): 0.8972
# ----------------------------------------
# Epoch 8: Test Accuracy: 0.9235
#   Class 0 Accuracy: 0.9607
#   Class 1 Accuracy: 0.8479
# Average Class Accuracy: 0.9043
# F1 Score (macro): 0.9118
# Precision (macro): 0.9208
# Recall (macro): 0.9043
# ----------------------------------------
# Epoch 9: Test Accuracy: 0.8730
#   Class 0 Accuracy: 0.8494
#   Class 1 Accuracy: 0.9209
# Average Class Accuracy: 0.8852
# F1 Score (macro): 0.8634
# Precision (macro): 0.8535
# Recall (macro): 0.8852
# ----------------------------------------
# Epoch 10: Test Accuracy: 0.9038
#   Class 0 Accuracy: 0.9076
#   Class 1 Accuracy: 0.8961
# Average Class Accuracy: 0.9019
# F1 Score (macro): 0.8934
# Precision (macro): 0.8868
# Recall (macro): 0.9019
# ----------------------------------------
# Epoch 11: Test Accuracy: 0.9232
#   Class 0 Accuracy: 0.9529
#   Class 1 Accuracy: 0.8630
# Average Class Accuracy: 0.9079
# F1 Score (macro): 0.9122
# Precision (macro): 0.9170
# Recall (macro): 0.9079
# ----------------------------------------
# Epoch 12: Test Accuracy: 0.9143
#   Class 0 Accuracy: 0.9514
#   Class 1 Accuracy: 0.8389
# Average Class Accuracy: 0.8951
# F1 Score (macro): 0.9015
# Precision (macro): 0.9089
# Recall (macro): 0.8951
# ----------------------------------------
# Epoch 13: Test Accuracy: 0.9177
#   Class 0 Accuracy: 0.9425
#   Class 1 Accuracy: 0.8675
# Average Class Accuracy: 0.9050
# F1 Score (macro): 0.9066
# Precision (macro): 0.9083
# Recall (macro): 0.9050
# ----------------------------------------
# Epoch 14: Test Accuracy: 0.9143
#   Class 0 Accuracy: 0.9496
#   Class 1 Accuracy: 0.8426
# Average Class Accuracy: 0.8961
# F1 Score (macro): 0.9017
# Precision (macro): 0.9081
# Recall (macro): 0.8961
# ----------------------------------------
# Epoch 15: Test Accuracy: 0.9200
#   Class 0 Accuracy: 0.9651
#   Class 1 Accuracy: 0.8283
# Average Class Accuracy: 0.8967
# F1 Score (macro): 0.9070
# Precision (macro): 0.9204
# Recall (macro): 0.8967
# ----------------------------------------
# Epoch 16: Test Accuracy: 0.9165
#   Class 0 Accuracy: 0.9191
#   Class 1 Accuracy: 0.9111
# Average Class Accuracy: 0.9151
# F1 Score (macro): 0.9073
# Precision (macro): 0.9009
# Recall (macro): 0.9151
# ----------------------------------------
# Epoch 17: Test Accuracy: 0.9185
#   Class 0 Accuracy: 0.9588
#   Class 1 Accuracy: 0.8366
# Average Class Accuracy: 0.8977
# F1 Score (macro): 0.9059
# Precision (macro): 0.9159
# Recall (macro): 0.8977
# ----------------------------------------
# Epoch 18: Test Accuracy: 0.9225
#   Class 0 Accuracy: 0.9763
#   Class 1 Accuracy: 0.8133
# Average Class Accuracy: 0.8948
# F1 Score (macro): 0.9089
# Precision (macro): 0.9290
# Recall (macro): 0.8948
# ----------------------------------------
# Epoch 19: Test Accuracy: 0.9177
#   Class 0 Accuracy: 0.9473
#   Class 1 Accuracy: 0.8577
# Average Class Accuracy: 0.9025
# F1 Score (macro): 0.9061
# Precision (macro): 0.9101
# Recall (macro): 0.9025
# ----------------------------------------
# Epoch 20: Test Accuracy: 0.9284
#   Class 0 Accuracy: 0.9644
#   Class 1 Accuracy: 0.8554
# Average Class Accuracy: 0.9099
# F1 Score (macro): 0.9175
# Precision (macro): 0.9267
# Recall (macro): 0.9099
# ----------------------------------------
# Epoch 21: Test Accuracy: 0.9163
#   Class 0 Accuracy: 0.9611
#   Class 1 Accuracy: 0.8253
# Average Class Accuracy: 0.8932
# F1 Score (macro): 0.9028
# Precision (macro): 0.9152
# Recall (macro): 0.8932
# ----------------------------------------
# Epoch 22: Test Accuracy: 0.9299
#   Class 0 Accuracy: 0.9533
#   Class 1 Accuracy: 0.8825
# Average Class Accuracy: 0.9179
# F1 Score (macro): 0.9203
# Precision (macro): 0.9229
# Recall (macro): 0.9179
# ----------------------------------------
# Epoch 23: Test Accuracy: 0.9135
#   Class 0 Accuracy: 0.9841
#   Class 1 Accuracy: 0.7703
# Average Class Accuracy: 0.8772
# F1 Score (macro): 0.8965
# Precision (macro): 0.9283
# Recall (macro): 0.8772
# ----------------------------------------
# Epoch 24: Test Accuracy: 0.9192
#   Class 0 Accuracy: 0.9692
#   Class 1 Accuracy: 0.8178
# Average Class Accuracy: 0.8935
# F1 Score (macro): 0.9056
# Precision (macro): 0.9221
# Recall (macro): 0.8935
# ----------------------------------------
# Epoch 25: Test Accuracy: 0.9277
#   Class 0 Accuracy: 0.9599
#   Class 1 Accuracy: 0.8622
# Average Class Accuracy: 0.9111
# F1 Score (macro): 0.9170
# Precision (macro): 0.9239
# Recall (macro): 0.9111
# ----------------------------------------
# Epoch 26: Test Accuracy: 0.9197
#   Class 0 Accuracy: 0.9692
#   Class 1 Accuracy: 0.8193
# Average Class Accuracy: 0.8942
# F1 Score (macro): 0.9063
# Precision (macro): 0.9225
# Recall (macro): 0.8942
# ----------------------------------------
# Epoch 27: Test Accuracy: 0.9322
#   Class 0 Accuracy: 0.9611
#   Class 1 Accuracy: 0.8735
# Average Class Accuracy: 0.9173
# F1 Score (macro): 0.9223
# Precision (macro): 0.9281
# Recall (macro): 0.9173
# ----------------------------------------
# Epoch 28: Test Accuracy: 0.9108
#   Class 0 Accuracy: 0.9770
#   Class 1 Accuracy: 0.7764
# Average Class Accuracy: 0.8767
# F1 Score (macro): 0.8940
# Precision (macro): 0.9210
# Recall (macro): 0.8767
# ----------------------------------------
# Epoch 29: Test Accuracy: 0.9210
#   Class 0 Accuracy: 0.9321
#   Class 1 Accuracy: 0.8983
# Average Class Accuracy: 0.9152
# F1 Score (macro): 0.9114
# Precision (macro): 0.9080
# Recall (macro): 0.9152
# ----------------------------------------
# Epoch 30: Test Accuracy: 0.9210
#   Class 0 Accuracy: 0.9614
#   Class 1 Accuracy: 0.8389
# Average Class Accuracy: 0.9001
# F1 Score (macro): 0.9087
# Precision (macro): 0.9192
# Recall (macro): 0.9001
# ----------------------------------------
# Epoch 31: Test Accuracy: 0.9259
#   Class 0 Accuracy: 0.9618
#   Class 1 Accuracy: 0.8532
# Average Class Accuracy: 0.9075
# F1 Score (macro): 0.9147
# Precision (macro): 0.9234
# Recall (macro): 0.9075
# ----------------------------------------
# Epoch 32: Test Accuracy: 0.9257
#   Class 0 Accuracy: 0.9440
#   Class 1 Accuracy: 0.8886
# Average Class Accuracy: 0.9163
# F1 Score (macro): 0.9160
# Precision (macro): 0.9158
# Recall (macro): 0.9163
# ----------------------------------------
# Epoch 33: Test Accuracy: 0.9150
#   Class 0 Accuracy: 0.9536
#   Class 1 Accuracy: 0.8366
# Average Class Accuracy: 0.8951
# F1 Score (macro): 0.9021
# Precision (macro): 0.9105
# Recall (macro): 0.8951
# ----------------------------------------
# Epoch 34: Test Accuracy: 0.9222
#   Class 0 Accuracy: 0.9299
#   Class 1 Accuracy: 0.9066
# Average Class Accuracy: 0.9183
# F1 Score (macro): 0.9131
# Precision (macro): 0.9086
# Recall (macro): 0.9183
# ----------------------------------------
# Epoch 35: Test Accuracy: 0.9071
#   Class 0 Accuracy: 0.8984
#   Class 1 Accuracy: 0.9247
# Average Class Accuracy: 0.9115
# F1 Score (macro): 0.8981
# Precision (macro): 0.8890
# Recall (macro): 0.9115
# ----------------------------------------

# %%
# Best choice: Epoch 34
