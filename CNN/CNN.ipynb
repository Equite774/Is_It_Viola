# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# %%
class ViolinViolaDataset(Dataset):
    def __init__(self, root_dir, label_map = None, transform=None):
        self.root_dir = root_dir
        self.files = [f for f in os.listdir(root_dir) if f.endswith('.npy')]
        self.label_map = label_map or {'violin': 0, 'viola': 1}
        self.transform = transform

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        filename = self.files[idx]
        filepath = os.path.join(self.root_dir, filename)
        mel = np.load(filepath)
        spec = torch.from_numpy(mel)
        spec = spec.unsqueeze(0)  # Add channel dimension
        label = self.label_map[filename.split('_')[1]] if self.label_map else None
        if self.transform:
            spec = self.transform(spec)
        return spec, label

# %%
transform = transforms.Compose([
    transforms.Resize((128, 517)),  # Resize to a fixed size
    transforms.Normalize([0.5], [0.5])  # Normalize the image
])

# %%
g_train = torch.Generator()
g_train.manual_seed(17)
train_dataset = ViolinViolaDataset('train/', transform=transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

g_test = torch.Generator()
g_test.manual_seed(17)
test_dataset = ViolinViolaDataset('test/', transform=transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)

# %%
class ViolinViolaCNN(nn.Module):
    def __init__(self):
        super(ViolinViolaCNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=1, out_channels=40, kernel_size=1)   # output: (40, 128, 517)
        self.conv2 = nn.Conv2d(in_channels=40, out_channels=32, kernel_size=5)  # output: (32, 124, 513)
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=16, kernel_size=1)  # output: (16, 124, 513)

        self.pool = nn.AdaptiveAvgPool2d((16, 16))  # reduce to fixed-size for Dense

        self.fc1 = nn.Linear(16 * 16 * 16, 64)
        self.fc2 = nn.Linear(64, 16)
        self.fc3 = nn.Linear(16, 12)
        self.out = nn.Linear(12, 2)  # binary classification: violin vs viola

    def forward(self, x):
        x = F.relu(self.conv1(x))  # -> (40, 128, 517)
        x = F.relu(self.conv2(x))  # -> (32, 124, 513)
        x = F.relu(self.conv3(x))  # -> (16, 124, 513)
        x = self.pool(x)           # -> (16, 16, 16)
        x = x.view(x.size(0), -1)  # flatten
        x = F.relu(self.fc1(x))    # -> (64)
        x = F.relu(self.fc2(x))    # -> (16)
        x = F.relu(self.fc3(x))    # -> (12)
        x = self.out(x)            # -> (2)
        return x

# %%
class ViolinViolaCrossEntropyLoss(nn.Module):
    def __init__(self):
        super(ViolinViolaCrossEntropyLoss, self).__init__()
        self.register_buffer("class_weights", torch.tensor([1.0, 1.2]))

    def forward(self, outputs, labels):
        if self.class_weights is not None:
            class_weights = self.class_weights.to(outputs.device)
            return F.cross_entropy(outputs, labels, weight=class_weights)
        return F.cross_entropy(outputs, labels)

# %%
model = ViolinViolaCNN()
criterion = ViolinViolaCrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
from collections import defaultdict

def train(model, train_loader, val_loader, criterion, optimizer, device, num_epochs=10):
    max_avg_acc = {}

    model.to(device)

    history = {
        "train_loss": [], "val_loss": [],
        "train_acc": [], "val_acc": [],
        "train_class_acc": [], "val_class_acc": [],
        "train_class_loss": [], "val_class_loss": [],
        "val_roc_y_true": [], "val_roc_y_score": [],
    }

    for epoch in range(num_epochs):
        model.train()
        total_loss, total_correct, total_samples = 0, 0, 0
        class_loss = defaultdict(float)
        class_correct = defaultdict(int)
        class_total = defaultdict(int)

        for X, y in train_loader:
            X, y = X.to(device), y.to(device)

            optimizer.zero_grad()
            logits = model(X)
            loss = criterion(logits, y)
            loss.backward()
            optimizer.step()

            preds = logits.argmax(dim=1)
            total_loss += loss.item() * y.size(0)
            total_correct += (preds == y).sum().item()
            total_samples += y.size(0)

            for cls in [0, 1]:  # violin, viola
                idx = (y == cls)
                if idx.sum().item() > 0:
                    cls_loss = criterion(logits[idx], y[idx])
                    class_loss[cls] += cls_loss.item() * idx.sum().item()
                    class_correct[cls] += (preds[idx] == y[idx]).sum().item()
                    class_total[cls] += idx.sum().item()

        train_loss = total_loss / total_samples
        train_acc = total_correct / total_samples
        train_class_acc = [class_correct[c] / class_total[c] for c in [0, 1]]
        train_class_loss = [class_loss[c] / class_total[c] for c in [0, 1]]

        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["train_class_acc"].append(train_class_acc)
        history["train_class_loss"].append(train_class_loss)

        # --- Validation ---
        model.eval()
        total_loss, total_correct, total_samples = 0, 0, 0
        class_loss = defaultdict(float)
        class_correct = defaultdict(int)
        class_total = defaultdict(int)
        val_y_true, val_y_score = [], []

        with torch.no_grad():
            for X, y in val_loader:
                X, y = X.to(device), y.to(device)
                logits = model(X)
                loss = criterion(logits, y)

                preds = logits.argmax(dim=1)
                probs = torch.softmax(logits, dim=1)[:, 1]

                total_loss += loss.item() * y.size(0)
                total_correct += (preds == y).sum().item()
                total_samples += y.size(0)

                val_y_true.extend(y.cpu().numpy())
                val_y_score.extend(probs.cpu().numpy())

                for cls in [0, 1]:
                    idx = (y == cls)
                    if idx.sum().item() > 0:
                        cls_loss = criterion(logits[idx], y[idx])
                        class_loss[cls] += cls_loss.item() * idx.sum().item()
                        class_correct[cls] += (preds[idx] == y[idx]).sum().item()
                        class_total[cls] += idx.sum().item()

        val_loss = total_loss / total_samples
        val_acc = total_correct / total_samples
        val_class_acc = [class_correct[c] / class_total[c] for c in [0, 1]]
        val_class_loss = [class_loss[c] / class_total[c] for c in [0, 1]]

        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)
        history["val_class_acc"].append(val_class_acc)
        history["val_class_loss"].append(val_class_loss)
        history["val_roc_y_true"] = val_y_true
        history["val_roc_y_score"] = val_y_score

        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"  Train Loss: {train_loss:.4f} | Acc: {train_acc:.4f} | Violin Acc: {train_class_acc[0]:.4f} | Viola Acc: {train_class_acc[1]:.4f}")
        print(f"  Val   Loss: {val_loss:.4f} | Acc: {val_acc:.4f} | Violin Acc: {val_class_acc[0]:.4f} | Viola Acc: {val_class_acc[1]:.4f}")

        # Save model every epoch
        torch.save(model.state_dict(), f"violin_viola_cnn_epoch_{epoch+1}.pth")
        print(f"Model saved as violin_viola_cnn_epoch_{epoch+1}.pth")
        # Save maximum average accuracy between violin and viola
        max_avg_acc[(epoch + 1)] = (train_acc + val_acc) / 2

    return history, max_avg_acc

def plot_history(history):
    epochs = range(1, len(history["train_loss"]) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, history["train_loss"], label="Train Loss")
    plt.plot(epochs, history["val_loss"], label="Val Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.title("Loss over Epochs")

    plt.subplot(1, 2, 2)
    plt.plot(epochs, history["train_acc"], label="Train Acc")
    plt.plot(epochs, history["val_acc"], label="Val Acc")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.title("Accuracy over Epochs")

    plt.tight_layout()
    plt.show()

def plot_roc(y_true, y_score):
    fpr, tpr, _ = roc_curve(y_true, y_score)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.2f})")
    plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve (Violin vs Viola)")
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()

# %%
history, max_avg_acc = train(model, train_loader, test_loader, criterion, optimizer, device='cpu', num_epochs=25)

plot_history(history)
plot_roc(history["val_roc_y_true"], history["val_roc_y_score"])

# Restore the best model based on maximum average accuracy
best_epoch = max(max_avg_acc, key=max_avg_acc.get)
model.load_state_dict(torch.load(f"violin_viola_cnn_epoch_{best_epoch}.pth"))
print(f"Best model restored from epoch {best_epoch} with max average accuracy {max_avg_acc[best_epoch]:.4f}")
# Out:
# Epoch 1/25
#   Train Loss: 0.1740 | Acc: 0.9296 | Violin Acc: 0.9388 | Viola Acc: 0.9154
#   Val   Loss: 0.3349 | Acc: 0.8609 | Violin Acc: 0.8679 | Viola Acc: 0.8466
# Model saved as violin_viola_cnn_epoch_22.pth
# Epoch 23/25
#   Train Loss: 0.1783 | Acc: 0.9285 | Violin Acc: 0.9381 | Viola Acc: 0.9136
#   Val   Loss: 0.3424 | Acc: 0.8711 | Violin Acc: 0.9210 | Viola Acc: 0.7679
# Model saved as violin_viola_cnn_epoch_23.pth
# Epoch 24/25
#   Train Loss: 0.1755 | Acc: 0.9287 | Violin Acc: 0.9384 | Viola Acc: 0.9137
#   Val   Loss: 0.3759 | Acc: 0.8711 | Violin Acc: 0.9296 | Viola Acc: 0.7500
# Model saved as violin_viola_cnn_epoch_24.pth
# Epoch 25/25
#   Train Loss: 0.1672 | Acc: 0.9344 | Violin Acc: 0.9426 | Viola Acc: 0.9217
#   Val   Loss: 0.3444 | Acc: 0.8613 | Violin Acc: 0.8703 | Viola Acc: 0.8427
# Model saved as violin_viola_cnn_epoch_25.pth
# Best model restored from epoch 13 with max average accuracy 0.9083

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

for epoch in range(1, 26):
    model.load_state_dict(torch.load(f"violin_viola_cnn_epoch_{epoch}.pth"))
    model.eval()
    total_correct, total_samples = 0, 0
    class_correct = defaultdict(int)
    class_total = defaultdict(int)

    all_preds = []
    all_labels = []

    with torch.no_grad():
        for X, y in test_loader:
            X, y = X.to('cpu'), y.to('cpu')
            logits = model(X)
            preds = logits.argmax(dim=1)
            total_correct += (preds == y).sum().item()
            total_samples += y.size(0)

            # For accuracy
            for i in range(y.size(0)):
                class_total[y[i].item()] += 1
                class_correct[y[i].item()] += (preds[i] == y[i]).item()

            # For F1/Precision/Recall
            all_preds.extend(preds.tolist())
            all_labels.extend(y.tolist())

    test_acc = total_correct / total_samples
    print(f"Epoch {epoch}: Test Accuracy: {test_acc:.4f}")

    for cls in [0, 1]:
        if class_total[cls] > 0:
            class_acc = class_correct[cls] / class_total[cls]
            print(f"  Class {cls} Accuracy: {class_acc:.4f}")

    avg_class_acc = sum(class_correct[c] / class_total[c] for c in [0, 1]) / 2
    print(f"Average Class Accuracy: {avg_class_acc:.4f}")

    # F1, Precision, Recall (macro = average across classes)
    f1 = f1_score(all_labels, all_preds, average='macro')
    precision = precision_score(all_labels, all_preds, average='macro')
    recall = recall_score(all_labels, all_preds, average='macro')
    print(f"F1 Score (macro): {f1:.4f}")
    print(f"Precision (macro): {precision:.4f}")
    print(f"Recall (macro): {recall:.4f}")
    print("-" * 40)
# Out:
# Epoch 1: Test Accuracy: 0.7623
#   Class 0 Accuracy: 0.7271
#   Class 1 Accuracy: 0.8351
# Average Class Accuracy: 0.7811
# F1 Score (macro): 0.7504
# Precision (macro): 0.7488
# Recall (macro): 0.7811
# ----------------------------------------
# Epoch 2: Test Accuracy: 0.8372
#   Class 0 Accuracy: 0.8568
#   Class 1 Accuracy: 0.7966
# Average Class Accuracy: 0.8267
# F1 Score (macro): 0.8188
# Precision (macro): 0.8129
# Recall (macro): 0.8267
# ----------------------------------------
# Epoch 3: Test Accuracy: 0.7922
#   Class 0 Accuracy: 0.7457
#   Class 1 Accuracy: 0.8885
# Average Class Accuracy: 0.8171
# F1 Score (macro): 0.7823
# Precision (macro): 0.7803
# Recall (macro): 0.8171
# ----------------------------------------
# Epoch 4: Test Accuracy: 0.8577
#   Class 0 Accuracy: 0.8975
#   Class 1 Accuracy: 0.7752
# Average Class Accuracy: 0.8364
# F1 Score (macro): 0.8375
# Precision (macro): 0.8386
# Recall (macro): 0.8364
# ----------------------------------------
# Epoch 5: Test Accuracy: 0.8324
#   Class 0 Accuracy: 0.8122
#   Class 1 Accuracy: 0.8740
# Average Class Accuracy: 0.8431
# F1 Score (macro): 0.8199
# Precision (macro): 0.8112
# Recall (macro): 0.8431
# ----------------------------------------
# Epoch 6: Test Accuracy: 0.8428
#   Class 0 Accuracy: 0.8367
#   Class 1 Accuracy: 0.8553
# Average Class Accuracy: 0.8460
# F1 Score (macro): 0.8288
# Precision (macro): 0.8198
# Recall (macro): 0.8460
# ----------------------------------------
# Epoch 7: Test Accuracy: 0.8690
#   Class 0 Accuracy: 0.9162
#   Class 1 Accuracy: 0.7714
# Average Class Accuracy: 0.8438
# F1 Score (macro): 0.8487
# Precision (macro): 0.8544
# Recall (macro): 0.8438
# ----------------------------------------
# Epoch 8: Test Accuracy: 0.8450
#   Class 0 Accuracy: 0.9698
#   Class 1 Accuracy: 0.5866
# Average Class Accuracy: 0.7782
# F1 Score (macro): 0.8027
# Precision (macro): 0.8665
# Recall (macro): 0.7782
# ----------------------------------------
# Epoch 9: Test Accuracy: 0.8688
#   Class 0 Accuracy: 0.8872
#   Class 1 Accuracy: 0.8305
# Average Class Accuracy: 0.8589
# F1 Score (macro): 0.8530
# Precision (macro): 0.8480
# Recall (macro): 0.8589
# ----------------------------------------
# Epoch 10: Test Accuracy: 0.8644
#   Class 0 Accuracy: 0.8706
#   Class 1 Accuracy: 0.8515
# Average Class Accuracy: 0.8611
# F1 Score (macro): 0.8500
# Precision (macro): 0.8423
# Recall (macro): 0.8611
# ----------------------------------------
# Epoch 11: Test Accuracy: 0.8612
#   Class 0 Accuracy: 0.9033
#   Class 1 Accuracy: 0.7740
# Average Class Accuracy: 0.8387
# F1 Score (macro): 0.8409
# Precision (macro): 0.8433
# Recall (macro): 0.8387
# ----------------------------------------
# Epoch 12: Test Accuracy: 0.8648
#   Class 0 Accuracy: 0.9206
#   Class 1 Accuracy: 0.7492
# Average Class Accuracy: 0.8349
# F1 Score (macro): 0.8424
# Precision (macro): 0.8519
# Recall (macro): 0.8349
# ----------------------------------------
# Epoch 13: Test Accuracy: 0.8926
#   Class 0 Accuracy: 0.9573
#   Class 1 Accuracy: 0.7588
# Average Class Accuracy: 0.8580
# F1 Score (macro): 0.8724
# Precision (macro): 0.8935
# Recall (macro): 0.8580
# ----------------------------------------
# Epoch 14: Test Accuracy: 0.8549
#   Class 0 Accuracy: 0.8495
#   Class 1 Accuracy: 0.8660
# Average Class Accuracy: 0.8577
# F1 Score (macro): 0.8414
# Precision (macro): 0.8323
# Recall (macro): 0.8577
# ----------------------------------------
# Epoch 15: Test Accuracy: 0.8829
#   Class 0 Accuracy: 0.9101
#   Class 1 Accuracy: 0.8267
# Average Class Accuracy: 0.8684
# F1 Score (macro): 0.8672
# Precision (macro): 0.8660
# Recall (macro): 0.8684
# ----------------------------------------
# Epoch 16: Test Accuracy: 0.8611
#   Class 0 Accuracy: 0.8577
#   Class 1 Accuracy: 0.8679
# Average Class Accuracy: 0.8628
# F1 Score (macro): 0.8477
# Precision (macro): 0.8387
# Recall (macro): 0.8628
# ----------------------------------------
# Epoch 17: Test Accuracy: 0.8705
#   Class 0 Accuracy: 0.9766
#   Class 1 Accuracy: 0.6508
# Average Class Accuracy: 0.8137
# F1 Score (macro): 0.8382
# Precision (macro): 0.8917
# Recall (macro): 0.8137
# ----------------------------------------
# Epoch 18: Test Accuracy: 0.8764
#   Class 0 Accuracy: 0.8920
#   Class 1 Accuracy: 0.8439
# Average Class Accuracy: 0.8680
# F1 Score (macro): 0.8616
# Precision (macro): 0.8563
# Recall (macro): 0.8680
# ----------------------------------------
# Epoch 19: Test Accuracy: 0.8590
#   Class 0 Accuracy: 0.8600
#   Class 1 Accuracy: 0.8569
# Average Class Accuracy: 0.8584
# F1 Score (macro): 0.8449
# Precision (macro): 0.8364
# Recall (macro): 0.8584
# ----------------------------------------
# Epoch 20: Test Accuracy: 0.8814
#   Class 0 Accuracy: 0.9563
#   Class 1 Accuracy: 0.7263
# Average Class Accuracy: 0.8413
# F1 Score (macro): 0.8577
# Precision (macro): 0.8839
# Recall (macro): 0.8413
# ----------------------------------------
# Epoch 21: Test Accuracy: 0.8603
#   Class 0 Accuracy: 0.8786
#   Class 1 Accuracy: 0.8225
# Average Class Accuracy: 0.8505
# F1 Score (macro): 0.8439
# Precision (macro): 0.8385
# Recall (macro): 0.8505
# ----------------------------------------
# Epoch 22: Test Accuracy: 0.8609
#   Class 0 Accuracy: 0.8679
#   Class 1 Accuracy: 0.8466
# Average Class Accuracy: 0.8572
# F1 Score (macro): 0.8462
# Precision (macro): 0.8385
# Recall (macro): 0.8572
# ----------------------------------------
# Epoch 23: Test Accuracy: 0.8711
#   Class 0 Accuracy: 0.9210
#   Class 1 Accuracy: 0.7679
# Average Class Accuracy: 0.8444
# F1 Score (macro): 0.8506
# Precision (macro): 0.8579
# Recall (macro): 0.8444
# ----------------------------------------
# Epoch 24: Test Accuracy: 0.8711
#   Class 0 Accuracy: 0.9296
#   Class 1 Accuracy: 0.7500
# Average Class Accuracy: 0.8398
# F1 Score (macro): 0.8490
# Precision (macro): 0.8612
# Recall (macro): 0.8398
# ----------------------------------------
# Epoch 25: Test Accuracy: 0.8613
#   Class 0 Accuracy: 0.8703
#   Class 1 Accuracy: 0.8427
# Average Class Accuracy: 0.8565
# F1 Score (macro): 0.8463
# Precision (macro): 0.8390
# Recall (macro): 0.8565
# ----------------------------------------
