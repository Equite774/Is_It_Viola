# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# %%
class ViolinViolaDataset(Dataset):
    def __init__(self, root_dir, label_map = None, transform=None):
        self.root_dir = root_dir
        self.files = [f for f in os.listdir(root_dir) if f.endswith('.npy')]
        self.label_map = label_map or {'violin': 0, 'viola': 1}
        self.transform = transform

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        filename = self.files[idx]
        filepath = os.path.join(self.root_dir, filename)
        mel = np.load(filepath)
        spec = torch.from_numpy(mel)
        spec = spec.unsqueeze(0)  # Add channel dimension
        label = self.label_map[filename.split('_')[1]] if self.label_map else None
        if self.transform:
            spec = self.transform(spec)
        return spec, label

# %%
transform = transforms.Compose([
    transforms.Resize((128, 517)),  # Resize to a fixed size
    transforms.Normalize([0.5], [0.5])  # Normalize the image
])

# %%
g_train = torch.Generator()
g_train.manual_seed(17)
train_dataset = ViolinViolaDataset('train/', transform=transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

g_test = torch.Generator()
g_test.manual_seed(17)
test_dataset = ViolinViolaDataset('test/', transform=transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)

# %%
class ViolinViolaCNN(nn.Module):
    def __init__(self):
        super(ViolinViolaCNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=1, out_channels=40, stride=(2, 1), kernel_size=(5, 1))   # output: (40, 62, 517)
        self.conv2 = nn.Conv2d(in_channels=40, out_channels=32, kernel_size=(3, 2))  # output: (32, 60, 516)
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=16, kernel_size=1)  # output: (16, 60, 516)

        self.pool = nn.AdaptiveAvgPool2d((16, 16))  # reduce to fixed-size for Dense

        self.fc1 = nn.Linear(16 * 16 * 16, 64)
        self.fc2 = nn.Linear(64, 16)
        self.fc3 = nn.Linear(16, 12)
        self.out = nn.Linear(12, 2)  # binary classification: violin vs viola

    def forward(self, x):
        x = F.relu(self.conv1(x))  # -> (40, 62, 517)
        x = F.relu(self.conv2(x))  # -> (32, 60, 516)
        x = F.relu(self.conv3(x))  # -> (16, 60, 516)
        x = self.pool(x)           # -> (16, 16, 16)
        x = x.view(x.size(0), -1)  # flatten
        x = F.relu(self.fc1(x))    # -> (64)
        x = F.relu(self.fc2(x))    # -> (16)
        x = F.relu(self.fc3(x))    # -> (12)
        x = self.out(x)            # -> (2)
        return x

# %%
class ViolinViolaCrossEntropyLoss(nn.Module):
    def __init__(self):
        super(ViolinViolaCrossEntropyLoss, self).__init__()
        self.register_buffer("class_weights", torch.tensor([1.0, 1.2]))

    def forward(self, outputs, labels):
        if self.class_weights is not None:
            class_weights = self.class_weights.to(outputs.device)
            return F.cross_entropy(outputs, labels, weight=class_weights)
        return F.cross_entropy(outputs, labels)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
model = ViolinViolaCNN()
criterion = ViolinViolaCrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# Out:
# Using device: cuda

# %%
from collections import defaultdict

def train(model, train_loader, val_loader, criterion, optimizer, device, num_epochs=10):
    max_avg_acc = {}

    model.to(device)

    # Use DataParallel for multiple GPUs
    if torch.cuda.device_count() > 1:
        print(f"Using {torch.cuda.device_count()} GPUs with DataParallel")
        model.to(device)  # Move model to CUDA *before* DataParallel
        model = torch.nn.DataParallel(model)
    else:
        model.to(device)


    history = {
        "train_loss": [], "val_loss": [],
        "train_acc": [], "val_acc": [],
        "train_class_acc": [], "val_class_acc": [],
        "train_class_loss": [], "val_class_loss": [],
        "val_roc_y_true": [], "val_roc_y_score": [],
    }

    for epoch in range(num_epochs):
        model.train()
        total_loss, total_correct, total_samples = 0, 0, 0
        class_loss = defaultdict(float)
        class_correct = defaultdict(int)
        class_total = defaultdict(int)

        for X, y in train_loader:
            X, y = X.to(device), y.to(device)

            optimizer.zero_grad()
            logits = model(X)
            loss = criterion(logits, y)
            loss.backward()
            optimizer.step()

            preds = logits.argmax(dim=1)
            total_loss += loss.item() * y.size(0)
            total_correct += (preds == y).sum().item()
            total_samples += y.size(0)

            for cls in [0, 1]:  # violin, viola
                idx = (y == cls)
                if idx.sum().item() > 0:
                    cls_loss = criterion(logits[idx], y[idx])
                    class_loss[cls] += cls_loss.item() * idx.sum().item()
                    class_correct[cls] += (preds[idx] == y[idx]).sum().item()
                    class_total[cls] += idx.sum().item()

        train_loss = total_loss / total_samples
        train_acc = total_correct / total_samples
        train_class_acc = [class_correct[c] / class_total[c] for c in [0, 1]]
        train_class_loss = [class_loss[c] / class_total[c] for c in [0, 1]]

        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["train_class_acc"].append(train_class_acc)
        history["train_class_loss"].append(train_class_loss)

        # --- Validation ---
        model.eval()
        total_loss, total_correct, total_samples = 0, 0, 0
        class_loss = defaultdict(float)
        class_correct = defaultdict(int)
        class_total = defaultdict(int)
        val_y_true, val_y_score = [], []

        with torch.no_grad():
            for X, y in val_loader:
                X, y = X.to(device), y.to(device)
                logits = model(X)
                loss = criterion(logits, y)

                preds = logits.argmax(dim=1)
                probs = torch.softmax(logits, dim=1)[:, 1]

                total_loss += loss.item() * y.size(0)
                total_correct += (preds == y).sum().item()
                total_samples += y.size(0)

                val_y_true.extend(y.cpu().numpy())
                val_y_score.extend(probs.cpu().numpy())

                for cls in [0, 1]:
                    idx = (y == cls)
                    if idx.sum().item() > 0:
                        cls_loss = criterion(logits[idx], y[idx])
                        class_loss[cls] += cls_loss.item() * idx.sum().item()
                        class_correct[cls] += (preds[idx] == y[idx]).sum().item()
                        class_total[cls] += idx.sum().item()

        val_loss = total_loss / total_samples
        val_acc = total_correct / total_samples
        val_class_acc = [class_correct[c] / class_total[c] for c in [0, 1]]
        val_class_loss = [class_loss[c] / class_total[c] for c in [0, 1]]

        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)
        history["val_class_acc"].append(val_class_acc)
        history["val_class_loss"].append(val_class_loss)
        history["val_roc_y_true"] = val_y_true
        history["val_roc_y_score"] = val_y_score

        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"  Train Loss: {train_loss:.4f} | Acc: {train_acc:.4f} | Violin Acc: {train_class_acc[0]:.4f} | Viola Acc: {train_class_acc[1]:.4f}")
        print(f"  Val   Loss: {val_loss:.4f} | Acc: {val_acc:.4f} | Violin Acc: {val_class_acc[0]:.4f} | Viola Acc: {val_class_acc[1]:.4f}")

        # Save model every epoch
        torch.save(model.state_dict(), f"violin_viola_cnn_asymmetrical_epoch_{epoch+1}.pth")
        print(f"Model saved as violin_viola_cnn_asymmetrical_epoch_{epoch+1}.pth")
        # Save maximum average accuracy between violin and viola
        max_avg_acc[(epoch + 1)] = (train_acc + val_acc) / 2

    return history, max_avg_acc

def plot_history(history):
    epochs = range(1, len(history["train_loss"]) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, history["train_loss"], label="Train Loss")
    plt.plot(epochs, history["val_loss"], label="Val Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.title("Loss over Epochs")

    plt.subplot(1, 2, 2)
    plt.plot(epochs, history["train_acc"], label="Train Acc")
    plt.plot(epochs, history["val_acc"], label="Val Acc")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.title("Accuracy over Epochs")

    plt.tight_layout()
    plt.show()

def plot_roc(y_true, y_score):
    fpr, tpr, _ = roc_curve(y_true, y_score)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.2f})")
    plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve (Violin vs Viola)")
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()

# %%
history, max_avg_acc = train(model, train_loader, test_loader, criterion, optimizer, device='cuda', num_epochs=25)

plot_history(history)
plot_roc(history["val_roc_y_true"], history["val_roc_y_score"])

# Restore the best model based on maximum average accuracy
best_epoch = max(max_avg_acc, key=max_avg_acc.get)
state_dict = torch.load(f"violin_viola_cnn_asymmetrical_epoch_{best_epoch}.pth")
# Remove 'module.' prefix from all keys
new_state_dict = {k.replace("module.", ""): v for k, v in state_dict.items()}
model.load_state_dict(new_state_dict)
print(f"Best model restored from epoch {best_epoch} with max average accuracy {max_avg_acc[best_epoch]:.4f}")
# Out:
# Using 2 GPUs with DataParallel
# Epoch 1/25
#   Train Loss: 0.5345 | Acc: 0.7339 | Violin Acc: 0.8434 | Viola Acc: 0.5641
#   Val   Loss: 0.4742 | Acc: 0.8000 | Violin Acc: 0.8189 | Viola Acc: 0.7611
# Model saved as violin_viola_cnn_asymmetrical_epoch_1.pth
# Epoch 2/25
#   Train Loss: 0.2675 | Acc: 0.8876 | Violin Acc: 0.8888 | Viola Acc: 0.8857
#   Val   Loss: 0.2920 | Acc: 0.8803 | Violin Acc: 0.9103 | Viola Acc: 0.8183
# Model saved as violin_viola_cnn_asymmetrical_epoch_2.pth
# Epoch 3/25
#   Train Loss: 0.1674 | Acc: 0.9338 | Violin Acc: 0.9328 | Viola Acc: 0.9353
#   Val   Loss: 0.2664 | Acc: 0.8684 | Violin Acc: 0.8308 | Viola Acc: 0.9462
# Model saved as violin_viola_cnn_asymmetrical_epoch_3.pth
# Epoch 4/25
#   Train Loss: 0.1177 | Acc: 0.9543 | Violin Acc: 0.9548 | Viola Acc: 0.9534
#   Val   Loss: 0.2123 | Acc: 0.9253 | Violin Acc: 0.9668 | Viola Acc: 0.8393
# Model saved as violin_viola_cnn_asymmetrical_epoch_4.pth
# Epoch 5/25
#   Train Loss: 0.0997 | Acc: 0.9621 | Violin Acc: 0.9654 | Viola Acc: 0.9571
#   Val   Loss: 0.2656 | Acc: 0.9156 | Violin Acc: 0.9792 | Viola Acc: 0.7840
# Model saved as violin_viola_cnn_asymmetrical_epoch_5.pth
# Epoch 6/25
#   Train Loss: 0.0895 | Acc: 0.9662 | Violin Acc: 0.9698 | Viola Acc: 0.9606
#   Val   Loss: 0.2178 | Acc: 0.9256 | Violin Acc: 0.9740 | Viola Acc: 0.8252
# Model saved as violin_viola_cnn_asymmetrical_epoch_6.pth
# Epoch 7/25
#   Train Loss: 0.0766 | Acc: 0.9713 | Violin Acc: 0.9749 | Viola Acc: 0.9658
#   Val   Loss: 0.2654 | Acc: 0.9005 | Violin Acc: 0.8705 | Viola Acc: 0.9626
# Model saved as violin_viola_cnn_asymmetrical_epoch_7.pth
# Epoch 8/25
#   Train Loss: 0.0601 | Acc: 0.9764 | Violin Acc: 0.9779 | Viola Acc: 0.9743
#   Val   Loss: 0.2059 | Acc: 0.9241 | Violin Acc: 0.9270 | Viola Acc: 0.9179
# Model saved as violin_viola_cnn_asymmetrical_epoch_8.pth
# Epoch 9/25
#   Train Loss: 0.0582 | Acc: 0.9785 | Violin Acc: 0.9793 | Viola Acc: 0.9773
#   Val   Loss: 0.2124 | Acc: 0.9251 | Violin Acc: 0.9184 | Viola Acc: 0.9389
# Model saved as violin_viola_cnn_asymmetrical_epoch_9.pth
# Epoch 10/25
#   Train Loss: 0.0447 | Acc: 0.9832 | Violin Acc: 0.9849 | Viola Acc: 0.9807
#   Val   Loss: 0.3415 | Acc: 0.8971 | Violin Acc: 0.8651 | Viola Acc: 0.9634
# Model saved as violin_viola_cnn_asymmetrical_epoch_10.pth
# Epoch 11/25
#   Train Loss: 0.0384 | Acc: 0.9847 | Violin Acc: 0.9855 | Viola Acc: 0.9836
#   Val   Loss: 0.2312 | Acc: 0.9328 | Violin Acc: 0.9491 | Viola Acc: 0.8989
# Model saved as violin_viola_cnn_asymmetrical_epoch_11.pth
# Epoch 12/25
#   Train Loss: 0.0402 | Acc: 0.9837 | Violin Acc: 0.9859 | Viola Acc: 0.9804
#   Val   Loss: 0.2398 | Acc: 0.9212 | Violin Acc: 0.9593 | Viola Acc: 0.8424
# Model saved as violin_viola_cnn_asymmetrical_epoch_12.pth
# Epoch 13/25
#   Train Loss: 0.0312 | Acc: 0.9872 | Violin Acc: 0.9880 | Viola Acc: 0.9859
#   Val   Loss: 0.2356 | Acc: 0.9338 | Violin Acc: 0.9720 | Viola Acc: 0.8546
# Model saved as violin_viola_cnn_asymmetrical_epoch_13.pth
# Epoch 14/25
#   Train Loss: 0.0324 | Acc: 0.9874 | Violin Acc: 0.9876 | Viola Acc: 0.9870
#   Val   Loss: 0.2157 | Acc: 0.9381 | Violin Acc: 0.9491 | Viola Acc: 0.9153
# Model saved as violin_viola_cnn_asymmetrical_epoch_14.pth
# Epoch 15/25
#   Train Loss: 0.0214 | Acc: 0.9910 | Violin Acc: 0.9915 | Viola Acc: 0.9902
#   Val   Loss: 0.2447 | Acc: 0.9329 | Violin Acc: 0.9536 | Viola Acc: 0.8901
# Model saved as violin_viola_cnn_asymmetrical_epoch_15.pth
# Epoch 16/25
#   Train Loss: 0.0342 | Acc: 0.9881 | Violin Acc: 0.9884 | Viola Acc: 0.9876
#   Val   Loss: 0.2470 | Acc: 0.9355 | Violin Acc: 0.9381 | Viola Acc: 0.9302
# Model saved as violin_viola_cnn_asymmetrical_epoch_16.pth
# Epoch 17/25
#   Train Loss: 0.0204 | Acc: 0.9916 | Violin Acc: 0.9912 | Viola Acc: 0.9922
#   Val   Loss: 0.2677 | Acc: 0.9276 | Violin Acc: 0.9359 | Viola Acc: 0.9103
# Model saved as violin_viola_cnn_asymmetrical_epoch_17.pth
# Epoch 18/25
#   Train Loss: 0.0180 | Acc: 0.9934 | Violin Acc: 0.9938 | Viola Acc: 0.9930
#   Val   Loss: 0.2934 | Acc: 0.9380 | Violin Acc: 0.9666 | Viola Acc: 0.8786
# Model saved as violin_viola_cnn_asymmetrical_epoch_18.pth
# Epoch 19/25
#   Train Loss: 0.0142 | Acc: 0.9951 | Violin Acc: 0.9949 | Viola Acc: 0.9954
#   Val   Loss: 0.3433 | Acc: 0.9305 | Violin Acc: 0.9773 | Viola Acc: 0.8336
# Model saved as violin_viola_cnn_asymmetrical_epoch_19.pth
# Epoch 20/25
#   Train Loss: 0.0192 | Acc: 0.9927 | Violin Acc: 0.9928 | Viola Acc: 0.9926
#   Val   Loss: 0.4279 | Acc: 0.9043 | Violin Acc: 0.8942 | Viola Acc: 0.9252
# Model saved as violin_viola_cnn_asymmetrical_epoch_20.pth
# Epoch 21/25
#   Train Loss: 0.0154 | Acc: 0.9939 | Violin Acc: 0.9944 | Viola Acc: 0.9931
#   Val   Loss: 0.3346 | Acc: 0.9346 | Violin Acc: 0.9499 | Viola Acc: 0.9031
# Model saved as violin_viola_cnn_asymmetrical_epoch_21.pth
# Epoch 22/25
#   Train Loss: 0.0136 | Acc: 0.9951 | Violin Acc: 0.9952 | Viola Acc: 0.9951
#   Val   Loss: 0.3285 | Acc: 0.9283 | Violin Acc: 0.9198 | Viola Acc: 0.9458
# Model saved as violin_viola_cnn_asymmetrical_epoch_22.pth
# Epoch 23/25
#   Train Loss: 0.0174 | Acc: 0.9941 | Violin Acc: 0.9947 | Viola Acc: 0.9933
#   Val   Loss: 0.2948 | Acc: 0.9359 | Violin Acc: 0.9353 | Viola Acc: 0.9370
# Model saved as violin_viola_cnn_asymmetrical_epoch_23.pth
# Epoch 24/25
#   Train Loss: 0.0153 | Acc: 0.9945 | Violin Acc: 0.9944 | Viola Acc: 0.9946
#   Val   Loss: 0.3236 | Acc: 0.9187 | Violin Acc: 0.9451 | Viola Acc: 0.8641
# Model saved as violin_viola_cnn_asymmetrical_epoch_24.pth
# Epoch 25/25
#   Train Loss: 0.0096 | Acc: 0.9965 | Violin Acc: 0.9965 | Viola Acc: 0.9963
#   Val   Loss: 0.4338 | Acc: 0.9239 | Violin Acc: 0.9580 | Viola Acc: 0.8534
# Model saved as violin_viola_cnn_asymmetrical_epoch_25.pth
# Best model restored from epoch 18 with max average accuracy 0.9657

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

for epoch in range(1, 26):
    state_dict = torch.load(f"violin_viola_cnn_asymmetrical_epoch_{epoch}.pth")
    new_state_dict = {k.replace("module.", ""): v for k, v in state_dict.items()}
    model.load_state_dict(new_state_dict)
    model.to('cpu')
    model.eval()
    total_correct, total_samples = 0, 0
    class_correct = defaultdict(int)
    class_total = defaultdict(int)

    all_preds = []
    all_labels = []

    with torch.no_grad():
        for X, y in test_loader:
            X, y = X.to('cpu'), y.to('cpu')
            logits = model(X)
            preds = logits.argmax(dim=1)
            total_correct += (preds == y).sum().item()
            total_samples += y.size(0)

            # For accuracy
            for i in range(y.size(0)):
                class_total[y[i].item()] += 1
                class_correct[y[i].item()] += (preds[i] == y[i]).item()

            # For F1/Precision/Recall
            all_preds.extend(preds.tolist())
            all_labels.extend(y.tolist())

    test_acc = total_correct / total_samples
    print(f"Epoch {epoch}: Test Accuracy: {test_acc:.4f}")

    for cls in [0, 1]:
        if class_total[cls] > 0:
            class_acc = class_correct[cls] / class_total[cls]
            print(f"  Class {cls} Accuracy: {class_acc:.4f}")

    avg_class_acc = sum(class_correct[c] / class_total[c] for c in [0, 1]) / 2
    print(f"Average Class Accuracy: {avg_class_acc:.4f}")

    # F1, Precision, Recall (macro = average across classes)
    f1 = f1_score(all_labels, all_preds, average='macro')
    precision = precision_score(all_labels, all_preds, average='macro')
    recall = recall_score(all_labels, all_preds, average='macro')
    print(f"F1 Score (macro): {f1:.4f}")
    print(f"Precision (macro): {precision:.4f}")
    print(f"Recall (macro): {recall:.4f}")
    print("-" * 40)
# Out:
# Epoch 1: Test Accuracy: 0.8000
#   Class 0 Accuracy: 0.8189
#   Class 1 Accuracy: 0.7611
# Average Class Accuracy: 0.7900
# F1 Score (macro): 0.7796
# Precision (macro): 0.7732
# Recall (macro): 0.7900
# ----------------------------------------
# Epoch 2: Test Accuracy: 0.8803
#   Class 0 Accuracy: 0.9103
#   Class 1 Accuracy: 0.8183
# Average Class Accuracy: 0.8643
# F1 Score (macro): 0.8639
# Precision (macro): 0.8635
# Recall (macro): 0.8643
# ----------------------------------------
# Epoch 3: Test Accuracy: 0.8684
#   Class 0 Accuracy: 0.8308
#   Class 1 Accuracy: 0.9462
# Average Class Accuracy: 0.8885
# F1 Score (macro): 0.8595
# Precision (macro): 0.8497
# Recall (macro): 0.8885
# ----------------------------------------
# Epoch 4: Test Accuracy: 0.9253
#   Class 0 Accuracy: 0.9668
#   Class 1 Accuracy: 0.8393
# Average Class Accuracy: 0.9031
# F1 Score (macro): 0.9128
# Precision (macro): 0.9250
# Recall (macro): 0.9031
# ----------------------------------------
# Epoch 5: Test Accuracy: 0.9156
#   Class 0 Accuracy: 0.9792
#   Class 1 Accuracy: 0.7840
# Average Class Accuracy: 0.8816
# F1 Score (macro): 0.8991
# Precision (macro): 0.9258
# Recall (macro): 0.8816
# ----------------------------------------
# Epoch 6: Test Accuracy: 0.9256
#   Class 0 Accuracy: 0.9740
#   Class 1 Accuracy: 0.8252
# Average Class Accuracy: 0.8996
# F1 Score (macro): 0.9124
# Precision (macro): 0.9295
# Recall (macro): 0.8996
# ----------------------------------------
# Epoch 7: Test Accuracy: 0.9005
#   Class 0 Accuracy: 0.8705
#   Class 1 Accuracy: 0.9626
# Average Class Accuracy: 0.9165
# F1 Score (macro): 0.8924
# Precision (macro): 0.8808
# Recall (macro): 0.9165
# ----------------------------------------
# Epoch 8: Test Accuracy: 0.9241
#   Class 0 Accuracy: 0.9270
#   Class 1 Accuracy: 0.9179
# Average Class Accuracy: 0.9225
# F1 Score (macro): 0.9150
# Precision (macro): 0.9088
# Recall (macro): 0.9225
# ----------------------------------------
# Epoch 9: Test Accuracy: 0.9251
#   Class 0 Accuracy: 0.9184
#   Class 1 Accuracy: 0.9389
# Average Class Accuracy: 0.9287
# F1 Score (macro): 0.9169
# Precision (macro): 0.9081
# Recall (macro): 0.9287
# ----------------------------------------
# Epoch 10: Test Accuracy: 0.8971
#   Class 0 Accuracy: 0.8651
#   Class 1 Accuracy: 0.9634
# Average Class Accuracy: 0.9142
# F1 Score (macro): 0.8890
# Precision (macro): 0.8776
# Recall (macro): 0.9142
# ----------------------------------------
# Epoch 11: Test Accuracy: 0.9328
#   Class 0 Accuracy: 0.9491
#   Class 1 Accuracy: 0.8989
# Average Class Accuracy: 0.9240
# F1 Score (macro): 0.9235
# Precision (macro): 0.9231
# Recall (macro): 0.9240
# ----------------------------------------
# Epoch 12: Test Accuracy: 0.9212
#   Class 0 Accuracy: 0.9593
#   Class 1 Accuracy: 0.8424
# Average Class Accuracy: 0.9008
# F1 Score (macro): 0.9085
# Precision (macro): 0.9177
# Recall (macro): 0.9008
# ----------------------------------------
# Epoch 13: Test Accuracy: 0.9338
#   Class 0 Accuracy: 0.9720
#   Class 1 Accuracy: 0.8546
# Average Class Accuracy: 0.9133
# F1 Score (macro): 0.9228
# Precision (macro): 0.9345
# Recall (macro): 0.9133
# ----------------------------------------
# Epoch 14: Test Accuracy: 0.9381
#   Class 0 Accuracy: 0.9491
#   Class 1 Accuracy: 0.9153
# Average Class Accuracy: 0.9322
# F1 Score (macro): 0.9299
# Precision (macro): 0.9277
# Recall (macro): 0.9322
# ----------------------------------------
# Epoch 15: Test Accuracy: 0.9329
#   Class 0 Accuracy: 0.9536
#   Class 1 Accuracy: 0.8901
# Average Class Accuracy: 0.9218
# F1 Score (macro): 0.9233
# Precision (macro): 0.9249
# Recall (macro): 0.9218
# ----------------------------------------
# Epoch 16: Test Accuracy: 0.9355
#   Class 0 Accuracy: 0.9381
#   Class 1 Accuracy: 0.9302
# Average Class Accuracy: 0.9341
# F1 Score (macro): 0.9276
# Precision (macro): 0.9221
# Recall (macro): 0.9341
# ----------------------------------------
# Epoch 17: Test Accuracy: 0.9276
#   Class 0 Accuracy: 0.9359
#   Class 1 Accuracy: 0.9103
# Average Class Accuracy: 0.9231
# F1 Score (macro): 0.9184
# Precision (macro): 0.9142
# Recall (macro): 0.9231
# ----------------------------------------
# Epoch 18: Test Accuracy: 0.9380
#   Class 0 Accuracy: 0.9666
#   Class 1 Accuracy: 0.8786
# Average Class Accuracy: 0.9226
# F1 Score (macro): 0.9284
# Precision (macro): 0.9350
# Recall (macro): 0.9226
# ----------------------------------------
# Epoch 19: Test Accuracy: 0.9305
#   Class 0 Accuracy: 0.9773
#   Class 1 Accuracy: 0.8336
# Average Class Accuracy: 0.9055
# F1 Score (macro): 0.9182
# Precision (macro): 0.9354
# Recall (macro): 0.9055
# ----------------------------------------
# Epoch 20: Test Accuracy: 0.9043
#   Class 0 Accuracy: 0.8942
#   Class 1 Accuracy: 0.9252
# Average Class Accuracy: 0.9097
# F1 Score (macro): 0.8947
# Precision (macro): 0.8849
# Recall (macro): 0.9097
# ----------------------------------------
# Epoch 21: Test Accuracy: 0.9346
#   Class 0 Accuracy: 0.9499
#   Class 1 Accuracy: 0.9031
# Average Class Accuracy: 0.9265
# F1 Score (macro): 0.9257
# Precision (macro): 0.9250
# Recall (macro): 0.9265
# ----------------------------------------
# Epoch 22: Test Accuracy: 0.9283
#   Class 0 Accuracy: 0.9198
#   Class 1 Accuracy: 0.9458
# Average Class Accuracy: 0.9328
# F1 Score (macro): 0.9205
# Precision (macro): 0.9115
# Recall (macro): 0.9328
# ----------------------------------------
# Epoch 23: Test Accuracy: 0.9359
#   Class 0 Accuracy: 0.9353
#   Class 1 Accuracy: 0.9370
# Average Class Accuracy: 0.9362
# F1 Score (macro): 0.9283
# Precision (macro): 0.9217
# Recall (macro): 0.9362
# ----------------------------------------
# Epoch 24: Test Accuracy: 0.9187
#   Class 0 Accuracy: 0.9451
#   Class 1 Accuracy: 0.8641
# Average Class Accuracy: 0.9046
# F1 Score (macro): 0.9069
# Precision (macro): 0.9094
# Recall (macro): 0.9046
# ----------------------------------------
# Epoch 25: Test Accuracy: 0.9239
#   Class 0 Accuracy: 0.9580
#   Class 1 Accuracy: 0.8534
# Average Class Accuracy: 0.9057
# F1 Score (macro): 0.9120
# Precision (macro): 0.9193
# Recall (macro): 0.9057
# ----------------------------------------
