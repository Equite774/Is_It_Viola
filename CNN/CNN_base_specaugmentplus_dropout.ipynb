# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from MixtureMasking import MixtureMasking

# %%
class ViolinViolaDataset(Dataset):
    def __init__(self, root_dir, label_map = None, transform=None):
        self.root_dir = root_dir
        self.files = [f for f in os.listdir(root_dir) if f.endswith('.npy')]
        self.label_map = label_map or {'violin': 0, 'viola': 1}
        self.transform = transform

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        filename = self.files[idx]
        filepath = os.path.join(self.root_dir, filename)
        mel = np.load(filepath)
        spec = torch.from_numpy(mel)
        spec = spec.unsqueeze(0)  # Add channel dimension
        label = self.label_map[filename.split('_')[1]] if self.label_map else None
        if self.transform:
            spec = self.transform(spec)
        return spec, label

# %%
transform = transforms.Compose([
    transforms.Resize((128, 517)),  # Resize to a fixed size
    transforms.Normalize([0.5], [0.5])  # Normalize the image
])

# %%
g_train = torch.Generator()
g_train.manual_seed(17)
train_dataset = ViolinViolaDataset('train/', transform=transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

g_testval = torch.Generator().manual_seed(17)
testval_dataset = ViolinViolaDataset('test/', transform=transform)
val_size = int(0.5 * len(testval_dataset))
test_size = len(testval_dataset) - val_size
val_subset, test_subset = random_split(testval_dataset, [val_size, test_size], generator=g_testval)
val_loader = DataLoader(val_subset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_subset, batch_size=32, shuffle=False)

# %%
for x, y in train_loader:
    print(x.shape)
    print(y.shape)
    break
# Out:
# torch.Size([32, 1, 128, 517])
# torch.Size([32])

# %%
class ViolinViolaCNN(nn.Module):
    def __init__(self):
        super(ViolinViolaCNN, self).__init__()

        self.mixturemasking1 = MixtureMasking(freq_param=8, time_param=35, activate_prob=0.6)
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=40, stride=(2, 1), kernel_size=(5, 1))   # output: (40, 62, 517)
        self.dropout = nn.Dropout2d(p=0.35)
        self.mixturemasking2 = MixtureMasking(freq_param=4, time_param=35, activate_prob=0.6)
        self.conv2 = nn.Conv2d(in_channels=40, out_channels=32, kernel_size=(3, 2))  # output: (32, 60, 516)
        self.mixturemasking3 = MixtureMasking(freq_param=4, time_param=35, activate_prob=0.6)
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=16, kernel_size=1)  # output: (16, 60, 516)

        self.pool = nn.AdaptiveAvgPool2d((16, 16))  # reduce to fixed-size for Dense

        self.fc1 = nn.Linear(16 * 16 * 16, 64)
        self.fc2 = nn.Linear(64, 16)
        self.fc3 = nn.Linear(16, 12)
        self.out = nn.Linear(12, 2)  # binary classification: violin vs viola

    def forward(self, x, labels):
        x = self.mixturemasking1(x, labels)
        x = F.relu(self.conv1(x))  # -> (40, 62, 517)
        x = self.dropout(x)
        x = self.mixturemasking2(x, labels)
        x = F.relu(self.conv2(x))  # -> (32, 60, 516)
        x = self.mixturemasking3(x, labels)
        x = F.relu(self.conv3(x))  # -> (16, 60, 516)
        x = self.pool(x)           # -> (16, 16, 16)
        x = x.view(x.size(0), -1)  # flatten
        x = F.relu(self.fc1(x))    # -> (64)
        x = F.relu(self.fc2(x))    # -> (16)
        x = F.relu(self.fc3(x))    # -> (12)
        x = self.out(x)            # -> (2)
        return x

# %%
class ViolinViolaCrossEntropyLoss(nn.Module):
    def __init__(self):
        super(ViolinViolaCrossEntropyLoss, self).__init__()
        self.register_buffer("class_weights", torch.tensor([1.0, 1.2]))

    def forward(self, outputs, labels):
        if self.class_weights is not None:
            class_weights = self.class_weights.to(outputs.device)
            return F.cross_entropy(outputs, labels, weight=class_weights)
        return F.cross_entropy(outputs, labels)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
model = ViolinViolaCNN()
criterion = ViolinViolaCrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# Out:
# Using device: cuda

# %%
from collections import defaultdict

def train(model, train_loader, val_loader, criterion, optimizer, device, num_epochs=10):
    max_avg_acc = {}

    model.to(device)

    # Use DataParallel for multiple GPUs
    if torch.cuda.device_count() > 1:
        print(f"Using {torch.cuda.device_count()} GPUs with DataParallel")
        model.to(device)  # Move model to CUDA *before* DataParallel
        model = torch.nn.DataParallel(model)
    else:
        model.to(device)


    history = {
        "train_loss": [], "val_loss": [],
        "train_acc": [], "val_acc": [],
        "train_class_acc": [], "val_class_acc": [],
        "train_class_loss": [], "val_class_loss": [],
        "val_roc_y_true": [], "val_roc_y_score": [],
    }

    for epoch in range(num_epochs):
        model.train()
        total_loss, total_correct, total_samples = 0, 0, 0
        class_loss = defaultdict(float)
        class_correct = defaultdict(int)
        class_total = defaultdict(int)

        for X, y in train_loader:
            X, y = X.to(device), y.to(device)

            optimizer.zero_grad()
            logits = model(X, y)
            loss = criterion(logits, y)
            loss.backward()
            optimizer.step()

            preds = logits.argmax(dim=1)
            total_loss += loss.item() * y.size(0)
            total_correct += (preds == y).sum().item()
            total_samples += y.size(0)

            for cls in [0, 1]:  # violin, viola
                idx = (y == cls)
                if idx.sum().item() > 0:
                    cls_loss = criterion(logits[idx], y[idx])
                    class_loss[cls] += cls_loss.item() * idx.sum().item()
                    class_correct[cls] += (preds[idx] == y[idx]).sum().item()
                    class_total[cls] += idx.sum().item()

        train_loss = total_loss / total_samples
        train_acc = total_correct / total_samples
        train_class_acc = [class_correct[c] / class_total[c] for c in [0, 1]]
        train_class_loss = [class_loss[c] / class_total[c] for c in [0, 1]]

        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["train_class_acc"].append(train_class_acc)
        history["train_class_loss"].append(train_class_loss)

        # --- Validation ---
        model.eval()
        total_loss, total_correct, total_samples = 0, 0, 0
        class_loss = defaultdict(float)
        class_correct = defaultdict(int)
        class_total = defaultdict(int)
        val_y_true, val_y_score = [], []

        with torch.no_grad():
            for X, y in val_loader:
                X, y = X.to(device), y.to(device)
                logits = model(X, None)
                loss = criterion(logits, y)

                preds = logits.argmax(dim=1)
                probs = torch.softmax(logits, dim=1)[:, 1]

                total_loss += loss.item() * y.size(0)
                total_correct += (preds == y).sum().item()
                total_samples += y.size(0)

                val_y_true.extend(y.cpu().numpy())
                val_y_score.extend(probs.cpu().numpy())

                for cls in [0, 1]:
                    idx = (y == cls)
                    if idx.sum().item() > 0:
                        cls_loss = criterion(logits[idx], y[idx])
                        class_loss[cls] += cls_loss.item() * idx.sum().item()
                        class_correct[cls] += (preds[idx] == y[idx]).sum().item()
                        class_total[cls] += idx.sum().item()

        val_loss = total_loss / total_samples
        val_acc = total_correct / total_samples
        val_class_acc = [class_correct[c] / class_total[c] for c in [0, 1]]
        val_class_loss = [class_loss[c] / class_total[c] for c in [0, 1]]

        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)
        history["val_class_acc"].append(val_class_acc)
        history["val_class_loss"].append(val_class_loss)
        history["val_roc_y_true"] = val_y_true
        history["val_roc_y_score"] = val_y_score

        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"  Train Loss: {train_loss:.4f} | Acc: {train_acc:.4f} | Violin Acc: {train_class_acc[0]:.4f} | Viola Acc: {train_class_acc[1]:.4f}")
        print(f"  Val   Loss: {val_loss:.4f} | Acc: {val_acc:.4f} | Violin Acc: {val_class_acc[0]:.4f} | Viola Acc: {val_class_acc[1]:.4f}")

        # Save model every epoch
        torch.save(model.state_dict(), f"mmdp/violin_viola_cnn_mixturemasking_dropout_epoch_{epoch+1}.pth")
        print(f"Model saved as mmdp/violin_viola_cnn_mixturemasking_dropout_epoch_{epoch+1}.pth")
        # Save maximum average accuracy between violin and viola
        max_avg_acc[(epoch + 1)] = (train_acc + val_acc) / 2

    return history, max_avg_acc

def plot_history(history):
    epochs = range(1, len(history["train_loss"]) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, history["train_loss"], label="Train Loss")
    plt.plot(epochs, history["val_loss"], label="Val Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.title("Loss over Epochs")

    plt.subplot(1, 2, 2)
    plt.plot(epochs, history["train_acc"], label="Train Acc")
    plt.plot(epochs, history["val_acc"], label="Val Acc")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.title("Accuracy over Epochs")

    plt.tight_layout()
    plt.show()

def plot_roc(y_true, y_score):
    fpr, tpr, _ = roc_curve(y_true, y_score)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.2f})")
    plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve (Violin vs Viola)")
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()

# %%
history, max_avg_acc = train(model, train_loader, val_loader, criterion, optimizer, device='cuda', num_epochs=60)

plot_history(history)
plot_roc(history["val_roc_y_true"], history["val_roc_y_score"])

# Restore the best model based on maximum average accuracy
best_epoch = max(max_avg_acc, key=max_avg_acc.get)
state_dict = torch.load(f"mmdp/violin_viola_cnn_mixturemasking_dropout_epoch_{best_epoch}.pth")
# Remove 'module.' prefix from all keys
new_state_dict = {k.replace("module.", ""): v for k, v in state_dict.items()}
model.load_state_dict(new_state_dict)
print(f"Best model restored from epoch {best_epoch} with max average accuracy {max_avg_acc[best_epoch]:.4f}")
# Out:
# Using 2 GPUs with DataParallel
# Epoch 1/60
#   Train Loss: 0.4596 | Acc: 0.7824 | Violin Acc: 0.8227 | Viola Acc: 0.7198
#   Val   Loss: 0.4359 | Acc: 0.8213 | Violin Acc: 0.8488 | Viola Acc: 0.7632
# Model saved as mmdp/violin_viola_cnn_mixturemasking_dropout_epoch_1.pth
# Epoch 2/60
#   Train Loss: 0.3259 | Acc: 0.8593 | Violin Acc: 0.8703 | Viola Acc: 0.8421
#   Val   Loss: 0.4296 | Acc: 0.8379 | Violin Acc: 0.8759 | Viola Acc: 0.7577
# Model saved as mmdp/violin_viola_cnn_mixturemasking_dropout_epoch_2.pth
# Epoch 3/60
#   Train Loss: 0.2781 | Acc: 0.8804 | Violin Acc: 0.8828 | Viola Acc: 0.8766
#   Val   Loss: 0.3299 | Acc: 0.8541 | Violin Acc: 0.8649 | Viola Acc: 0.8313
# Model saved as mmdp/violin_viola_cnn_mixturemasking_dropout_epoch_3.pth
# Epoch 4/60
#   Train Loss: 0.2108 | Acc: 0.9146 | Violin Acc: 0.9159 | Viola Acc: 0.9126
#   Val   Loss: 0.5580 | Acc: 0.7557 | Violin Acc: 0.6507 | Viola Acc: 0.9776
# Model saved as mmdp/violin_viola_cnn_mixturemasking_dropout_epoch_4.pth
# Epoch 5/60
#   Train Loss: 0.1846 | Acc: 0.9256 | Violin Acc: 0.9242 | Viola Acc: 0.9278
#   Val   Loss: 0.2597 | Acc: 0.8755 | Violin Acc: 0.8623 | Viola Acc: 0.9033
# Model saved as mmdp/violin_viola_cnn_mixturemasking_dropout_epoch_5.pth
# Epoch 6/60
#   Train Loss: 0.1590 | Acc: 0.9386 | Violin Acc: 0.9407 | Viola Acc: 0.9355
#   Val   Loss: 0.2207 | Acc: 0.9212 | Violin Acc: 0.9484 | Viola Acc: 0.8638
# Model saved as mmdp/violin_viola_cnn_mixturemasking_dropout_epoch_6.pth
# Epoch 7/60
#   Train Loss: 0.1395 | Acc: 0.9461 | Violin Acc: 0.9482 | Viola Acc: 0.9428
#   Val   Loss: 0.2130 | Acc: 0.9234 | Violin Acc: 0.9385 | Viola Acc: 0.8916
# Model saved as mmdp/violin_viola_cnn_mixturemasking_dropout_epoch_7.pth
# Epoch 8/60
#   Train Loss: 0.1187 | Acc: 0.9553 | Violin Acc: 0.9573 | Viola Acc: 0.9523
#   Val   Loss: 0.2178 | Acc: 0.9152 | Violin Acc: 0.9275 | Viola Acc: 0.8893
# Model saved as mmdp/violin_viola_cnn_mixturemasking_dropout_epoch
# Model saved as mmdp/violin_viola_cnn_mixturemasking_dropout_epoch_57.pth
# Epoch 58/60
#   Train Loss: 0.0202 | Acc: 0.9929 | Violin Acc: 0.9932 | Viola Acc: 0.9925
#   Val   Loss: 0.2686 | Acc: 0.9411 | Violin Acc: 0.9685 | Viola Acc: 0.8831
# Model saved as mmdp/violin_viola_cnn_mixturemasking_dropout_epoch_58.pth
# Epoch 59/60
#   Train Loss: 0.0191 | Acc: 0.9933 | Violin Acc: 0.9937 | Viola Acc: 0.9928
#   Val   Loss: 0.3141 | Acc: 0.9309 | Violin Acc: 0.9711 | Viola Acc: 0.8460
# Model saved as mmdp/violin_viola_cnn_mixturemasking_dropout_epoch_59.pth
# Epoch 60/60
#   Train Loss: 0.0169 | Acc: 0.9933 | Violin Acc: 0.9932 | Viola Acc: 0.9934
#   Val   Loss: 0.3368 | Acc: 0.9456 | Violin Acc: 0.9659 | Viola Acc: 0.9025
# Model saved as mmdp/violin_viola_cnn_mixturemasking_dropout_epoch_60.pth
# Best model restored from epoch 38 with max average accuracy 0.9708

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

for epoch in range(1, 61):
    state_dict = torch.load(f"mmdp/violin_viola_cnn_mixturemasking_dropout_epoch_{epoch}.pth")
    new_state_dict = {k.replace("module.", ""): v for k, v in state_dict.items()}
    model.load_state_dict(new_state_dict)
    model.to('cpu')
    model.eval()
    total_correct, total_samples = 0, 0
    class_correct = defaultdict(int)
    class_total = defaultdict(int)

    all_preds = []
    all_labels = []

    with torch.no_grad():
        for X, y in test_loader:
            X, y = X.to('cpu'), y.to('cpu')
            logits = model(X, None)
            preds = logits.argmax(dim=1)
            total_correct += (preds == y).sum().item()
            total_samples += y.size(0)

            # For accuracy
            for i in range(y.size(0)):
                class_total[y[i].item()] += 1
                class_correct[y[i].item()] += (preds[i] == y[i]).item()

            # For F1/Precision/Recall
            all_preds.extend(preds.tolist())
            all_labels.extend(y.tolist())

    test_acc = total_correct / total_samples
    print(f"Epoch {epoch}: Test Accuracy: {test_acc:.4f}")

    for cls in [0, 1]:
        if class_total[cls] > 0:
            class_acc = class_correct[cls] / class_total[cls]
            print(f"  Class {cls} Accuracy: {class_acc:.4f}")

    avg_class_acc = sum(class_correct[c] / class_total[c] for c in [0, 1]) / 2
    print(f"Average Class Accuracy: {avg_class_acc:.4f}")

    # F1, Precision, Recall (macro = average across classes)
    f1 = f1_score(all_labels, all_preds, average='macro')
    precision = precision_score(all_labels, all_preds, average='macro')
    recall = recall_score(all_labels, all_preds, average='macro')
    print(f"F1 Score (macro): {f1:.4f}")
    print(f"Precision (macro): {precision:.4f}")
    print(f"Recall (macro): {recall:.4f}")
    print("-" * 40)
# Out:
# Epoch 1: Test Accuracy: 0.8062
#   Class 0 Accuracy: 0.8320
#   Class 1 Accuracy: 0.7538
# Average Class Accuracy: 0.7929
# F1 Score (macro): 0.7858
# Precision (macro): 0.7806
# Recall (macro): 0.7929
# ----------------------------------------
# Epoch 2: Test Accuracy: 0.8203
#   Class 0 Accuracy: 0.8609
#   Class 1 Accuracy: 0.7380
# Average Class Accuracy: 0.7994
# F1 Score (macro): 0.7979
# Precision (macro): 0.7964
# Recall (macro): 0.7994
# ----------------------------------------
# Epoch 3: Test Accuracy: 0.8474
#   Class 0 Accuracy: 0.8539
#   Class 1 Accuracy: 0.8343
# Average Class Accuracy: 0.8441
# F1 Score (macro): 0.8327
# Precision (macro): 0.8252
# Recall (macro): 0.8441
# ----------------------------------------
# Epoch 4: Test Accuracy: 0.7502
#   Class 0 Accuracy: 0.6350
#   Class 1 Accuracy: 0.9842
# Average Class Accuracy: 0.8096
# F1 Score (macro): 0.7477
# Precision (macro): 0.7792
# Recall (macro): 0.8096
# ----------------------------------------
# Epoch 5: Test Accuracy: 0.8693
#   Class 0 Accuracy: 0.8516
#   Class 1 Accuracy: 0.9051
# Average Class Accuracy: 0.8784
# F1 Score (macro): 0.8589
# Precision (macro): 0.8491
# Recall (macro): 0.8784
# ----------------------------------------
# Epoch 6: Test Accuracy: 0.9197
#   Class 0 Accuracy: 0.9462
#   Class 1 Accuracy: 0.8660
# Average Class Accuracy: 0.9061
# F1 Score (macro): 0.9087
# Precision (macro): 0.9114
# Recall (macro): 0.9061
# ----------------------------------------
# Epoch 7: Test Accuracy: 0.9237
#   Class 0 Accuracy: 0.9351
#   Class 1 Accuracy: 0.9006
# Average Class Accuracy: 0.9178
# F1 Score (macro): 0.9144
# Precision (macro): 0.9113
# Recall (macro): 0.9178
# ----------------------------------------
# Epoch 8: Test Accuracy: 0.9175
#   Class 0 Accuracy: 0.9284
#   Class 1 Accuracy: 0.8953
# Average Class Accuracy: 0.9119
# F1 Score (macro): 0.9076
# Precision (macro): 0.9039
# Recall (macro): 0.9119
# ----------------------------------------
# Epoch 9: Test Accuracy: 0.9257
#   Class 0 Accuracy: 0.9748
#   Class 1 Accuracy: 0.8261
# Average Class Accuracy: 0.9004
# F1 Score (macro): 0.9131
# Precision (macro): 0.9304
# Recall (macro): 0.9004
# ----------------------------------------
# Epoch 10: Test Accuracy: 0.8954
#   Class 0 Accuracy: 0.8798
#   Class 1 Accuracy: 0.9270
# Average Class Accuracy: 0.9034
# F1 Score (macro): 0.8862
# Precision (macro): 0.8762
# Recall (macro): 0.9034
# ----------------------------------------
# Epoch 11: Test Accuracy: 0.9349
#   Class 0 Accuracy: 0.9340
#   Class 1 Accuracy: 0.9367
# Average Class Accuracy: 0.9354
# F1 Score (macro): 0.9276
# Precision (macro): 0.9213
# Recall (macro): 0.9354
# ----------------------------------------
# Epoch 12: Test Accuracy: 0.9284
#   Class 0 Accuracy: 0.9180
#   Class 1 Accuracy: 0.9495
# Average Class Accuracy: 0.9338
# F1 Score (macro): 0.9213
# Precision (macro): 0.9123
# Recall (macro): 0.9338
# ----------------------------------------
# Epoch 13: Test Accuracy: 0.9212
#   Class 0 Accuracy: 0.9065
#   Class 1 Accuracy: 0.9511
# Average Class Accuracy: 0.9288
# F1 Score (macro): 0.9138
# Precision (macro): 0.9039
# Recall (macro): 0.9288
# ----------------------------------------
# Epoch 14: Test Accuracy: 0.9396
#   Class 0 Accuracy: 0.9288
#   Class 1 Accuracy: 0.9616
# Average Class Accuracy: 0.9452
# F1 Score (macro): 0.9334
# Precision (macro): 0.9247
# Recall (macro): 0.9452
# ----------------------------------------
# Epoch 15: Test Accuracy: 0.9389
#   Class 0 Accuracy: 0.9358
#   Class 1 Accuracy: 0.9450
# Average Class Accuracy: 0.9404
# F1 Score (macro): 0.9321
# Precision (macro): 0.9254
# Recall (macro): 0.9404
# ----------------------------------------
# Epoch 16: Test Accuracy: 0.9396
#   Class 0 Accuracy: 0.9310
#   Class 1 Accuracy: 0.9571
# Average Class Accuracy: 0.9440
# F1 Score (macro): 0.9333
# Precision (macro): 0.9251
# Recall (macro): 0.9440
# ----------------------------------------
# Epoch 17: Test Accuracy: 0.9389
#   Class 0 Accuracy: 0.9733
#   Class 1 Accuracy: 0.8690
# Average Class Accuracy: 0.9211
# F1 Score (macro): 0.9295
# Precision (macro): 0.9395
# Recall (macro): 0.9211
# ----------------------------------------
# Epoch 18: Test Accuracy: 0.9406
#   Class 0 Accuracy: 0.9440
#   Class 1 Accuracy: 0.9337
# Average Class Accuracy: 0.9389
# F1 Score (macro): 0.9336
# Precision (macro): 0.9290
# Recall (macro): 0.9389
# ----------------------------------------
# Epoch 19: Test Accuracy: 0.9297
#   Class 0 Accuracy: 0.9180
#   Class 1 Accuracy: 0.9533
# Average Class Accuracy: 0.9357
# F1 Score (macro): 0.9227
# Precision (macro): 0.9135
# Recall (macro): 0.9357
# ----------------------------------------
# Epoch 20: Test Accuracy: 0.9389
#   Class 0 Accuracy: 0.9258
#   Class 1 Accuracy: 0.9654
# Average Class Accuracy: 0.9456
# F1 Score (macro): 0.9327
# Precision (macro): 0.9235
# Recall (macro): 0.9456
# ----------------------------------------
# Epoch 21: Test Accuracy: 0.9369
#   Class 0 Accuracy: 0.9392
#   Class 1 Accuracy: 0.9322
# Average Class Accuracy: 0.9357
# F1 Score (macro): 0.9296
# Precision (macro): 0.9243
# Recall (macro): 0.9357
# ----------------------------------------
# Epoch 22: Test Accuracy: 0.9374
#   Class 0 Accuracy: 0.9518
#   Class 1 Accuracy: 0.9081
# Average Class Accuracy: 0.9300
# F1 Score (macro): 0.9293
# Precision (macro): 0.9287
# Recall (macro): 0.9300
# ----------------------------------------
# Epoch 23: Test Accuracy: 0.9399
#   Class 0 Accuracy: 0.9336
#   Class 1 Accuracy: 0.9526
# Average Class Accuracy: 0.9431
# F1 Score (macro): 0.9334
# Precision (macro): 0.9258
# Recall (macro): 0.9431
# ----------------------------------------
# Epoch 24: Test Accuracy: 0.9324
#   Class 0 Accuracy: 0.9228
#   Class 1 Accuracy: 0.9518
# Average Class Accuracy: 0.9373
# F1 Score (macro): 0.9255
# Precision (macro): 0.9168
# Recall (macro): 0.9373
# ----------------------------------------
# Epoch 25: Test Accuracy: 0.9284
#   Class 0 Accuracy: 0.9507
#   Class 1 Accuracy: 0.8833
# Average Class Accuracy: 0.9170
# F1 Score (macro): 0.9187
# Precision (macro): 0.9206
# Recall (macro): 0.9170
# ----------------------------------------
# Epoch 26: Test Accuracy: 0.9411
#   Class 0 Accuracy: 0.9440
#   Class 1 Accuracy: 0.9352
# Average Class Accuracy: 0.9396
# F1 Score (macro): 0.9342
# Precision (macro): 0.9295
# Recall (macro): 0.9396
# ----------------------------------------
# Epoch 27: Test Accuracy: 0.9374
#   Class 0 Accuracy: 0.9599
#   Class 1 Accuracy: 0.8916
# Average Class Accuracy: 0.9258
# F1 Score (macro): 0.9287
# Precision (macro): 0.9319
# Recall (macro): 0.9258
# ----------------------------------------
# Epoch 28: Test Accuracy: 0.9349
#   Class 0 Accuracy: 0.9659
#   Class 1 Accuracy: 0.8720
# Average Class Accuracy: 0.9189
# F1 Score (macro): 0.9252
# Precision (macro): 0.9326
# Recall (macro): 0.9189
# ----------------------------------------
# Epoch 29: Test Accuracy: 0.9414
#   Class 0 Accuracy: 0.9458
#   Class 1 Accuracy: 0.9322
# Average Class Accuracy: 0.9390
# F1 Score (macro): 0.9344
# Precision (macro): 0.9302
# Recall (macro): 0.9390
# ----------------------------------------
# Epoch 30: Test Accuracy: 0.9428
#   Class 0 Accuracy: 0.9677
#   Class 1 Accuracy: 0.8923
# Average Class Accuracy: 0.9300
# F1 Score (macro): 0.9347
# Precision (macro): 0.9398
# Recall (macro): 0.9300
# ----------------------------------------
# Epoch 31: Test Accuracy: 0.9421
#   Class 0 Accuracy: 0.9466
#   Class 1 Accuracy: 0.9330
# Average Class Accuracy: 0.9398
# F1 Score (macro): 0.9352
# Precision (macro): 0.9311
# Recall (macro): 0.9398
# ----------------------------------------
# Epoch 32: Test Accuracy: 0.9399
#   Class 0 Accuracy: 0.9503
#   Class 1 Accuracy: 0.9187
# Average Class Accuracy: 0.9345
# F1 Score (macro): 0.9323
# Precision (macro): 0.9303
# Recall (macro): 0.9345
# ----------------------------------------
# Epoch 33: Test Accuracy: 0.9401
#   Class 0 Accuracy: 0.9243
#   Class 1 Accuracy: 0.9721
# Average Class Accuracy: 0.9482
# F1 Score (macro): 0.9343
# Precision (macro): 0.9245
# Recall (macro): 0.9482
# ----------------------------------------
# Epoch 34: Test Accuracy: 0.9304
#   Class 0 Accuracy: 0.9236
#   Class 1 Accuracy: 0.9443
# Average Class Accuracy: 0.9339
# F1 Score (macro): 0.9232
# Precision (macro): 0.9150
# Recall (macro): 0.9339
# ----------------------------------------
# Epoch 35: Test Accuracy: 0.9381
#   Class 0 Accuracy: 0.9429
#   Class 1 Accuracy: 0.9285
# Average Class Accuracy: 0.9357
# F1 Score (macro): 0.9308
# Precision (macro): 0.9265
# Recall (macro): 0.9357
# ----------------------------------------
# Epoch 36: Test Accuracy: 0.9406
#   Class 0 Accuracy: 0.9573
#   Class 1 Accuracy: 0.9066
# Average Class Accuracy: 0.9320
# F1 Score (macro): 0.9327
# Precision (macro): 0.9335
# Recall (macro): 0.9320
# ----------------------------------------
# Epoch 37: Test Accuracy: 0.9220
#   Class 0 Accuracy: 0.9841
#   Class 1 Accuracy: 0.7959
# Average Class Accuracy: 0.8900
# F1 Score (macro): 0.9074
# Precision (macro): 0.9341
# Recall (macro): 0.8900
# ----------------------------------------
# Epoch 38: Test Accuracy: 0.9481
#   Class 0 Accuracy: 0.9525
#   Class 1 Accuracy: 0.9390
# Average Class Accuracy: 0.9458
# F1 Score (macro): 0.9418
# Precision (macro): 0.9382
# Recall (macro): 0.9458
# ----------------------------------------
# Epoch 39: Test Accuracy: 0.9446
#   Class 0 Accuracy: 0.9481
#   Class 1 Accuracy: 0.9375
# Average Class Accuracy: 0.9428
# F1 Score (macro): 0.9380
# Precision (macro): 0.9337
# Recall (macro): 0.9428
# ----------------------------------------
# Epoch 40: Test Accuracy: 0.9001
#   Class 0 Accuracy: 0.9904
#   Class 1 Accuracy: 0.7169
# Average Class Accuracy: 0.8536
# F1 Score (macro): 0.8778
# Precision (macro): 0.9250
# Recall (macro): 0.8536
# ----------------------------------------
# Epoch 41: Test Accuracy: 0.9401
#   Class 0 Accuracy: 0.9585
#   Class 1 Accuracy: 0.9029
# Average Class Accuracy: 0.9307
# F1 Score (macro): 0.9321
# Precision (macro): 0.9335
# Recall (macro): 0.9307
# ----------------------------------------
# Epoch 42: Test Accuracy: 0.9334
#   Class 0 Accuracy: 0.9766
#   Class 1 Accuracy: 0.8456
# Average Class Accuracy: 0.9111
# F1 Score (macro): 0.9225
# Precision (macro): 0.9373
# Recall (macro): 0.9111
# ----------------------------------------
# Epoch 43: Test Accuracy: 0.9341
#   Class 0 Accuracy: 0.9496
#   Class 1 Accuracy: 0.9029
# Average Class Accuracy: 0.9262
# F1 Score (macro): 0.9256
# Precision (macro): 0.9251
# Recall (macro): 0.9262
# ----------------------------------------
# Epoch 44: Test Accuracy: 0.9401
#   Class 0 Accuracy: 0.9488
#   Class 1 Accuracy: 0.9224
# Average Class Accuracy: 0.9356
# F1 Score (macro): 0.9327
# Precision (macro): 0.9300
# Recall (macro): 0.9356
# ----------------------------------------
# Epoch 45: Test Accuracy: 0.9235
#   Class 0 Accuracy: 0.9117
#   Class 1 Accuracy: 0.9473
# Average Class Accuracy: 0.9295
# F1 Score (macro): 0.9160
# Precision (macro): 0.9066
# Recall (macro): 0.9295
# ----------------------------------------
# Epoch 46: Test Accuracy: 0.9488
#   Class 0 Accuracy: 0.9651
#   Class 1 Accuracy: 0.9157
# Average Class Accuracy: 0.9404
# F1 Score (macro): 0.9419
# Precision (macro): 0.9435
# Recall (macro): 0.9404
# ----------------------------------------
# Epoch 47: Test Accuracy: 0.9202
#   Class 0 Accuracy: 0.9777
#   Class 1 Accuracy: 0.8035
# Average Class Accuracy: 0.8906
# F1 Score (macro): 0.9059
# Precision (macro): 0.9283
# Recall (macro): 0.8906
# ----------------------------------------
# Epoch 48: Test Accuracy: 0.9441
#   Class 0 Accuracy: 0.9755
#   Class 1 Accuracy: 0.8803
# Average Class Accuracy: 0.9279
# F1 Score (macro): 0.9356
# Precision (macro): 0.9448
# Recall (macro): 0.9279
# ----------------------------------------
# Epoch 49: Test Accuracy: 0.9426
#   Class 0 Accuracy: 0.9540
#   Class 1 Accuracy: 0.9194
# Average Class Accuracy: 0.9367
# F1 Score (macro): 0.9353
# Precision (macro): 0.9339
# Recall (macro): 0.9367
# ----------------------------------------
# Epoch 50: Test Accuracy: 0.9386
#   Class 0 Accuracy: 0.9611
#   Class 1 Accuracy: 0.8931
# Average Class Accuracy: 0.9271
# F1 Score (macro): 0.9301
# Precision (macro): 0.9334
# Recall (macro): 0.9271
# ----------------------------------------
# Epoch 51: Test Accuracy: 0.9346
#   Class 0 Accuracy: 0.9644
#   Class 1 Accuracy: 0.8742
# Average Class Accuracy: 0.9193
# F1 Score (macro): 0.9251
# Precision (macro): 0.9316
# Recall (macro): 0.9193
# ----------------------------------------
# Epoch 52: Test Accuracy: 0.9411
#   Class 0 Accuracy: 0.9644
#   Class 1 Accuracy: 0.8938
# Average Class Accuracy: 0.9291
# F1 Score (macro): 0.9328
# Precision (macro): 0.9369
# Recall (macro): 0.9291
# ----------------------------------------
# Epoch 53: Test Accuracy: 0.9433
#   Class 0 Accuracy: 0.9403
#   Class 1 Accuracy: 0.9495
# Average Class Accuracy: 0.9449
# F1 Score (macro): 0.9370
# Precision (macro): 0.9305
# Recall (macro): 0.9449
# ----------------------------------------
# Epoch 54: Test Accuracy: 0.9411
#   Class 0 Accuracy: 0.9581
#   Class 1 Accuracy: 0.9066
# Average Class Accuracy: 0.9324
# F1 Score (macro): 0.9333
# Precision (macro): 0.9342
# Recall (macro): 0.9324
# ----------------------------------------
# Epoch 55: Test Accuracy: 0.9359
#   Class 0 Accuracy: 0.9340
#   Class 1 Accuracy: 0.9398
# Average Class Accuracy: 0.9369
# F1 Score (macro): 0.9288
# Precision (macro): 0.9222
# Recall (macro): 0.9369
# ----------------------------------------
# Epoch 56: Test Accuracy: 0.9394
#   Class 0 Accuracy: 0.9425
#   Class 1 Accuracy: 0.9330
# Average Class Accuracy: 0.9377
# F1 Score (macro): 0.9323
# Precision (macro): 0.9275
# Recall (macro): 0.9377
# ----------------------------------------
# Epoch 57: Test Accuracy: 0.9361
#   Class 0 Accuracy: 0.9718
#   Class 1 Accuracy: 0.8637
# Average Class Accuracy: 0.9178
# F1 Score (macro): 0.9263
# Precision (macro): 0.9366
# Recall (macro): 0.9178
# ----------------------------------------
# Epoch 58: Test Accuracy: 0.9399
#   Class 0 Accuracy: 0.9662
#   Class 1 Accuracy: 0.8863
# Average Class Accuracy: 0.9263
# F1 Score (macro): 0.9312
# Precision (macro): 0.9367
# Recall (macro): 0.9263
# ----------------------------------------
# Epoch 59: Test Accuracy: 0.9299
#   Class 0 Accuracy: 0.9751
#   Class 1 Accuracy: 0.8381
# Average Class Accuracy: 0.9066
# F1 Score (macro): 0.9183
# Precision (macro): 0.9338
# Recall (macro): 0.9066
# ----------------------------------------
# Epoch 60: Test Accuracy: 0.9421
#   Class 0 Accuracy: 0.9648
#   Class 1 Accuracy: 0.8961
# Average Class Accuracy: 0.9304
# F1 Score (macro): 0.9340
# Precision (macro): 0.9378
# Recall (macro): 0.9304
# ----------------------------------------

# %%
# Best choice: Epoch 38, 46, 53
